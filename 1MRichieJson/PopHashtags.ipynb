# %%
ls
# Out:
# PLaw.ipynb                     replies_rm_clust.txt
# PopHashtags.ipynb              replies_rm_lelp_analysis.txt
# hashtags.txt                   replies_rm_lelp_clust.txt
# mentions.txt                   replies_rm_lelp_network.png
# mentions_analysis.txt          replies_rm_lelp_randhist.png
# mentions_clust.txt             replies_rm_network.png
# mentions_randhist.png          replies_rm_randhist.png
# mentions_rm_analysis.txt       retweet.txt
# mentions_rm_clust.txt          retweet_analysis.txt
# mentions_rm_lelp.png           retweet_clust.txt
# mentions_rm_lelp_analysis.txt  retweet_randhist.png
# mentions_rm_lelp_clust.txt     retweet_rm_analysis.txt
# mentions_rm_lelp_randhist.png  retweet_rm_clust.txt
# mentions_rm_network.png        retweet_rm_lelp_analysis.txt
# mentions_rm_randhist.png       retweet_rm_lelp_clust.txt
# replies.txt                    retweet_rm_lelp_network.png
# replies_analysis.txt           retweet_rm_lelp_randhist.png
# replies_clust.txt              retweet_rm_network.png
# replies_randhist.png           retweet_rm_randhist.png
# replies_rm_analysis.txt        users_w_tweets.txt*

# %%
from collections import Counter
hashtags_per_person = {} 
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        hashtag = split_line[1]
        if user_id not in hashtags_per_person:
            hashtags_per_person[user_id] = Counter()
        hashtags_per_person[user_id][hashtag] += 1

# %%
user_to_cluster = {} 
with open('mentions_rm_clust.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        cluster_id = int(split_line[1])
        user_id = int(split_line[0])
        user_to_cluster[user_id] = cluster_id

# %%
counter_per_cluster = {}
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        if user_id not in user_to_cluster:
            continue
        hashtag = split_line[1]
        cluster_id = user_to_cluster[user_id]
        
        if cluster_id not in counter_per_cluster:
            counter_per_cluster[cluster_id] = Counter()
        counter_per_cluster[cluster_id][hashtag] += 1

# %%
# for mentions
for cluster in counter_per_cluster:
    most_common = counter_per_cluster[cluster].most_common(5)
    if len(most_common) < 5:
        continue
    print "#################"
    print cluster
    print most_common
    print "#################"
# Out:
# #################
# 0
# [('Trump', 16282), ('MAGA', 9682), ('PodestaEmails9', 7012), ('HillaryGropedMe', 4399), ('Hillary', 4265)]
# #################
# #################
# 1
# [('SNL', 5), ('Election2016', 4), ('ImWithHer', 4), ('100YearsStrong', 3), ('trump', 2)]
# #################
# #################
# 4
# [('Trump', 4), ('Uber', 1), ('Google', 1), ('USA', 1), ('ToriesOut', 1)]
# #################
# #################
# 9
# [('WomenWhoVoteTrump', 13), ('boycottpaypal', 1), ('Trumpsays', 1), ('WasteHisTime2016', 1), ('PrisonStrike', 1)]
# #################
# #################
# 12
# [('trumpismplusinmypants', 1), ('Trump', 1), ('twitter', 1), ('ImWithHer', 1), ('Hillary', 1)]
# #################
# #################
# 13
# [('Election2016', 8), ('Trump', 2), ('LGBT', 2), ('100YearsStrong', 2), ('sorrynotsorry', 2)]
# #################
# #################
# 14
# [('Election2016', 6), ('sastorms', 3), ('vote', 3), ('ImWithHer', 3), ('Regina', 2)]
# #################
# #################
# 15
# [('Trump', 3), ('SNL', 2), ('Election2016', 2), ('insidejob', 1), ('ImWithHer', 1)]
# #################
# #################
# 16
# [('100YearsStrong', 2), ('whiteboymagic', 1), ('DNC', 1), ('tytlive', 1), ('RapeCulture', 1)]
# #################
# #################
# 18
# [('100YearsStrong', 5), ('Trump', 4), ('ImWithHer', 3), ('SNL', 3), ('USElection', 2)]
# #################
# #################
# 19
# [('SNL', 2), ('TrumpCheck', 2), ('Debate', 2), ('DailyShow', 1), ('Polls', 1)]
# #################
# #################
# 21
# [('SundayMorning', 1), ('CrookedHillary', 1), ('Debate', 1), ('Justice', 1), ('HilarityForPrison', 1)]
# #################
# #################
# 23
# [('HILLARY', 165), ('TRUMP', 153), ('CLINTON', 84), ('DRUGS', 69), ('AXELROD', 67)]
# #################
# #################
# 25
# [('Obama4Life', 2), ('Election2016', 2), ('FuckElection2k16', 1), ('LGBTQ', 1), ('ImWithHer', 1)]
# #################
# #################
# 26
# [('Trump', 2), ('SNL', 2), ('AAPIM4Hillary', 1), ('sexualassault', 1), ('vote', 1)]
# #################
# #################
# 27
# [('HILLARY2016', 3), ('TRUMP', 2), ('Hillary2016', 1), ('tcot', 1), ('FUNNY', 1)]
# #################
# #################
# 28
# [('Trump', 2), ('SNL', 2), ('TrumpNo', 1), ('TYbravewomen', 1), ('ImWithHer', 1)]
# #################
# #################
# 29
# [('cdnpoli', 4), ('CTVpp', 2), ('uspoli', 2), ('UKpolitics', 2), ('pnpcbc', 2)]
# #################
# #################
# 30
# [('Election2016', 3), ('ImWithHer', 2), ('p2', 1), ('NeverTrump', 1), ('SNL', 1)]
# #################
# #################
# 31
# [('totalblowoutcoming', 1), ('nevertrump', 1), ('Trump', 1), ('Jacinallhonesty', 1), ('disqualifying', 1)]
# #################
# #################
# 33
# [('socialjustice', 1), ('DinseeNuffin', 1), ('TrumpTapes', 1), ('CaseyNeistat', 1), ('sjw', 1)]
# #################
# #################
# 37
# [('Election2016', 9), ('boycottPayPal', 1), ('BoycottPayPal', 1), ('13TH', 1), ('BLACKLIVESMATTER', 1)]
# #################
# #################
# 41
# [('TerrifyingTrump', 46), ('Trump', 5), ('SaturdayNightLive', 4), ('TrumpSorrogates', 3), ('CNN', 3)]
# #################
# #################
# 43
# [('Election2016', 3), ('AmericaFirst', 1), ('electionburnout', 1), ('SNL', 1), ('funnyordie', 1)]
# #################
# #################
# 47
# [('Election2016', 6), ('Trump', 3), ('BoycottPaypal', 2), ('LGBTQS', 2), ('ImWithHer', 1)]
# #################
# #################
# 49
# [('Election2016', 3), ('SNL', 2), ('chef', 1), ('nevertrump', 1), ('yourapig', 1)]
# #################
# #################
# 50
# [('debatenight', 2), ('TrumpSucks', 1), ('MikePence', 1), ('TrumpForPresident', 1), ('TrumpTrain', 1)]
# #################
# #################
# 51
# [('SNL', 2), ('Sociology', 1), ('TrumpFatigue', 1), ('GHS', 1), ('alecbaldwin', 1)]
# #################
# #################
# 53
# [('Clinton', 72), ('Trump', 7), ('Jupp', 5), ('Daesh', 5), ('WikiLeaks', 3)]
# #################
# #################
# 62
# [('Election2016', 6), ('USpoli', 1), ('100YearsStrong', 1), ('Facepalm', 1), ('Trump', 1)]
# #################
# #################
# 63
# [('wikileaks', 3), ('PodestaEmails', 3), ('YankeeGoHome', 1), ('Clinton', 1), ('HillaryClinton', 1)]
# #################
# #################
# 64
# [('sayfie', 7), ('flpol', 7), ('Trump', 4), ('CNN', 4), ('WikiLeaks', 2)]
# #################
# #################
# 65
# [('PodestaEmails9', 2), ('maga', 2), ('TrumpPence16', 1), ('brexit', 1), ('RapeCulture', 1)]
# #################
# #################
# 68
# [('Trump', 5), ('Clinton', 3), ('WikiLeaks', 3), ('Mxico', 2), ('Ficrea', 2)]
# #################
# #################
# 78
# [('Trump', 2), ('tinafey', 1), ('writingprompts', 1), ('Clinton', 1), ('dystopian', 1)]
# #################
# #################
# 79
# [('TulsiGabbard', 1), ('SHEEPLE', 1), ('100YearsStrong', 1), ('TrumpPence16', 1), ('election2016', 1)]
# #################
# #################
# 85
# [('AAP', 2), ('HindusForTrump', 2), ('ProudTrumpKakaFan', 1), ('LSElections', 1), ('Grabthembythe', 1)]
# #################
# #################
# 88
# [('Clinton', 2), ('Trump', 2), ('1A', 2), ('MakeSNLGreatAgain', 2), ('CNNSOTU', 2)]
# #################
# #################
# 90
# [('NarendraTrumpLIVE', 5), ('Breaking', 1), ('DonaldTrump', 1), ('Trump', 1), ('JustAsking', 1)]
# #################
# #################
# 93
# [('ImWithHer', 1971), ('TheTylerOakleyShow', 4), ('100YearsStrong', 4), ('debate', 4), ('debates2016', 1)]
# #################
# #################
# 101
# [('trump', 183), ('dumptrump', 106), ('debates', 106), ('IAmWithHer', 53), ('Ciao', 44)]
# #################
# #################
# 102
# [('Trump', 2), ('SundayMorning', 1), ('Fed', 1), ('Clinton', 1), ('SNL', 1)]
# #################
# #################
# 103
# [('EEUU', 1), ('Elecciones2016', 1), ('EncuestaDLA', 1), ('Trump', 1), ('MikePence', 1)]
# #################
# #################
# 106
# [('SundayMorning', 109), ('podestaemails9', 53), ('PodestaEmails8', 1), ('Foxnews', 1), ('ImWithHer', 1)]
# #################
# #################
# 107
# [('ImWithHer', 2), ('zerotoleranceforhate', 1), ('Clinton', 1), ('trump', 1), ('nevertrumptraitor', 1)]
# #################
# #################
# 110
# [('Trump', 22), ('NewHampshire', 2), ('MediasVendus', 2), ('Clinton', 1), ('DANGER', 1)]
# #################
# #################
# 111
# [('Trump', 4), ('India', 2), ('IndianElectio', 1), ('I', 1), ('ModisInnovativeDiplomacy', 1)]
# #################
# #################
# 112
# [('ImWithHer', 7), ('NopetoTrump', 6), ('SNL', 4), ('KenBone', 2), ('debates', 2)]
# #################
# #################
# 115
# [('News', 43), ('Election', 33), ('Politics', 33), ('Hillary', 9), ('Clinton', 2)]
# #################
# #################
# 121
# [('Trump', 5), ('popmusic', 2), ('rockmusic', 2), ('Forbes400', 2), ('KellyKatharin', 2)]
# #################
# #################
# 122
# [('Election2016', 247), ('PrisonStrike', 3), ('MakeAmericaRiotAgain', 1), ('ItsWorthAShot', 1), ('TrumpCheck', 1)]
# #################
# #################
# 123
# [('Reuters', 5), ('PrimeraPgina', 2), ('LockHerUp', 1), ('IMPEACHobama', 1), ('debate', 1)]
# #################
# #################
# 131
# [('BoycottPayPal', 6), ('HB2', 3), ('IceCreamConvos', 1), ('BoycottVenmo', 1), ('OITNB', 1)]
# #################
# #################
# 134
# [('Trump', 15), ('Election2016', 4), ('MostVotesWins', 2), ('Dems', 2), ('AssumeZip', 2)]
# #################
# #################
# 135
# [('SNL', 62), ('LEMONADE', 55), ('KenBone', 26), ('debates', 22), ('RealTime', 2)]
# #################
# #################
# 136
# [('TrumpGirls', 1), ('Trump', 1), ('FoxNews', 1), ('incest', 1), ('MakeAmericaGullibleAgain', 1)]
# #################
# #################
# 140
# [('QueNoSeTePase', 5), ('Video', 4), ('Sonora', 3), ('NoEsBroma', 2), ('Enterate', 1)]
# #################
# #################
# 144
# [('Trump', 5), ('Clinton', 3), ('SNL', 3), ('Election2016', 2), ('NoProp60', 2)]
# #################
# #################
# 145
# [('Election2016', 4), ('excuses', 1), ('tryingtosaveface', 1), ('poorloser', 1), ('100YearsStrong', 1)]
# #################
# #################
# 149
# [('Trump', 14), ('animals', 7), ('HillaryBecause', 6), ('wildlife', 4), ('WednesdayWisdom', 4)]
# #################
# #################
# 156
# [('AAP', 4), ('PbElections', 3), ('MPElections', 3), ('RajasthanElections', 3), ('KtkElections', 3)]
# #################
# #################
# 161
# [('Trump', 1), ('CrookedHillary', 1), ('Moldova', 1), ('Europea', 1), ('election', 1)]
# #################
# #################
# 165
# [('Decision2016', 2), ('TrumpCheck', 2), ('Election2016', 2), ('HouseOfCards', 1), ('YallneedGary', 1)]
# #################
# #################
# 171
# [('Trump', 2), ('p2', 1), ('Election2016', 1), ('Election', 1), ('ImWithHer', 1)]
# #################
# #################
# 178
# [('unityforfreedom', 11), ('unionforfreedom', 5), ('UnityForFreedom', 4), ('___', 4), ('_', 4)]
# #################
# #################
# 180
# [('EdBalls', 24), ('Strictly', 24), ('Trump', 9), ('c4news', 1), ('ChooChoo', 1)]
# #################
# #################
# 184
# [('GetWithTheReadingandLearning', 1), ('BirthOfANation', 1), ('PrisonStrike', 1), ('NateParker', 1), ('DWatkins', 1)]
# #################
# #################
# 189
# [('ImWithHer', 2), ('LadyGaga', 1), ('100YearsStrong', 1), ('ImwithHer', 1), ('lovethedrama', 1)]
# #################
# #################
# 195
# [('LaCasaBianca', 70), ('RaiUsa2016', 17), ('Trump', 16), ('Clinton', 11), ('Sanders', 7)]
# #################
# #################
# 208
# [('Republicans', 3), ('GOP', 3), ('NYT', 3), ('CIA', 2), ('cyber', 2)]
# #################
# #################
# 211
# [('Trump', 2), ('AKRoarsInGujarat', 2), ('whiteboymagic', 1), ('USA', 1), ('India', 1)]
# #################
# #################
# 213
# [('Trump', 4), ('SouthAsiansDumpTrump', 2), ('Modi', 2), ('SouthasiansDumpTrump', 2), ('Dalit', 1)]
# #################
# #################
# 216
# [('EuropeGoesUs', 19), ('Trump', 2), ('URGENTE', 1), ('CarolinaDelNorte', 1), ('Mundo', 1)]
# #################
# #################
# 221
# [('whiteboymagic', 18), ('trump', 3), ('fungshui', 3), ('election2016', 3), ('WhiteBoyMagic', 1)]
# #################
# #################
# 236
# [('Hitler', 3), ('Nazi', 3), ('Trump', 3), ('TerrifyingTrump', 1), ('SaturdayNightLive', 1)]
# #################
# #################
# 239
# [('Trump', 2), ('13h15', 1), ('Clinton', 1), ('USA', 1), ('Hollande', 1)]
# #################
# #################
# 242
# [('PanamaPapers', 1), ('wearehismedia', 1), ('JillNotHill', 1), ('NeverHillary', 1), ('Demexit', 1)]
# #################
# #################
# 246
# [('Russia', 16), ('Kuwait', 1), ('Montenegro', 1), ('CrookedHillary', 1), ('Trump', 1)]
# #################
# #################
# 260
# [('NoEsBroma', 1), ('WhyWomanDontReport', 1), ('TheSimpsons', 1), ('Columna', 1), ('RiseUpAsOne', 1)]
# #################
# #################
# 263
# [('ImWithHer', 2), ('NeverTrump', 1), ('TeamClinton', 1), ('FollowTheMoney', 1), ('Trump2016', 1)]
# #################
# #################
# 289
# [('Election2016', 19), ('Obama', 12), ('truth', 1), ('GetItOverWith', 1), ('election2016', 1)]
# #################
# #################
# 312
# [('SNL', 2), ('GCPR', 1), ('AP', 1), ('NEWS', 1), ('HEADLINES', 1)]
# #################
# #################
# 317
# [('ItWasEvenASong', 1), ('GameofThrones', 1), ('WomenCanStopTrump', 1), ('WasteHisTime2016', 1), ('NoBetterMelaniaThanBenanti', 1)]
# #################
# #################
# 325
# [('FUKUSHIMA', 2), ('TEPCO', 2), ('Fukushima', 1), ('trump', 1), ('tcot', 1)]
# #################
# #################
# 336
# [('EEUU', 56), ('Clinton', 4), ('Trump', 2), ('Pence', 1), ('MundoCurioso', 1)]
# #################
# #################
# 339
# [('Trump', 2), ('lifeofauggie', 1), ('Clinton', 1), ('selloutsanders', 1), ('Kansas', 1)]
# #################
# #################
# 340
# [('HillaryClinton', 1), ('ImWithHer', 1), ('LaganjaEstranja', 1), ('RPDR', 1), ('100YearsStrong', 1)]
# #################
# #################
# 345
# [('GoldmanSachs', 1), ('Trump', 1), ('CrookedHillary', 1), ('WikiLeaks', 1), ('MAGA', 1)]
# #################
# #################
# 350
# [('Clinton', 24), ('US', 14), ('WikiLeaks', 13), ('Chine', 3), ('Wikileaks', 3)]
# #################
# #################
# 352
# [('Chilcot', 1), ('isis', 1), ('trump', 1), ('TerrifyingTrump', 1), ('syria', 1)]
# #################
# #################
# 355
# [('Clinton', 2), ('USA', 2), ('ClintonFoundation', 2), ('Hillary', 2), ('Ethics', 2)]
# #################
# #################
# 364
# [('trump', 3), ('imwither', 3), ('podestaemails', 2), ('brexit', 1), ('NeverTrump', 1)]
# #################
# #################
# 379
# [('SNL', 1), ('TrumpCheck', 1), ('Debate', 1), ('Duncan4Witney', 1), ('unity', 1)]
# #################
# #################
# 415
# [('Trump', 1), ('PayPal', 1), ('LatinosWithTrump', 1), ('GaysforTrump', 1), ('Trump2016', 1)]
# #################
# #################
# 422
# [('millennial', 1), ('everyonesucks2016', 1), ('Periscope', 1), ('LatinosWithTrump', 1), ('MAGA3X', 1)]
# #################
# #################
# 432
# [('Sputnik', 3), ('feignant', 2), ('Clinton', 1), ('Trump', 1), ('Wilileaks', 1)]
# #################
# #################
# 434
# [('ACloserLookBack', 8), ('ACloserLook', 3), ('oxygen2016', 2), ('LNSM', 2), ('Trump', 1)]
# #################
# #################
# 442
# [('Trump', 50), ('VoteYourView', 3), ('mustread', 1), ('Clinton', 1), ('GaetaSusan', 1)]
# #################
# #################
# 446
# [('FOLLE', 12), ('Soros', 6), ('HitlaryClinton', 6), ('massona', 6), ('burattinaio', 6)]
# #################
# #################
# 447
# [('Farrakhan', 712), ('HDOA16', 678), ('Election2016', 173), ('Trump', 88), ('Hillary', 73)]
# #################
# #################
# 449
# [('Mundo', 3), ('EU', 2), ('EstadosUnidos', 1), ('Ficrea', 1), ('Mxico', 1)]
# #################
# #################
# 452
# [('Election2016', 6), ('99cents', 3), ('kindle', 3), ('Amazon', 3), ('RT', 3)]
# #################
# #################
# 454
# [('SNL', 1), ('PresidentialDebate', 1), ('NeverTrump', 1), ('WhyWomenDontReport', 1), ('100YearsStrong', 1)]
# #################
# #################
# 461
# [('Trump', 2), ('Elecciones2016', 2), ('MikePence', 2), ('EEUU', 2), ('EncuestaDLA', 1)]
# #################
# #################
# 476
# [('trending', 21), ('HB', 7), ('hacking', 5), ('cyber', 3), ('Trump', 2)]
# #################
# #################
# 478
# [('TrumpPence2016', 1), ('Trump', 1), ('USA', 1), ('MakeAmericaGreatAgain', 1), ('FACT', 1)]
# #################
# #################
# 484
# [('NuclearNightmare', 69), ('NorthKoreanKOOK', 69), ('DonTheThinSkinnedCON', 69), ('NeverTrump', 2), ('StarWars', 1)]
# #################
# #################
# 485
# [('Trump', 9), ('M5S', 5), ('Grillo', 5), ('Clinton', 4), ('Hillary', 4)]
# #################
# #################
# 491
# [('Hillary', 3), ('sondeos', 3), ('Tendencia', 3), ('Clinton', 1), ('Correos', 1)]
# #################
# #################
# 494
# [('ROIMentor', 5), ('videos', 2), ('funny', 2), ('vote2016', 2), ('yycwalks', 1)]
# #################
# #################
# 504
# [('ProLife', 2), ('abortion', 2), ('Trump', 1), ('WhiteMasculinitySoFragile', 1), ('NEWSWIRE', 1)]
# #################
# #################
# 517
# [('IsraeltheRegion', 2), ('Trump', 2), ('JewishTimes', 2), ('polls', 1), ('HillaryClinton', 1)]
# #################
# #################
# 531
# [('politics2016', 1), ('Clinton', 1), ('Trump', 1), ('Premonitions', 1), ('Revelations', 1)]
# #################
# #################
# 538
# [('Trump', 19), ('SundayTabloid', 19), ('newyork', 10), ('stutiuniti', 4), ('NewYork', 3)]
# #################
# #################
# 559
# [('Trump', 5), ('Clinton', 4), ('FOLLE', 2), ('HillaryClinton', 1), ('Corriere', 1)]
# #################
# #################
# 568
# [('Trump', 7), ('LeaveEU', 6), ('Vote', 1), ('Hillary', 1), ('Poll', 1)]
# #################
# #################
# 580
# [('NeverTrump', 2), ('WhinyLittleBitch', 2), ('sacrilegeSunday', 1), ('VetsAgainstTrump', 1), ('Election2016', 1)]
# #################
# #################
# 581
# [('WomenCanStopTrump', 73), ('benghazi', 1), ('FlyEaglesFly', 1), ('vote', 1), ('Eagles', 1)]
# #################
# #################
# 582
# [('Trump', 4), ('HinduAmericans', 4), ('Modi', 4), ('USA', 1), ('India', 1)]
# #################
# #################
# 586
# [('Trump', 24), ('MAGA', 24), ('CrookedHillary', 22), ('TrumpTrain', 3), ('TrumpPence16', 2)]
# #################
# #################
# 594
# [('RT', 19), ('OPININ', 9), ('RiseUpAsOne', 1), ('pasajerofeliz', 1), ('CrookedHillary', 1)]
# #################
# #################
# 595
# [('AFP', 30), ('Trump', 6), ('Hillary', 6), ('Wikileaks', 5), ('GoldmanSachs', 4)]
# #################
# #################
# 603
# [('CNCNet', 14), ('pjnet', 12), ('rednationrising', 6), ('ccot', 4), ('tcot', 4)]
# #################
# #################
# 610
# [('nevertrump', 7), ('trump', 7), ('CaptainAmerica', 7), ('art', 7), ('Election2016', 7)]
# #################
# #################
# 624
# [('Alinsky', 5), ('media', 5), ('Trump', 5), ('PodestaEmails9', 1), ('Voting4Trump', 1)]
# #################
# #################
# 630
# [('TrumpCheck', 2), ('Mentallyill', 1), ('Meltdown', 1), ('SNL', 1), ('OntheBlow', 1)]
# #################
# #################
# 645
# [('WitneyByElection', 2), ('PrisonStrike', 1), ('Trump', 1), ('Election2016', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 648
# [('ImZentrum', 5), ('Trump', 2), ('wasgehtbitte', 2), ('Pussygate', 1), ('imzentrum', 1)]
# #################
# #################
# 658
# [('Trump', 13), ('Sexismus', 3), ('wethepeople', 1), ('Clinton', 1), ('USA', 1)]
# #################
# #################
# 666
# [('clinton', 7), ('trump', 7), ('hilary', 7), ('vote', 2), ('president', 2)]
# #################
# #################
# 692
# [('FUCKDONALDTRUMP', 2), ('OnikaForPresident2k16', 2), ('HillaryClinton', 1), ('indyre2', 1), ('WomenStopTrumpParty', 1)]
# #################
# #################
# 703
# [('Eagles', 2), ('silverlining', 1), ('PHIvsWAS', 1), ('GrabThePussy', 1), ('Redskins', 1)]
# #################
# #################
# 704
# [('MAGA', 2), ('CrookedRottenShillaryForPrison2016', 1), ('LOCKHERUP', 1), ('Trump', 1), ('Election2016', 1)]
# #################
# #################
# 707
# [('Trump', 5), ('Clinton', 2), ('Elections2016', 2), ('polqc', 1), ('Jupp', 1)]
# #################
# #################
# 714
# [('Trump', 5), ('CarolinaDelNorte', 3), ('URGENTE', 3), ('EUA', 2), ('EU', 1)]
# #################
# #################
# 719
# [('polQc', 1), ('polqc', 1), ('polCan', 1), ('polUSA', 1), ('Trump', 1)]
# #################
# #################
# 736
# [('IG', 7), ('NEWS', 4), ('DAILY', 2), ('news', 2), ('FASHION', 1)]
# #################
# #################
# 739
# [('13h15', 3), ('Trump', 3), ('Hollande', 3), ('PrimaireLeDebat', 3), ('Trierweiler', 3)]
# #################
# #################
# 748
# [('MQMatGround', 1), ('Putin', 1), ('Trump', 1), ('Encryption', 1), ('Hillary', 1)]
# #################
# #################
# 751
# [('Election2016', 4), ('WomenCanStopTrump', 2), ('stopwhining', 1), ('ImWithHer', 1), ('Clarify', 1)]
# #################
# #################
# 753
# [('Syria', 7), ('Clinton', 5), ('Taliban', 3), ('rebels', 3), ('Emails', 2)]
# #################
# #################
# 774
# [('Trump', 1), ('SNL', 1), ('MartinLutherKing', 1), ('LGBT', 1), ('Debate', 1)]
# #################
# #################
# 777
# [('trump', 1), ('WhinyLittleBitch', 1), ('debates', 1), ('Election2016', 1), ('ImWithHer', 1)]
# #################
# #################
# 778
# [('Video', 5), ('Trump', 2), ('Clinton', 1), ('TheNewYorkTimes', 1), ('SaturdayNightLive', 1)]
# #################
# #################
# 804
# [('DonaldTrump', 6), ('Clinton', 3), ('Trump', 3), ('SundayMorning', 1), ('SNL', 1)]
# #################
# #################
# 809
# [('witney', 2), ('LabourLeadership', 1), ('Broadstone', 1), ('DOH', 1), ('Trump', 1)]
# #################
# #################
# 845
# [('boycottpaypal', 6), ('BoyCottPayPal', 2), ('BoycottPaypal', 2), ('BoycottPayPal', 2), ('Trump', 1)]
# #################
# #################
# 848
# [('G', 14), ('Wikileaks', 14), ('WRH', 12), ('GN', 9), ('AP', 6)]
# #################
# #################
# 894
# [('polqc', 1), ('HumaAbedin', 1), ('Clinton', 1), ('Hillary', 1), ('HillarysHuma', 1)]
# #################
# #################
# 924
# [('Sunday', 2), ('UnusualWords', 2), ('Trump', 2), ('XFactor', 2), ('Hillary', 1)]
# #################
# #################
# 970
# [('politics', 4), ('election', 3), ('Trump', 2), ('evangelical', 1), ('NOW', 1)]
# #################
# #################
# 986
# [('Farrakhan', 14), ('HDOA16', 14), ('HDOA', 14), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 1011
# [('Trump', 12), ('xenophobia', 12), ('Equality', 1), ('LGBT', 1), ('Politics', 1)]
# #################
# #################
# 1048
# [('Trump', 12), ('leadership', 2), ('lockerroom', 2), ('leaders', 1), ('integrity', 1)]
# #################
# #################
# 1069
# [('rochdale', 3), ('labour', 3), ('BNP', 2), ('salford', 1), ('middleton', 1)]
# #################
# #################
# 1106
# [('BoycottPayPal', 16), ('BoycottPaypal', 7), ('boycottpaypal', 3), ('PayPal', 2), ('SexualPredator', 1)]
# #################
# #################
# 1132
# [('TienesQueVerlo', 3), ('VIDEO', 2), ('MichelleObama', 1), ('Trump', 1), ('NACIN', 1)]
# #################
# #################
# 1135
# [('Trump', 5), ('Hillary', 4), ('nieuwsuur', 4), ('911Day', 3), ('Debates2016', 3)]
# #################
# #################
# 1160
# [('Debate', 2), ('LaughAtTrump', 1), ('SundayMorning', 1), ('hillarygropedme', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 1172
# [('clinton', 3), ('trump', 3), ('SEO', 3), ('ripple', 3), ('fintech', 3)]
# #################
# #################
# 1191
# [('auspol', 2), ('Trump', 1), ('USA', 1), ('financ', 1), ('politics', 1)]
# #################
# #################
# 1197
# [('clinton', 18), ('trump', 18), ('kenbone', 18), ('WikiLeaks', 1), ('jokes', 1)]
# #################
# #################
# 1205
# [('bluegrasslife', 3), ('bluegrass', 3), ('AlisonKrauss', 3), ('Clinton', 3), ('Trump', 3)]
# #################
# #################
# 1217
# [('auspol', 8), ('uspoli', 8), ('TrumpTrain', 8), ('Trump', 8), ('oops', 8)]
# #################
# #################
# 1244
# [('Brexit', 3), ('wato', 3), ('Tory', 3), ('c4news', 3), ('bbcdp', 3)]
# #################
# #################
# 1251
# [('Trump', 4), ('sondages', 2), ('Clinton', 2), ('USA', 2), ('Prsidentielle', 2)]
# #################
# #################
# 1269
# [('ImWithHer', 13), ('GameofThrones', 12), ('lovetrumpshate', 12), ('comics', 4), ('SNL', 1)]
# #################
# #################
# 1277
# [('Russian', 16), ('MindGames', 16), ('hacking', 16), ('Putin', 16), ('US', 16)]
# #################

# %%
user_to_cluster_retweet = {} 
with open('retweet_rm_clust.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        cluster_id = int(split_line[1])
        user_id = int(split_line[0])
        user_to_cluster_retweet[user_id] = cluster_id

# %%
counter_per_cluster_retweet = {}
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        if user_id not in user_to_cluster_retweet:
            continue
        hashtag = split_line[1]
        cluster_id = user_to_cluster_retweet[user_id]
        
        if cluster_id not in counter_per_cluster_retweet:
            counter_per_cluster_retweet[cluster_id] = Counter()
        counter_per_cluster_retweet[cluster_id][hashtag] += 1

# %%
# for retweet
for cluster in counter_per_cluster_retweet:
    most_common = counter_per_cluster_retweet[cluster].most_common(5)
    if len(most_common) < 5:
        continue
    print "#################"
    print cluster
    print most_common
    print "#################"
# Out:
# #################
# 0
# [('Trump', 4156), ('ImWithHer', 2003), ('NeverTrump', 1434), ('TrumpCheck', 1223), ('SNL', 1178)]
# #################
# #################
# 1
# [('Trump', 10961), ('MAGA', 8939), ('PodestaEmails9', 6745), ('Hillary', 3756), ('HillaryGropedMe', 3642)]
# #################
# #################
# 2
# [('Senado', 3), ('Trump', 3), ('SNL', 3), ('Election2016', 2), ('WallStreet', 2)]
# #################
# #################
# 3
# [('SNL', 10), ('whinylittlebitch', 6), ('Trump', 6), ('ImWithHer', 5), ('Election2016', 4)]
# #################
# #################
# 4
# [('CNNSOTU', 168), ('Trumpkin', 31), ('SNL', 6), ('100YearsStrong', 4), ('Trump', 4)]
# #################
# #################
# 8
# [('Trump', 6), ('RunMilaRun', 1), ('NeverTrump', 1), ('freespeech', 1), ('UnfitToLead', 1)]
# #################
# #################
# 13
# [('WomenWhoVoteTrump', 12), ('Lincoln', 1), ('WasteHisTime2016', 1), ('Trumpsays', 1), ('Reagan', 1)]
# #################
# #################
# 14
# [('GameofThrones', 2), ('lovetrumpshate', 2), ('ImWithHer', 2), ('100YearsStrong', 1), ('13TH', 1)]
# #################
# #################
# 16
# [('Election2016', 10), ('Trump', 4), ('100YearsStrong', 2), ('ImWithHer', 2), ('sorrynotsorry', 2)]
# #################
# #################
# 17
# [('Election2016', 3), ('democracy', 2), ('ImWithHer', 2), ('onassignment', 1), ('Trump', 1)]
# #################
# #################
# 18
# [('SNL', 3), ('insidejob', 1), ('LEMONADE', 1), ('100YearsStrong', 1), ('TrumpCheck', 1)]
# #################
# #################
# 19
# [('traitortrump', 5), ('treasonoustrump', 4), ('USElection', 3), ('grabthembythepussy', 3), ('gotojailtrump', 2)]
# #################
# #################
# 20
# [('SNL', 3), ('ChristianWomenPreach', 2), ('Trump', 2), ('Debate', 2), ('BreakingNews', 1)]
# #################
# #################
# 21
# [('Logic', 3), ('trumpgate', 3), ('NYTLetters', 3), ('Trump', 2), ('TrumpTV', 1)]
# #################
# #################
# 24
# [('Election2016', 16), ('boycottpaypal', 5), ('WomenStopTrumpParty', 3), ('HillaryClinton', 2), ('Iwillvote', 2)]
# #################
# #################
# 26
# [('HILLARY', 161), ('TRUMP', 153), ('CLINTON', 83), ('DRUGS', 69), ('AXELROD', 66)]
# #################
# #################
# 28
# [('trumpisapig', 2), ('Election2016', 2), ('FreetheFrog', 2), ('PodestaEmails', 2), ('CNNSOTU', 2)]
# #################
# #################
# 29
# [('Election2016', 265), ('PrisonStrike', 3), ('WomensLivesMatter', 1), ('WomansLivesMatter', 1), ('ElectionFun', 1)]
# #################
# #################
# 31
# [('Obama4Life', 2), ('Election2016', 2), ('FuckElection2k16', 1), ('WomenCanStopTrump', 1), ('LGBTQ', 1)]
# #################
# #################
# 34
# [('HILLARY2016', 3), ('TRUMP', 2), ('Hillary2016', 1), ('tcot', 1), ('FUNNY', 1)]
# #################
# #################
# 38
# [('Election2016', 4), ('ImWithHer', 2), ('p2', 1), ('NuclearNightmare', 1), ('SNL', 1)]
# #################
# #################
# 39
# [('Trump', 2), ('TrumpCheck', 2), ('totalblowoutcoming', 1), ('nevertrump', 1), ('disqualifying', 1)]
# #################
# #################
# 40
# [('socialjustice', 1), ('DinseeNuffin', 1), ('TrumpTapes', 1), ('sjw', 1), ('CaseyNeistat', 1)]
# #################
# #################
# 43
# [('Trump', 6), ('ImWithHer', 5), ('100YearsStrong', 4), ('NeverTrump', 3), ('ibelieveher', 2)]
# #################
# #################
# 46
# [('Election2016', 8), ('boycottPayPal', 1), ('BoycottPayPal', 1), ('13TH', 1), ('BLACKLIVESMATTER', 1)]
# #################
# #################
# 50
# [('TerrifyingTrump', 49), ('Trump', 6), ('TrumpSorrogates', 4), ('CNN', 4), ('SaturdayNightLive', 3)]
# #################
# #################
# 52
# [('Trump', 3), ('ProtectThe2nd', 2), ('Clarify', 2), ('TrumpCheck', 2), ('Election2016', 2)]
# #################
# #################
# 53
# [('Election2016', 3), ('AmericaFirst', 1), ('electionburnout', 1), ('SNL', 1), ('ImWithHer', 1)]
# #################
# #################
# 55
# [('KansasCrusaders', 23), ('WellActually', 23), ('Trump', 3), ('Clinton', 1), ('deplorable', 1)]
# #################
# #################
# 57
# [('ImWithHer', 3), ('boycottpaypal', 1), ('Breaking', 1), ('debates', 1), ('Election2016', 1)]
# #################
# #################
# 58
# [('Election2016', 5), ('Trump', 2), ('ImWithHer', 2), ('BoycottPaypal', 2), ('LGBTQS', 2)]
# #################
# #################
# 60
# [('ImWithHer', 3), ('Election2016', 3), ('chef', 1), ('nevertrump', 1), ('yourapig', 1)]
# #################
# #################
# 61
# [('debatenight', 2), ('TrumpSucks', 1), ('MikePence', 1), ('TrumpForPresident', 1), ('TrumpTrain', 1)]
# #################
# #################
# 62
# [('100YearsStrong', 1), ('Sociology', 1), ('DJT', 1), ('GHS', 1), ('alecbaldwin', 1)]
# #################
# #################
# 63
# [('Trump', 4), ('SundayMorning', 1), ('Clinton', 1), ('Corruptmedia', 1), ('tcot', 1)]
# #################
# #################
# 64
# [('Clinton', 75), ('Daesh', 7), ('Jupp', 6), ('Trump', 5), ('Montenegro', 3)]
# #################
# #################
# 76
# [('Election2016', 7), ('100YearsStrong', 1), ('WomenWhoVoteTrump', 1), ('ImWithHer', 1), ('hoax', 1)]
# #################
# #################
# 77
# [('WikiLeak', 37), ('HillaryGropeMe', 31), ('wikileaks', 22), ('HillaryGropedMe', 13), ('RiggedElection', 10)]
# #################
# #################
# 78
# [('PodestaEmails', 4), ('wikileaks', 4), ('HillaryClinton', 2), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 79
# [('sayfie', 13), ('flpol', 10), ('Trump', 5), ('CNN', 5), ('pfla', 3)]
# #################
# #################
# 83
# [('RapeCulture', 1), ('LoserDonald', 1), ('ShortEnd', 1), ('TrumpPence16', 1), ('GoldmanSach', 1)]
# #################
# #################
# 86
# [('Trump', 4), ('Clinton', 3), ('EEUU', 2), ('WikiLeaks', 2), ('Syria', 1)]
# #################
# #################
# 99
# [('carlzimmer', 2), ('potus', 2), ('tinafey', 1), ('groping', 1), ('democrazy', 1)]
# #################
# #################
# 100
# [('TrumpCheck', 2), ('LostInAmerica', 1), ('NeverTrump', 1), ('YesEveryWoman', 1), ('WasteHisTime2016', 1)]
# #################
# #################
# 104
# [('AAP', 2), ('LSElections', 1), ('Trump', 1), ('HindusForTrump', 1), ('WalterRobinson', 1)]
# #################
# #################
# 109
# [('NarendraTrumpLIVE', 4), ('Trump', 1), ('ProudTrumpKakaFan', 1), ('Breaking', 1), ('HindusForTrump', 1)]
# #################
# #################
# 112
# [('ImWithHer', 1970), ('100YearsStrong', 5), ('TheTylerOakleyShow', 4), ('debate', 4), ('HillaryGropedMe', 2)]
# #################
# #################
# 113
# [('trump', 4), ('HillaryGropedMe', 3), ('HillaryClinton', 2), ('debate', 2), ('ImWithHer', 2)]
# #################
# #################
# 115
# [('brexit', 1), ('trump', 1), ('SNL', 1), ('unity', 1), ('TrumpCheck', 1)]
# #################
# #################
# 116
# [('AmJoy', 1), ('debate', 1), ('Trump', 1), ('loser', 1), ('pig', 1)]
# #################
# #################
# 117
# [('TrumpTapes', 1), ('13thfilm', 1), ('TrumpCheck', 1), ('unfit', 1), ('debate', 1)]
# #################
# #################
# 127
# [('BoycottPaypal', 7), ('BoycottPayPal', 6), ('boycottpaypal', 4), ('Trump', 1), ('PayPal', 1)]
# #################
# #################
# 128
# [('trump', 184), ('dumptrump', 107), ('debates', 106), ('IAmWithHer', 54), ('Ciao', 45)]
# #################
# #################
# 130
# [('Trump', 2), ('HillaryClinton', 1), ('MikePence', 1), ('VoterSuppression', 1), ('HateSpeech', 1)]
# #################
# #################
# 134
# [('SundayMorning', 111), ('podestaemails9', 53), ('NoMercy', 1), ('gva', 1), ('TrumpBush2016', 1)]
# #################
# #################
# 138
# [('ImWithHer', 8), ('NopetoTrump', 7), ('Trump', 3), ('SNL', 3), ('dumptrump', 1)]
# #################
# #################
# 144
# [('News', 44), ('Election', 33), ('Politics', 33), ('Hillary', 9), ('Clinton', 2)]
# #################
# #################
# 152
# [('Trump', 4), ('popmusic', 2), ('KellyKatharin', 2), ('rockmusic', 2), ('CommonSense', 2)]
# #################
# #################
# 153
# [('Trump', 14), ('Election2016', 4), ('ImWithHer', 3), ('TrumpTapes', 3), ('MostVotesWins', 2)]
# #################
# #################
# 154
# [('Election2016', 3), ('Trump', 2), ('TrumpWhiner', 1), ('debates', 1), ('ICantEven', 1)]
# #################
# #################
# 157
# [('Election2016', 3), ('trump', 2), ('Trump', 2), ('scary', 1), ('climate', 1)]
# #################
# #################
# 162
# [('MeetThePress', 2), ('whiteboymagic', 1), ('DNC', 1), ('RapeCulture', 1), ('NeverHillary', 1)]
# #################
# #################
# 171
# [('BoycottPayPal', 7), ('HB2', 3), ('IceCreamConvos', 1), ('BoycottVenmo', 1), ('OITNB', 1)]
# #################
# #################
# 172
# [('SexualPredator', 1), ('NeverForget', 1), ('NeverTrump', 1), ('disaster', 1), ('whinyLittleBitch', 1)]
# #################
# #################
# 174
# [('TrumpGirls', 1), ('Trump', 1), ('FoxNews', 1), ('incest', 1), ('MakeAmericaGullibleAgain', 1)]
# #################
# #################
# 179
# [('MakeAmericaGreatAgain', 2), ('Election2016', 2), ('NeverTrump', 1), ('Trump', 1), ('notokay', 1)]
# #################
# #################
# 180
# [('QueNoSeTePase', 5), ('Video', 3), ('Sonora', 3), ('Enterate', 2), ('NoEsBroma', 2)]
# #################
# #################
# 183
# [('Election2016', 8), ('Trump', 2), ('NeverEverTrump', 1), ('BernieSanders', 1), ('election2016', 1)]
# #################
# #################
# 186
# [('DumpTrump', 46), ('Trump', 24), ('NeverTrump', 8), ('GOP', 8), ('RememberCecil', 4)]
# #################
# #################
# 188
# [('100YearsStrong', 4), ('NeverTrump', 3), ('NuclearNightmare', 3), ('dishonestdonald', 3), ('DonTheThinSkinnedCON', 3)]
# #################
# #################
# 189
# [('LGBT', 3), ('ImWithHer', 2), ('xenophobia', 1), ('racism', 1), ('misogeny', 1)]
# #################
# #################
# 190
# [('loser', 2), ('downinflames', 1), ('mentalhealthmatters', 1), ('antisocialpersonalitydisorder', 1), ('electionrigfail', 1)]
# #################
# #################
# 192
# [('Trump', 13), ('animals', 7), ('HillaryBecause', 6), ('wildlife', 4), ('WednesdayWisdom', 4)]
# #################
# #################
# 197
# [('NoOne', 3), ('SNL', 2), ('hypocrite', 1), ('NeverTrump', 1), ('debates', 1)]
# #################
# #################
# 200
# [('NoQuarter', 4), ('Libertarian', 4), ('EvenABlindGroperFindsANut', 3), ('LetGaryDebate', 2), ('Election2016', 2)]
# #################
# #################
# 201
# [('Election2016', 4), ('tryingtosaveface', 1), ('Murica', 1), ('Trump', 1), ('poorloser', 1)]
# #################
# #################
# 202
# [('AAP', 4), ('PbElections', 3), ('MPElections', 3), ('RajasthanElections', 3), ('KtkElections', 3)]
# #################
# #################
# 203
# [('loser', 2), ('UniteBlue', 1), ('deplorable', 1), ('FLASH', 1), ('BoycottPayPal', 1)]
# #################
# #################
# 206
# [('SNL', 73), ('Debate', 4), ('loser', 1), ('whiner', 1), ('MAGA', 1)]
# #################
# #################
# 210
# [('SNL', 31), ('PowerOfWomen', 8), ('LEMONADE', 1), ('TrumpCheck', 1), ('PowerofWomen', 1)]
# #################
# #################
# 213
# [('Election2016', 2), ('WasteHisTime2016', 1), ('ThinSkin', 1), ('SNL', 1), ('100YearsStrong', 1)]
# #################
# #################
# 216
# [('ImWithHer', 15), ('Independents', 9), ('Latinos', 9), ('Millennials', 9), ('BlackLivesMatter', 9)]
# #################
# #################
# 221
# [('Trump', 6), ('LindsayLohan', 3), ('ExclsiorTv', 1), ('Hillary', 1), ('NoEsBroma', 1)]
# #################
# #################
# 226
# [('EdBalls', 24), ('Strictly', 24), ('Trump', 6), ('c4news', 1), ('ChooChoo', 1)]
# #################
# #################
# 228
# [('Second', 3), ('trump', 1), ('uhoh', 1), ('second', 1), ('TIBA', 1)]
# #################
# #################
# 230
# [('FPU', 8), ('Breaking', 8), ('Clinton', 8), ('Trump', 8), ('Herald', 7)]
# #################
# #################
# 232
# [('SNL', 2), ('Market', 2), ('Clownpocalyse', 1), ('2ndAmendment', 1), ('standmyground', 1)]
# #################
# #################
# 233
# [('Trump', 1), ('USA', 1), ('Cuba', 1), ('EEUU', 1), ('Opinin', 1)]
# #################
# #################
# 234
# [('Election2016', 11), ('DonaldTrump', 8), ('Trump', 7), ('HillaryClinton', 4), ('Beyonce', 2)]
# #################
# #################
# 237
# [('RiseUpAsOne', 46), ('CrookedTrump', 1), ('Jerk', 1), ('PredatorTrump', 1), ('PiataTrump', 1)]
# #################
# #################
# 245
# [('unityforfreedom', 11), ('unionforfreedom', 5), ('UnityForFreedom', 4), ('___', 4), ('_', 4)]
# #################
# #################
# 249
# [('ImWithHer', 9), ('Election2016', 3), ('GoVote', 1), ('UniteBlue', 1), ('WrongAgainTrump', 1)]
# #################
# #################
# 257
# [('FYI', 3), ('FakeNews', 3), ('Trump', 1), ('Howard', 1), ('Stern', 1)]
# #################
# #################
# 271
# [('Republicans', 3), ('GOP', 3), ('NYT', 3), ('CIA', 2), ('cyber', 2)]
# #################
# #################
# 272
# [('SNL', 3), ('NeverTrump', 1), ('Trump', 1), ('LEMONADE', 1), ('WhyWomenDontReport', 1)]
# #################
# #################
# 276
# [('Trump', 11), ('SNL', 8), ('Clinton', 6), ('FranceInfo', 4), ('ClintonVsTrump', 2)]
# #################
# #################
# 281
# [('Trump', 3), ('SouthAsiansDumpTrump', 2), ('Modi', 2), ('SouthasiansDumpTrump', 2), ('Dalit', 1)]
# #################
# #################
# 288
# [('whiteboymagic', 19), ('trump', 3), ('fungshui', 3), ('election2016', 3), ('WhiteBoyMagic', 1)]
# #################
# #################
# 289
# [('HillaryClinton', 1), ('NeverTrump', 1), ('Trump', 1), ('ChooChoo', 1), ('100YearsStrong', 1)]
# #################
# #################
# 291
# [('Trump', 2), ('AKRoarsInGujarat', 2), ('whiteboymagic', 1), ('USA', 1), ('India', 1)]
# #################
# #################
# 297
# [('NeverTrump', 3), ('SNL', 2), ('PodestaEmails', 2), ('Election2016', 2), ('BDS', 1)]
# #################
# #################
# 301
# [('TrumpPence16', 1), ('MAGA', 1), ('TrumpTrain', 1), ('AmericaFirst', 1), ('Dobbs', 1)]
# #################
# #################
# 303
# [('vote', 2), ('Election2016', 2), ('McMullinFinn2016', 1), ('Derailed', 1), ('irony', 1)]
# #################
# #################
# 304
# [('ImWithHer', 10), ('repealthe19th', 1), ('LGBTQ', 1), ('Election2016', 1), ('Trump', 1)]
# #################
# #################
# 305
# [('Hitler', 3), ('Nazi', 3), ('Trump', 3), ('TerrifyingTrump', 1), ('SaturdayNightLive', 1)]
# #################
# #################
# 306
# [('49ers', 16), ('Bills', 16), ('DumpHillary', 1), ('TidalX1015', 1), ('DumpTrump', 1)]
# #################
# #################
# 309
# [('Trump', 3), ('13h15', 1), ('Clinton', 1), ('USA', 1), ('Hollande', 1)]
# #################
# #################
# 310
# [('Trump', 1), ('StopWhining', 1), ('SNL', 1), ('violence', 1), ('rigged', 1)]
# #################
# #################
# 313
# [('Drumpf', 5), ('Fukushima', 5), ('POTUS', 3), ('nuclear', 2), ('FUKUSHIMA', 1)]
# #################
# #################
# 315
# [('PanamaPapers', 1), ('wearehismedia', 1), ('JillNotHill', 1), ('NeverHillary', 1), ('Demexit', 1)]
# #################
# #################
# 316
# [('Syria', 9), ('Clinton', 6), ('Taliban', 4), ('rebels', 4), ('Emails', 2)]
# #################
# #################
# 317
# [('ClimateVoter', 9), ('TheChoicePBS', 1), ('Humor', 1), ('SNL', 1), ('ComedyRules', 1)]
# #################
# #################
# 320
# [('Election2016', 2), ('49ers', 1), ('Patriots', 1), ('ImWithHer', 1), ('Trump', 1)]
# #################
# #################
# 335
# [('USpoli', 1), ('TwitterHallOfFame', 1), ('Trump', 1), ('BabyHitler', 1), ('TimeMachine', 1)]
# #################
# #################
# 339
# [('NeverTrump', 2), ('SNL', 2), ('ImWithHer', 2), ('sniff', 1), ('Trump', 1)]
# #################
# #################
# 341
# [('Farrakhan', 717), ('HDOA16', 684), ('Election2016', 173), ('Trump', 88), ('Hillary', 73)]
# #################
# #################
# 356
# [('Evangelical', 1), ('PodestaEmails9', 1), ('YouIn', 1), ('TeamGov', 1), ('HillaryBecause', 1)]
# #################
# #################
# 373
# [('Trump', 17), ('USA', 1), ('ElectionPrsidentielle', 1), ('AFP', 1), ('US', 1)]
# #################
# #################
# 391
# [('Sputnik', 3), ('Clinton', 2), ('feignant', 2), ('Trump', 1), ('Wilileaks', 1)]
# #################
# #################
# 397
# [('scritturebrevi', 3), ('Debates', 3), ('Trump', 1), ('QueNoSeTePase', 1), ('Mxico', 1)]
# #################
# #################
# 398
# [('Clinton', 5), ('Trump', 4), ('us', 3), ('usa', 2), ('WSJ', 1)]
# #################
# #################
# 415
# [('Trump', 2), ('VoteTrumpPence16', 1), ('SNL', 1), ('ImWithHer', 1), ('VoteTrump', 1)]
# #################
# #################
# 419
# [('HillaryForPrison', 3), ('LockHerUp', 3), ('Turkey', 1), ('Qatar', 1), ('ISIS', 1)]
# #################
# #################
# 429
# [('SNL', 66), ('LEMONADE', 55), ('KenBone', 29), ('debates', 25), ('debate', 3)]
# #################
# #################
# 440
# [('AtHome', 5), ('benefits', 1), ('immigrants', 1), ('Roadto270', 1), ('LaCasaBianca', 1)]
# #################
# #################
# 444
# [('Latinos', 1), ('scarystuff', 1), ('HillaryBecause', 1), ('PodestaEmail7', 1), ('NeverHillary', 1)]
# #################
# #################
# 457
# [('Hacked', 6), ('Clinton', 4), ('hacked', 4), ('WikiLeaks', 4), ('Trump', 2)]
# #################
# #################
# 467
# [('TrumpTapes', 3), ('debates2016', 3), ('TrumpRape', 3), ('NeverTrump', 3), ('debate', 3)]
# #################
# #################
# 477
# [('Internacional', 2), ('HillaryClinton', 2), ('fotos', 1), ('AristeguiEnLibertad', 1), ('LibertadFILZocalo', 1)]
# #################
# #################
# 484
# [('Hillary', 3), ('CrookedHillary', 2), ('2016Election', 2), ('deplorable', 2), ('feelthebern', 1)]
# #################
# #################
# 487
# [('SNL', 1), ('Melanianade', 1), ('Debate', 1), ('WasteHisTime2016', 1), ('WomenCanStopTrump', 1)]
# #################
# #################
# 489
# [('PrisonStrike', 65), ('America', 1), ('MAGA', 1), ('NiTrumpNiHillary', 1), ('Trump', 1)]
# #################
# #################
# 520
# [('insane', 1), ('Prospective', 1), ('crazy', 1), ('From', 1), ('Trump', 1)]
# #################
# #################
# 522
# [('trump', 1), ('SNL', 1), ('tidalx1015', 1), ('100YearsStrong', 1), ('MuteTrump', 1)]
# #################
# #################
# 529
# [('Fed', 1), ('Clinton', 1), ('Trump', 1), ('lastword', 1), ('SNL', 1)]
# #################
# #################
# 533
# [('FOLLE', 2), ('clinton', 1), ('burattinaio', 1), ('TerzaGuerraMondiale', 1), ('Soros', 1)]
# #################
# #################
# 537
# [('Election2016', 7), ('RT', 4), ('99cents', 4), ('Amazon', 4), ('kindle', 4)]
# #################
# #################
# 549
# [('Trump', 3), ('Hillary', 2), ('CNNSOTU', 2), ('HailTrump', 1), ('CNNRealityCheck', 1)]
# #################
# #################
# 556
# [('networks', 18), ('marketing', 13), ('news', 11), ('business', 10), ('social', 10)]
# #################
# #################
# 558
# [('TRUMP', 2), ('HILLARY', 2), ('SundayMorning', 1), ('Clinton', 1), ('NovaScotia411', 1)]
# #################
# #################
# 568
# [('trending', 21), ('HB', 7), ('hacking', 5), ('cyber', 3), ('Trump', 2)]
# #################
# #################
# 569
# [('HillaryClinton', 1), ('ImWithHer', 1), ('LaganjaEstranja', 1), ('RPDR', 1), ('100YearsStrong', 1)]
# #################
# #################
# 577
# [('Trump', 11), ('Clinton', 6), ('M5S', 5), ('Hillary', 5), ('Grillo', 5)]
# #################
# #################
# 587
# [('ROIMentor', 5), ('politics', 4), ('DonaldTrump', 3), ('videos', 2), ('funny', 2)]
# #################
# #################
# 601
# [('WTF', 11), ('wtf', 7), ('CollegeStudents', 5), ('Millennials', 5), ('Progressives', 5)]
# #################
# #################
# 607
# [('LGBTQ', 9), ('ClintonFoundationRocks', 9), ('NeverTrump', 4), ('Trump', 1), ('ImWithHer', 1)]
# #################
# #################
# 608
# [('GaryJohnson', 10), ('libertarian', 5), ('JohnsonWeld', 4), ('LetGaryDebate', 4), ('JohnsonWeld2016', 2)]
# #################
# #################
# 646
# [('SNL', 31), ('Trump', 26), ('Clinton', 6), ('Debate', 5), ('concession', 1)]
# #################
# #################
# 652
# [('Trump', 12), ('HesCountingTheSecondsTilItsOver', 1), ('ZEERO', 1), ('Oops', 1), ('maga', 1)]
# #################
# #################
# 667
# [('Trump', 20), ('Clinton', 10), ('USA', 6), ('sondages', 3), ('Prsidentielle', 2)]
# #################
# #################
# 670
# [('Trump', 5), ('HinduAmericans', 5), ('Modi', 5), ('USA', 1), ('India', 1)]
# #################
# #################
# 671
# [('ACloserLookBack', 9), ('ACloserLook', 3), ('Ohio', 1), ('Trump', 1), ('LNSM', 1)]
# #################
# #################
# 673
# [('Trump', 2), ('Clinton', 1), ('sakpol', 1), ('Moldova', 1), ('Pence', 1)]
# #################
# #################
# 676
# [('Trump', 26), ('MAGA', 26), ('CrookedHillary', 23), ('TrumpPence16', 3), ('TrumpTrain', 3)]
# #################
# #################
# 685
# [('notinmyname', 2), ('TerrifyingTrump', 2), ('witney', 2), ('remain', 2), ('LabourLeadership', 1)]
# #################
# #################
# 688
# [('NuclearNightmare', 71), ('NorthKoreanKOOK', 71), ('DonTheThinSkinnedCON', 71), ('NeverTrump', 2), ('StarWars', 1)]
# #################
# #################
# 695
# [('Trump', 13), ('Sexismus', 3), ('wethepeople', 1), ('Clinton', 1), ('USA', 1)]
# #################
# #################
# 697
# [('Trump', 19), ('SundayTabloid', 19), ('newyork', 10), ('stutiuniti', 4), ('NewYork', 3)]
# #################
# #################
# 700
# [('Election', 3), ('Election2016', 2), ('Evangelical', 1), ('clinton', 1), ('trump', 1)]
# #################
# #################
# 701
# [('277Days', 26), ('sexcrimes', 10), ('MartinsvilleSexCrimes', 7), ('RNCinCLE', 3), ('Trump', 3)]
# #################
# #################
# 713
# [('Alinsky', 5), ('media', 5), ('Trump', 5), ('PodestaEmails9', 1), ('Voting4Trump', 1)]
# #################
# #################
# 718
# [('NeverTrump', 2), ('WhinyLittleBitch', 2), ('sacrilegeSunday', 1), ('VetsAgainstTrump', 1), ('Election2016', 1)]
# #################
# #################
# 721
# [('SNL', 13), ('FactCheck', 13), ('MAGA', 13), ('TeamTrump', 1), ('Debates2016', 1)]
# #################
# #################
# 753
# [('clinton', 7), ('trump', 7), ('hilary', 7), ('vote', 2), ('president', 2)]
# #################
# #################
# 762
# [('p2', 1), ('tcot', 1), ('bansatire', 1), ('ImWithHer', 1), ('ChooChoo', 1)]
# #################
# #################
# 780
# [('IG', 8), ('NEWS', 4), ('FASHION', 2), ('DAILY', 2), ('TRENDS', 2)]
# #################
# #################
# 782
# [('TrumpPence16', 2), ('TrumpTrain', 2), ('MAGA', 2), ('CleanYourMuteList', 2), ('Trump', 2)]
# #################
# #################
# 784
# [('NYC', 1), ('SNL', 1), ('Trump', 1), ('SaturdayNightLive', 1), ('DonaldTrump', 1)]
# #################
# #################
# 787
# [('News', 8), ('Campaign', 7), ('Trump', 4), ('Presidential', 4), ('Clinton', 2)]
# #################
# #################
# 791
# [('EEUU', 1), ('Elecciones2016', 1), ('EncuestaDLA', 1), ('Trump', 1), ('MikePence', 1)]
# #################
# #################
# 806
# [('Trump', 5), ('CarolinaDelNorte', 3), ('URGENTE', 3), ('EUA', 2), ('EU', 1)]
# #################
# #################
# 810
# [('Trump', 14), ('Clinton', 7), ('DonVoyage', 6), ('POTUS', 5), ('WomenForTrump', 3)]
# #################
# #################
# 831
# [('FestivalPeople', 13), ('BullshitArtists', 2), ('Trump', 2), ('MediaMatters', 2), ('CNN', 2)]
# #################
# #################
# 833
# [('RT', 1), ('FlashAlert', 1), ('Trump', 1), ('Registered', 1), ('State', 1)]
# #################
# #################
# 836
# [('CNCNet', 15), ('pjnet', 13), ('rednationrising', 7), ('ccot', 4), ('tcot', 4)]
# #################
# #################
# 855
# [('journalistes', 7), ('Trump', 4), ('Brady', 2), ('NFL', 2), ('EuropeGoesUS', 2)]
# #################
# #################
# 860
# [('MartinLutherKing', 1), ('Trump', 1), ('LGBT', 1), ('SNL', 1), ('Sexist', 1)]
# #################
# #################
# 863
# [('Video', 6), ('Trump', 3), ('SaturdayNightLive', 2), ('Clinton', 1), ('TheNewYorkTimes', 1)]
# #################
# #################
# 869
# [('AFP', 9), ('Trump', 5), ('Hillary', 5), ('Wikileaks', 5), ('GoldmanSachs', 4)]
# #################
# #################
# 870
# [('Clinton', 3), ('Trump', 3), ('FOLLE', 2), ('Usa2016', 2), ('HillaryClinton', 1)]
# #################
# #################
# 873
# [('WomenCanStopTrump', 72), ('MySignatureScent', 3), ('ThingsTrumpClaimsRigged', 2), ('Election2016', 2), ('FlyEaglesFly', 1)]
# #################
# #################
# 894
# [('boycottpaypal', 128), ('BoycottPayPal', 8), ('Election2016', 4), ('debates2016', 1), ('SexualPredator', 1)]
# #################
# #################
# 907
# [('Russia', 14), ('CrookedHillary', 1), ('debates', 1), ('tcot', 1), ('Kuwait', 1)]
# #################
# #################
# 911
# [('Clinton', 19), ('US', 15), ('WikiLeaks', 15), ('Chine', 2), ('Wikileaks', 2)]
# #################
# #################
# 944
# [('PrisonStrike', 9), ('PT', 1), ('PodestaEmails9', 1), ('elections', 1), ('GoogleGaryJohnson', 1)]
# #################
# #################
# 949
# [('LaCasaBianca', 34), ('Trump', 12), ('RaiUsa2016', 7), ('Sanders', 6), ('Clinton', 5)]
# #################
# #################
# 970
# [('MTP', 2), ('ImWithHer', 2), ('PodestaEmails8', 1), ('ThisWeek', 1), ('BasementDwellers', 1)]
# #################
# #################
# 983
# [('msnbc', 10), ('MSNBC', 6), ('cnn', 3), ('AMJoy', 1), ('takedownthedonald', 1)]
# #################
# #################
# 993
# [('NoProp60', 10), ('Election2016', 9), ('California', 7), ('Vote', 2), ('Prop60', 1)]
# #################
# #################
# 996
# [('Hillary', 4), ('OITNB', 2), ('polqc', 1), ('Clinton', 1), ('HumaAbedin', 1)]
# #################
# #################
# 998
# [('Latinos', 1), ('Clinton', 1), ('HumaAbedin', 1), ('HillaryBecause', 1), ('Hillary', 1)]
# #################
# #################
# 1000
# [('Trump', 2), ('HillaryClinton', 1), ('hillarymob', 1), ('CrookedHIllary', 1), ('mediabias', 1)]
# #################
# #################
# 1005
# [('PodestaEmails9', 1), ('neverhillary', 1), ('SaveAmyGoodman', 1), ('HILLNO', 1), ('NeverHillary', 1)]
# #################
# #################
# 1024
# [('Trump', 50), ('Hillary', 43), ('Libertarian', 41), ('HillaryClinton', 7), ('Evangelical', 2)]
# #################
# #################
# 1042
# [('Election2016', 4), ('WomenCanStopTrump', 2), ('Clinton', 1), ('stopwhining', 1), ('tax', 1)]
# #################
# #################
# 1057
# [('ImWithHillary', 1), ('HillaryClinton', 1), ('NarcissistTrump', 1), ('scared', 1), ('TurnUSABlue', 1)]
# #################
# #################
# 1063
# [('bospoli', 3), ('Clinton', 2), ('dnc', 2), ('dncc', 2), ('Hitler', 2)]
# #################
# #################
# 1080
# [('FOLLE', 10), ('burattinaio', 5), ('Soros', 5), ('HitlaryClinton', 5), ('massona', 5)]
# #################
# #################
# 1095
# [('trumpismplusinmypants', 1), ('twitter', 1), ('trump', 1), ('Election2016', 1), ('DonaldTrump', 1)]
# #################
# #################
# 1098
# [('Trump', 8), ('Brexit', 5), ('TrumpWatch', 1), ('debatenight2016', 1), ('satire', 1)]
# #################
# #################
# 1106
# [('Farrakhan', 15), ('HDOA16', 15), ('HDOA', 15), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 1114
# [('Utah', 9), ('Trump', 9), ('USElection', 5), ('Clinton', 4), ('SNL', 1)]
# #################
# #################
# 1129
# [('polQc', 1), ('polqc', 1), ('polCan', 1), ('polUSA', 1), ('Trump', 1)]
# #################
# #################
# 1131
# [('Trump', 13), ('xenophobia', 13), ('WitneyByElection', 3), ('DwyforMeirionnydd', 1), ('Equality', 1)]
# #################
# #################
# 1132
# [('misogyny', 1), ('journalism', 1), ('WomensRights', 1), ('fascism', 1), ('hacking', 1)]
# #################
# #################
# 1144
# [('tinyhands', 1), ('IsraelNews', 1), ('CounterStrikeGlobalOffensive', 1), ('triggered', 1), ('fuckdrumpf', 1)]
# #################
# #################
# 1177
# [('Trump', 12), ('leadership', 2), ('lockerroom', 2), ('leaders', 1), ('integrity', 1)]
# #################
# #################
# 1201
# [('rochdale', 3), ('labour', 3), ('BNP', 2), ('salford', 1), ('middleton', 1)]
# #################
# #################
# 1202
# [('hillaryclinton', 4), ('ilikeher', 3), ('imwithher', 3), ('hillary', 3), ('maga3x', 2)]
# #################
# #################
# 1233
# [('DumpTrump', 2), ('dumpTrump', 2), ('HillaryGropedMe', 2), ('pervert', 1), ('dirtyoldman', 1)]
# #################
# #################
# 1236
# [('Trump', 22), ('Hillary', 8), ('Election2016', 5), ('Fox', 4), ('Decision2016', 4)]
# #################
# #################
# 1242
# [('BoycottPayPal', 16), ('BoycottPaypal', 2), ('NeverTrump', 1), ('LGBT', 1), ('PayPal', 1)]
# #################
# #################
# 1249
# [('13h15', 3), ('Trump', 3), ('Hollande', 3), ('PrimaireLeDebat', 3), ('Trierweiler', 3)]
# #################
# #################
# 1260
# [('WarrenBuffett', 16), ('HillaryClinton', 6), ('DonaldTrump', 3), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 1261
# [('Trump', 2), ('Beyonce', 2), ('Melania', 2), ('CNN', 2), ('BBCNews', 1)]
# #################
# #################
# 1274
# [('LaCasaBianca', 13), ('RaiUsa2016', 8), ('ObamaCare', 2), ('LGBTQ', 1), ('Trump', 1)]
# #################
# #################
# 1281
# [('TienesQueVerlo', 3), ('VIDEO', 2), ('MichelleObama', 1), ('Trump', 1), ('NACIN', 1)]
# #################
# #################
# 1285
# [('Trump', 2), ('TheAccountant', 1), ('PodestaEmails9', 1), ('ImWithHer', 1), ('mepolitics', 1)]
# #################
# #################
# 1295
# [('nevertrump', 7), ('trump', 7), ('CaptainAmerica', 7), ('art', 7), ('Election2016', 7)]
# #################
# #################
# 1331
# [('trump', 3), ('imwither', 3), ('Trump2016', 1), ('NeverTrump', 1), ('dnc', 1)]
# #################
# #################
# 1358
# [('Trump', 7), ('LeaveEU', 6), ('Vote', 1), ('Hillary', 1), ('Poll', 1)]
# #################
# #################
# 1363
# [('EEUU', 5), ('Clinton', 4), ('Rusia', 1), ('Pence', 1), ('Trump', 1)]
# #################
# #################
# 1364
# [('auspol', 2), ('Trump', 1), ('USA', 1), ('financ', 1), ('politics', 1)]
# #################
# #################
# 1365
# [('Trump', 3), ('Economy', 2), ('HillaryClinton', 1), ('Clinton', 1), ('tcot', 1)]
# #################
# #################
# 1372
# [('clinton', 18), ('trump', 18), ('kenbone', 18), ('WikiLeaks', 1), ('jokes', 1)]
# #################
# #################
# 1376
# [('Hillary', 2), ('sondeos', 2), ('Tendencia', 2), ('Clinton', 1), ('Correos', 1)]
# #################
# #################
# 1379
# [('Ohio', 1), ('Georgia', 1), ('Arizona', 1), ('Iowa', 1), ('Nevada', 1)]
# #################
# #################
# 1381
# [('bluegrasslife', 3), ('bluegrass', 3), ('AlisonKrauss', 3), ('Clinton', 3), ('Trump', 3)]
# #################
# #################
# 1385
# [('boycottpaypal', 5), ('Trump', 4), ('paypal', 4), ('Paypal', 4), ('PayPal', 2)]
# #################
# #################
# 1390
# [('auspol', 8), ('uspoli', 8), ('TrumpTrain', 8), ('Trump', 8), ('oops', 8)]
# #################
# #################
# 1422
# [('ToriesDoLie', 6), ('Brexit', 3), ('wato', 3), ('Tory', 3), ('c4news', 3)]
# #################
# #################
# 1428
# [('SaudiArabia', 1), ('MadamPresident', 1), ('ImWithHer', 1), ('palin', 1), ('UAE', 1)]
# #################
# #################
# 1433
# [('fascist', 2), ('stockholmsyndrome', 1), ('sniff', 1), ('worldwatches', 1), ('auspol', 1)]
# #################
# #################
# 1463
# [('Trump', 5), ('Hillary', 4), ('911Day', 3), ('Debates2016', 3), ('MichelleObama', 3)]
# #################
# #################
# 1475
# [('Russian', 16), ('MindGames', 16), ('hacking', 16), ('Putin', 16), ('US', 16)]
# #################
# #################
# 1492
# [('Clinton', 3), ('gendergap', 2), ('Trump', 2), ('womenandwork', 2), ('race', 2)]
# #################
# #################
# 1503
# [('TakeTheMoney', 11), ('TaketheMoney', 5), ('AdmissionOfGuilt', 2), ('WomenForTrump', 2), ('PodestaForPrison', 2)]
# #################
# #################
# 1541
# [('trumppence16', 3), ('DonaldTrump', 3), ('Sacramento', 1), ('MyHappyPlace', 1), ('politics', 1)]
# #################

# %%
ls
# Out:
# PLaw.ipynb                     replies_rm_clust.txt
# PopHashtags.ipynb              replies_rm_lelp_analysis.txt
# hashtags.txt                   replies_rm_lelp_clust.txt
# mentions.txt                   replies_rm_lelp_network.png
# mentions_analysis.txt          replies_rm_lelp_randhist.png
# mentions_clust.txt             replies_rm_network.png
# mentions_randhist.png          replies_rm_randhist.png
# mentions_rm_analysis.txt       retweet.txt
# mentions_rm_clust.txt          retweet_analysis.txt
# mentions_rm_lelp.png           retweet_clust.txt
# mentions_rm_lelp_analysis.txt  retweet_randhist.png
# mentions_rm_lelp_clust.txt     retweet_rm_analysis.txt
# mentions_rm_lelp_randhist.png  retweet_rm_clust.txt
# mentions_rm_network.png        retweet_rm_lelp_analysis.txt
# mentions_rm_randhist.png       retweet_rm_lelp_clust.txt
# replies.txt                    retweet_rm_lelp_network.png
# replies_analysis.txt           retweet_rm_lelp_randhist.png
# replies_clust.txt              retweet_rm_network.png
# replies_randhist.png           retweet_rm_randhist.png
# replies_rm_analysis.txt        users_w_tweets.txt*

# %%
user_to_cluster_replies = {} 
with open('replies_rm_clust.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        cluster_id = int(split_line[1])
        user_id = int(split_line[0])
        user_to_cluster_replies[user_id] = cluster_id

# %%
counter_per_cluster_replies = {}
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        
        if user_id not in user_to_cluster_replies:
            continue
        
        hashtag = split_line[1]
        cluster_id = user_to_cluster_replies[user_id]
        
        if cluster_id not in counter_per_cluster_replies:
            counter_per_cluster_replies[cluster_id] = Counter()
        counter_per_cluster_replies[cluster_id][hashtag] += 1

# %%
# for replies
for cluster in counter_per_cluster_replies:
    most_common = counter_per_cluster_replies[cluster].most_common(5)
    if len(most_common) < 5:
        continue
    print "#################"
    print cluster
    print most_common
    print "#################"
# Out:
# #################
# 0
# [('Trump', 23), ('PodestaEmails9', 8), ('PodestaEmails', 7), ('Hillary', 7), ('ImWithHer', 7)]
# #################
# #################
# 1
# [('Trump', 2406), ('MAGA', 1768), ('PodestaEmails9', 950), ('HillaryGropedMe', 631), ('TrumpPence16', 625)]
# #################
# #################
# 2
# [('Trump', 6), ('natashastoynoff', 2), ('Brexit', 1), ('cpc', 1), ('DumbAmerica', 1)]
# #################
# #################
# 3
# [('Trump', 3), ('SNL', 3), ('ImWithHer', 2), ('insidepolitics', 1), ('DumpTrump', 1)]
# #################
# #################
# 4
# [('Trump', 486), ('MAGA', 409), ('PodestaEmails9', 278), ('trump', 236), ('Hillary', 158)]
# #################
# #################
# 6
# [('Trump', 12), ('MAGA', 9), ('PodestaEmails9', 9), ('PodestaEmails', 7), ('TrumpPence16', 6)]
# #################
# #################
# 7
# [('Trump', 28), ('trump', 20), ('ImWithHer', 16), ('PodestaEmails9', 15), ('MAGA', 13)]
# #################
# #################
# 8
# [('Trump', 4), ('HillaryGropedMe', 3), ('KenStarr', 2), ('McCarthyism', 2), ('TrumpTrain', 2)]
# #################
# #################
# 9
# [('Trump', 27), ('HillaryGropedMe', 24), ('MAGA', 16), ('SundayMorning', 7), ('TRUMP', 6)]
# #################
# #################
# 10
# [('MAGA', 2), ('HillaryClinton', 1), ('ISIS', 1), ('TrumpPence16', 1), ('HillaryBecause', 1)]
# #################
# #################
# 11
# [('Trump', 26), ('RiggedSystem', 11), ('MAGA', 8), ('Demexit', 8), ('Wikileaks', 7)]
# #################
# #################
# 12
# [('Trump', 2), ('SNL', 2), ('TiSA', 1), ('ChrisWallace', 1), ('BLM', 1)]
# #################
# #################
# 13
# [('Vote', 5), ('BillClinton', 4), ('FaceTheNation', 4), ('Election2016', 3), ('MeetThePress', 3)]
# #################
# #################
# 14
# [('Trump', 2), ('p2', 1), ('tcot', 1), ('theonlyadult', 1), ('EstoyConElla', 1)]
# #################
# #################
# 15
# [('PodestaEmails9', 11), ('Trump', 9), ('NeverHillary', 6), ('Wikileaks', 5), ('MAGA', 4)]
# #################
# #################
# 16
# [('PodestaEmails9', 21), ('MAGA', 14), ('HillaryGropedMe', 10), ('PodestaEmails', 8), ('Trump', 8)]
# #################
# #################
# 18
# [('Trump', 81), ('PodestaEmails9', 78), ('MAGA', 58), ('PodestaEmails', 50), ('CorruptMedia', 37)]
# #################
# #################
# 19
# [('WikiLeaks', 5), ('nevertrump', 4), ('TrumpTrain', 4), ('Trump', 3), ('Wikileaks', 2)]
# #################
# #################
# 21
# [('HillaryClinton', 1), ('ISIS', 1), ('Libya', 1), ('Justice', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 22
# [('p2', 11), ('tcot', 10), ('Trump', 8), ('Election2016', 5), ('NeverTrump', 5)]
# #################
# #################
# 24
# [('Trump', 3), ('WorseThanWeEvenThought', 1), ('lies', 1), ('ModernGOP', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 25
# [('Trump', 3), ('MAGA', 3), ('TrumpTapes', 1), ('McMullinFin', 1), ('JamesWoods', 1)]
# #################
# #################
# 26
# [('Trump', 3), ('TrumpCheck', 1), ('hillaryshills', 1), ('trolls', 1), ('innercity', 1)]
# #################
# #################
# 27
# [('PodestaEmails9', 2), ('Uber', 1), ('USA', 1), ('WomenWhoVoteTrump', 1), ('Apple', 1)]
# #################
# #################
# 28
# [('Trump', 11), ('Modi', 2), ('jihad', 1), ('beef', 1), ('PodestaEmails', 1)]
# #################
# #################
# 29
# [('MAGA', 5), ('TRUMP', 5), ('Trump', 5), ('Hillary', 3), ('NeverHillary', 3)]
# #################
# #################
# 30
# [('Trump', 4), ('LockHimUp', 1), ('Clinton', 1), ('CorruptMedia', 1), ('CrookedHillary', 1)]
# #################
# #################
# 31
# [('Trump', 27), ('TrumpPence16', 7), ('trump', 6), ('HillaryGropedMe', 5), ('ImWithHer', 5)]
# #################
# #################
# 34
# [('PodestaEmails', 3), ('HillaryClinton', 1), ('Trump', 1), ('Snap_Politics', 1), ('MAGA', 1)]
# #################
# #################
# 35
# [('SundayMorning', 6), ('Trump', 3), ('SNL', 1), ('NeverHillary', 1), ('NastyNikki', 1)]
# #################
# #################
# 36
# [('Clinton', 1), ('MAGA3X', 1), ('TCOT', 1), ('HumaAbedin', 1), ('ImWithHer', 1)]
# #################
# #################
# 37
# [('Hillary2016', 6), ('VoteBlue', 6), ('ImWithHer', 5), ('HillYes', 5), ('HFA', 4)]
# #################
# #################
# 39
# [('PodestaEmails9', 2), ('ImWithHer', 2), ('DNCLeaks', 2), ('TrumpEffect', 1), ('SundayMorning', 1)]
# #################
# #################
# 41
# [('Trump', 29), ('MAGA', 20), ('PodestaEmails9', 11), ('Hillary', 9), ('SundayMorning', 8)]
# #################
# #################
# 43
# [('NeverTrump', 2), ('MeetThePress', 2), ('HILLARYCLINTON', 1), ('JoeBiden', 1), ('WearRED', 1)]
# #################
# #################
# 44
# [('Trump', 164), ('MAGA', 114), ('PodestaEmails9', 86), ('TrumpPence16', 52), ('Hillary', 50)]
# #################
# #################
# 45
# [('Trump', 11), ('PodestaEmails9', 9), ('MAGA', 8), ('SundayMorning', 7), ('HillaryBecause', 4)]
# #################
# #################
# 47
# [('Wikileaks', 2), ('TeamTrump', 1), ('SundayMorning', 1), ('AmericaFirst', 1), ('Clinton', 1)]
# #################
# #################
# 48
# [('Trump', 5), ('Lies', 2), ('Hillary', 2), ('SundayMorning', 1), ('Debates2016', 1)]
# #################
# #################
# 49
# [('Trump', 5), ('1U', 2), ('NeverTrump', 2), ('ImWithHer', 2), ('HillaryGropedMe', 2)]
# #################
# #################
# 50
# [('Trump', 12), ('trump', 3), ('MAGA', 3), ('TrumpPence16', 2), ('tcot', 2)]
# #################
# #################
# 51
# [('ImWithHer', 2), ('p2', 1), ('HillaryClinton', 1), ('ShesWithUs', 1), ('EFFSC', 1)]
# #################
# #################
# 52
# [('Trump', 17), ('HillaryGropedMe', 7), ('Hillary', 6), ('Michigan', 5), ('Texas', 5)]
# #################
# #################
# 53
# [('MAGA', 21), ('Trump', 15), ('NeverHillary', 14), ('HillaryGropedMe', 10), ('CrookedHillary', 10)]
# #################
# #################
# 54
# [('TruePundit', 4), ('Clinton', 3), ('ResignDonna', 2), ('ClintonCash', 2), ('COpolitics', 2)]
# #################
# #################
# 55
# [('ImWithHer', 7), ('StrongerTogether', 6), ('AfricanAmericans', 2), ('BLM', 2), ('HillaryGropedMe', 2)]
# #################
# #################
# 56
# [('Trump', 7), ('p2', 6), ('ctl', 6), ('ImWithHer', 3), ('RT', 2)]
# #################
# #################
# 57
# [('ShesWithUs', 1), ('podestaemails6', 1), ('irony', 1), ('DC', 1), ('WhinyDiaperBaby', 1)]
# #################
# #################
# 59
# [('Trump', 7), ('Hillary', 5), ('SundayMorning', 4), ('Trump2016', 3), ('debate', 3)]
# #################
# #################
# 60
# [('MAGA3X', 2), ('SundayMorning', 1), ('Clinton', 1), ('Trump', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 61
# [('WhinyLittleBitch', 3), ('TrumpLoser', 1), ('TrumpSucks', 1), ('SorryDonald', 1), ('DumpTrump', 1)]
# #################
# #################
# 62
# [('Trump', 4), ('TrumpPence16', 2), ('Yay', 1), ('catholics', 1), ('Aroyaldmd', 1)]
# #################
# #################
# 63
# [('Trump', 2), ('TeamTrump', 1), ('SundayMorning', 1), ('PodestaEmails9', 1), ('RiggedSystem', 1)]
# #################
# #################
# 65
# [('MAGA', 5), ('Trump2016', 4), ('2A', 3), ('NCGOPHeadquarters', 3), ('trumptrain', 3)]
# #################
# #################
# 66
# [('Trump', 94), ('MAGA', 86), ('Hillary', 45), ('PodestaEmails9', 38), ('HillaryGropedMe', 33)]
# #################
# #################
# 67
# [('Trump', 14), ('MAGA', 8), ('Wikileaks', 6), ('MAGA3X', 4), ('Hillary', 4)]
# #################
# #################
# 68
# [('DontGetHappy', 3), ('p2', 3), ('trump', 2), ('TrumpTapes', 2), ('WATCH', 2)]
# #################
# #################
# 69
# [('MAGA', 6), ('TrumpPence16', 3), ('Wikileaks', 3), ('HillaryGropedMe', 3), ('Catholic', 2)]
# #################
# #################
# 70
# [('Trump', 8), ('Hillary', 6), ('MAGA', 6), ('PodestaEmails9', 5), ('NeverHillary', 4)]
# #################
# #################
# 71
# [('NeverTrump', 1), ('crookedHillary', 1), ('TeamClinton', 1), ('ImWithHer', 1), ('Trump2016', 1)]
# #################
# #################
# 72
# [('tcot', 10), ('pjnet', 7), ('Trump', 7), ('gop', 6), ('Wallace', 4)]
# #################
# #################
# 73
# [('MAGA', 4), ('ImWithPeace', 3), ('Trump', 3), ('PodestaEmails9', 3), ('WakeUpAmerica', 2)]
# #################
# #################
# 74
# [('HillaryGropedMe', 4), ('SundayMorning', 3), ('Maga3x', 2), ('RIPJournalism', 2), ('FNCE', 1)]
# #################
# #################
# 75
# [('Trump', 34), ('MAGA', 18), ('PodestaEmails9', 17), ('HillaryGropedMe', 14), ('Election2016', 9)]
# #################
# #################
# 76
# [('RhodeIsland', 1), ('Vetted', 1), ('HillaryGropedMe', 1), ('Trump', 1), ('America1st', 1)]
# #################
# #################
# 78
# [('Trump', 2), ('democratic', 2), ('GOP', 2), ('RealElectionFraud', 1), ('VPDebate', 1)]
# #################
# #################
# 79
# [('SundayMorning', 14), ('PodestaEmails9', 13), ('Trump', 7), ('PodestaEmails', 6), ('MAGA', 6)]
# #################
# #################
# 80
# [('PodestaEmails9', 5), ('NeverHillary', 2), ('BoycottPayPal', 2), ('PodestaEmails8', 2), ('PowerPost', 1)]
# #################
# #################
# 81
# [('PodestaEmails9', 22), ('Trump', 7), ('MAGA', 5), ('TrumpPence16', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 83
# [('NeverTrump', 6), ('MAGA', 4), ('Trump', 4), ('HillaryGropedMe', 3), ('Hillary', 2)]
# #################
# #################
# 84
# [('NeverTrump', 8), ('UniteBlue', 7), ('Sanity', 7), ('ClintonKaine', 7), ('BoycottTrump', 6)]
# #################
# #################
# 85
# [('Clintonclan', 1), ('CorruptClintonSupporterFail', 1), ('MillennialsForTrump', 1), ('PodestaEmail9', 1), ('TrumpCheck', 1)]
# #################
# #################
# 86
# [('MAGA', 8), ('Trump', 8), ('HillaryGropedMe', 7), ('PodestaEmails9', 4), ('TrumpPence16', 3)]
# #################
# #################
# 87
# [('NeverHillary', 4), ('MAGA', 4), ('PodestaEmails9', 4), ('Wikileaks', 3), ('Clinton', 3)]
# #################
# #################
# 88
# [('ImWithHer', 7), ('Trump', 5), ('SNL', 4), ('trump', 3), ('icanhazPulitzernow', 2)]
# #################
# #################
# 89
# [('PodestaEmails9', 4), ('Trump', 3), ('CrookedHillary', 3), ('Wikileaks', 2), ('wikileaks', 2)]
# #################
# #################
# 90
# [('NeverTrump', 7), ('NeverTyranny', 2), ('Election2016', 2), ('NeverHillary', 2), ('tcot', 2)]
# #################
# #################
# 91
# [('Trump', 3), ('MAGA', 3), ('DC', 2), ('McMullinFinn', 1), ('HillaryClinton', 1)]
# #################
# #################
# 92
# [('FeelTheBern', 3), ('OurRevolution', 3), ('Election2016', 3), ('Clinton', 2), ('Trump', 2)]
# #################
# #################
# 93
# [('RiggedSystem', 2), ('dumptrump', 2), ('Trump', 2), ('p2', 2), ('nevertrump', 2)]
# #################
# #################
# 94
# [('MAGA', 8), ('Trump', 8), ('AmericaFirst', 3), ('TrumpPence16', 3), ('ClintonCartel', 2)]
# #################
# #################
# 95
# [('HillaryForPrison', 14), ('CrookedHillary', 14), ('Hillary2016', 13), ('Trump', 10), ('MAGA', 7)]
# #################
# #################
# 96
# [('Trump', 15), ('Wikileaks', 8), ('ImWithHer', 6), ('MAGA', 6), ('PodestaEmails9', 6)]
# #################
# #################
# 99
# [('Trump', 5), ('NeverTrump', 4), ('AMJoy', 3), ('ImWithHer', 2), ('HillaryClinton', 1)]
# #################
# #################
# 101
# [('yourownname', 15), ('Trump', 12), ('PodestaEmails9', 4), ('TrumpPence16', 3), ('Wikileaks', 3)]
# #################
# #################
# 102
# [('Trump', 5), ('CorruptMedia', 4), ('MAGA', 4), ('DC', 2), ('Hillary', 2)]
# #################
# #################
# 103
# [('TrumpPence2016', 6), ('MAGA', 6), ('Trump', 6), ('WomenWhoVoteTrump', 4), ('maga', 3)]
# #################
# #################
# 104
# [('boycottdonaldtrump', 54), ('Trump', 4), ('boycotttrump', 2), ('Wikileaks', 2), ('SundayMorning', 2)]
# #################
# #################
# 106
# [('totalblowoutcoming', 1), ('VoteItalianPeter', 1), ('ImWithHer', 1), ('ElectionFraud', 1), ('TrumpCheck', 1)]
# #################
# #################
# 107
# [('Trump', 4), ('PodestaEmails9', 2), ('DonaldTrump', 2), ('Unhinged', 1), ('russiantrolls', 1)]
# #################
# #################
# 108
# [('MAGA', 3), ('TRUMP2016', 3), ('Rigged', 2), ('PodestEmails9', 1), ('Hillary', 1)]
# #################
# #################
# 109
# [('CLTV', 5), ('p2', 2), ('ImWithHer', 2), ('sundaymorning', 1), ('UniteBlue', 1)]
# #################
# #################
# 110
# [('SundayMorning', 1), ('NeverTrump', 1), ('100YearsStrong', 1), ('HillaryBecause', 1), ('ImWithHer', 1)]
# #################
# #################
# 111
# [('MAGA', 5), ('Hillary', 4), ('Trump', 4), ('Trump2016', 2), ('TrumpPence16', 2)]
# #################
# #################
# 112
# [('Trump', 7), ('Hillary', 3), ('HillaryClinton', 2), ('ImWithHer', 2), ('Christians', 2)]
# #################
# #################
# 113
# [('Trump', 9), ('tcot', 6), ('MAGA', 6), ('Hillary', 5), ('HillaryGropedMe', 5)]
# #################
# #################
# 114
# [('VoteTrumpPence16', 15), ('VoteYourFuture', 14), ('Trump', 13), ('ImWithHer', 8), ('vote2016', 5)]
# #################
# #################
# 115
# [('MAGA', 4), ('AmericaFirst', 3), ('Trump', 3), ('MakeAmericaGreatAgain', 2), ('TrumpPence16', 2)]
# #################
# #################
# 116
# [('Trump', 20), ('MAGA', 12), ('TruePundit', 6), ('PodestaEmails9', 6), ('NeverHillary', 6)]
# #################
# #################
# 117
# [('PodestaEmails9', 2), ('HillaryGropedMe', 2), ('SundayMorning', 1), ('trump', 1), ('hillaryforprison', 1)]
# #################
# #################
# 119
# [('PodestaEmails9', 2), ('PayToPlay', 2), ('MAGA3X', 1), ('HillaryScandals', 1), ('Crooked', 1)]
# #################
# #################
# 120
# [('PodestaEmails9', 4), ('PodestEmails9', 1), ('DNC', 1), ('JillNotHill', 1), ('InvestYourVote', 1)]
# #################
# #################
# 121
# [('Trump', 7), ('SNL', 5), ('MAGA', 4), ('CLTV', 3), ('ChooChoo', 3)]
# #################
# #################
# 122
# [('Trump', 14), ('Hillary', 5), ('Clinton', 5), ('debate', 4), ('SWVA', 2)]
# #################
# #################
# 123
# [('trump', 8), ('Islamic', 1), ('Muslim', 1), ('ISIS', 1), ('DumpTrump', 1)]
# #################
# #################
# 124
# [('Trump2016', 3), ('Trump', 2), ('Periscope', 2), ('MAGA', 2), ('SNL', 1)]
# #################
# #################
# 127
# [('Trump', 9), ('ImWithHer', 7), ('100YearsStrong', 3), ('p2', 3), ('AMJoy', 2)]
# #################
# #################
# 128
# [('Trump', 28), ('MAGA', 23), ('SundayMorning', 13), ('HillaryGropedMe', 12), ('PodestaEmails9', 12)]
# #################
# #################
# 129
# [('NeverTrump', 2), ('LatinosForTrump', 2), ('Wikileaks', 2), ('2A', 2), ('Trump', 2)]
# #################
# #################
# 131
# [('Trump', 4), ('SNL', 2), ('Election', 2), ('NBC', 2), ('stopTrump', 1)]
# #################
# #################
# 132
# [('ImWithHer', 8), ('TrumpIsARapist', 3), ('DonaldTrump', 2), ('ShesMyShero', 1), ('1U', 1)]
# #################
# #################
# 133
# [('Trump', 23), ('MAGA', 14), ('PodestaEmails9', 13), ('Hillary', 9), ('SundayMorning', 8)]
# #################
# #################
# 134
# [('Trump', 9), ('Election2016', 7), ('TrumpCheck', 5), ('MAGA', 5), ('bothsidery', 4)]
# #################
# #################
# 136
# [('NeverTrump', 1), ('Trump', 1), ('NotOkay', 1), ('DumpTrump', 1), ('MakeDonaldDrumpfAgain', 1)]
# #################
# #################
# 137
# [('Trump', 24), ('GOP', 3), ('SNL', 3), ('Vote', 3), ('Polls', 3)]
# #################
# #################
# 138
# [('GOPUnite', 2), ('SundayMorning', 1), ('WomenWhoVoteTrump', 1), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 139
# [('CNN', 1), ('PodestaEmails9', 1), ('scampaign', 1), ('Trump', 1), ('CrookedHillary', 1)]
# #################
# #################
# 140
# [('SundayMorning', 2), ('Awhinylittlebitch', 2), ('awhinylilbitch', 2), ('SNL', 2), ('CNNSOTU', 2)]
# #################
# #################
# 141
# [('BlackLivesMatter', 2), ('voter', 1), ('nevertrump', 1), ('Undecided2016', 1), ('dumptrump', 1)]
# #################
# #################
# 142
# [('NEVERTRUMP', 1), ('Trump', 1), ('ChooChoo', 1), ('MAGA', 1), ('Russia', 1)]
# #################
# #################
# 143
# [('Trump', 4), ('SundayMorning', 1), ('TrumpWasRight', 1), ('Journalists', 1), ('RealTime', 1)]
# #################
# #################
# 144
# [('Trump', 24), ('Hillary', 13), ('MAGA', 11), ('Media', 7), ('LolitaExpress', 6)]
# #################
# #################
# 145
# [('DNCLeak', 1), ('NeverTrump', 1), ('Trump', 1), ('mediabias', 1), ('ImWithHer', 1)]
# #################
# #################
# 148
# [('Trump', 28), ('PodestaEmails9', 23), ('MAGA', 17), ('HillaryGropedMe', 14), ('PodestaEmails', 7)]
# #################
# #################
# 149
# [('TrumpPence16', 1), ('CrookedBarack', 1), ('MAGA', 1), ('CrookedHillary', 1), ('Election2016', 1)]
# #################
# #################
# 151
# [('MAGA', 15), ('Trump', 14), ('debate', 7), ('BigLeagueTruth', 7), ('SundayMorning', 6)]
# #################
# #################
# 152
# [('FBICoverUp', 4), ('ClintonCorruption', 3), ('fbicoverup', 3), ('FBICoverup', 2), ('FBI', 2)]
# #################
# #################
# 153
# [('Trump', 3), ('satchat', 1), ('Paypal', 1), ('pjnet', 1), ('tcot', 1)]
# #################
# #################
# 155
# [('anybodybuthillary', 1), ('HILLARYCLINTON', 1), ('Arizona', 1), ('TRUMP', 1), ('Utah', 1)]
# #################
# #################
# 156
# [('MAGA', 12), ('Hillary', 7), ('Trump', 6), ('PodestaEmails9', 6), ('Wikileaks', 5)]
# #################
# #################
# 157
# [('DonTheCon', 1), ('iowa', 1), ('Trump', 1), ('TrumperTantrum', 1), ('McMullinFin', 1)]
# #################
# #################
# 158
# [('Trump', 2), ('ParentFail', 2), ('Election2016', 2), ('HillaryClinton', 1), ('ThirdParty', 1)]
# #################
# #################
# 159
# [('WomenStopTrumpParty', 2), ('HillaryClinton', 1), ('HaveSomeRespect', 1), ('Iwillvote', 1), ('OHVotesEarly', 1)]
# #################
# #################
# 160
# [('Trump', 2), ('TrumPathology', 1), ('TrumPowerGlutton', 1), ('TrumPathological', 1), ('TrumPathetic', 1)]
# #################
# #################
# 161
# [('PodestaEmails9', 2), ('TrumpPence16', 1), ('SundayMorning', 1), ('MAGA', 1), ('ClintonEmails', 1)]
# #################
# #################
# 162
# [('YouAreWhatYouEat', 8), ('TrumpSpill', 8), ('Hillary', 2), ('MAGA', 2), ('Trump', 2)]
# #################
# #################
# 164
# [('SundayMorning', 2), ('Kathy', 1), ('Trump', 1), ('CrookedHillary', 1), ('HillarysEmails', 1)]
# #################
# #################
# 165
# [('Trump', 14), ('PodestaEmails9', 14), ('SundayMorning', 4), ('Hillary', 4), ('Election2016', 3)]
# #################
# #################
# 166
# [('NeverHillary', 4), ('SundayFunday', 3), ('DNCLeak', 2), ('SteinBaraka', 1), ('SundayMorning', 1)]
# #################
# #################
# 168
# [('StopWW3', 3), ('PodestaEmails9', 2), ('RiggingForWar', 2), ('JillOrBust', 2), ('NeverHillary', 1)]
# #################
# #################
# 169
# [('Trump', 4), ('HRCRealityCheck', 2), ('HillaryClinton', 2), ('crooked', 2), ('ImWithHer', 2)]
# #################
# #################
# 170
# [('Trump', 5), ('NeverTrump', 4), ('HillaryBecause', 3), ('MSNBC', 2), ('PowerPost', 1)]
# #################
# #################
# 171
# [('Hillary', 4), ('Trump', 4), ('Nukes', 2), ('IranDeal', 2), ('Clinton', 2)]
# #################
# #################
# 172
# [('Trump', 5), ('jaketapper', 1), ('Mediafail', 1), ('GOP', 1), ('SCOTUS', 1)]
# #################
# #################
# 175
# [('Trump', 7), ('TrumpCheck', 1), ('Trump2016', 1), ('maga', 1), ('Election2016', 1)]
# #################
# #################
# 178
# [('StrongerTogether', 3), ('Arizona', 2), ('Georgia', 2), ('YesWeKaine', 2), ('Ohio', 2)]
# #################
# #################
# 179
# [('NeverTrumpOrHillary', 3), ('MAGA', 2), ('LGBTI', 2), ('wikileaks', 1), ('EndTheFed', 1)]
# #################
# #################
# 180
# [('Trump', 4), ('TrumpFatigue', 2), ('HillaryClinton', 1), ('USMC', 1), ('Election2016', 1)]
# #################
# #################
# 181
# [('Trump', 16), ('MAGA', 11), ('PodestaEmails9', 8), ('Hillary', 6), ('TrumpTrain', 5)]
# #################
# #################
# 182
# [('Trump', 3), ('Vote', 2), ('insultstexanstyle', 1), ('PodestaEmails9', 1), ('100YearsStrong', 1)]
# #################
# #################
# 183
# [('Trump', 22), ('MAGA', 7), ('CrookedHillary', 4), ('WomenWhoVoteTrump', 2), ('Hillary', 2)]
# #################
# #################
# 184
# [('ImWithHer', 2), ('likea5yearold', 1), ('HintHint', 1), ('ClintonWins', 1), ('trumpisapussy', 1)]
# #################
# #################
# 186
# [('Trump', 5), ('Hillary', 2), ('PodestaEmails', 2), ('CHRISWALLACE', 1), ('debate', 1)]
# #################
# #################
# 187
# [('HillaryClinton', 1), ('maddow', 1), ('YesWeKaine', 1), ('ClintonKaine16', 1), ('Utah', 1)]
# #################
# #################
# 188
# [('Trump', 9), ('TrumpCheck', 5), ('ImWithHer', 4), ('NeverTrump', 3), ('SNL', 3)]
# #################
# #################
# 189
# [('MAGA', 8), ('MTP', 6), ('PJNET', 4), ('trump', 3), ('Benghazi', 3)]
# #################
# #################
# 190
# [('PodestaEmails9', 3), ('FakePolls', 1), ('Trump2016', 1), ('HillaryHatesYou', 1), ('NoDAPL', 1)]
# #################
# #################
# 191
# [('Wikileaks', 2), ('Clinton', 1), ('CrookedHillary', 1), ('RIPJournalism', 1), ('CatholicsForTrump', 1)]
# #################
# #################
# 192
# [('LockHimUp', 22), ('GetWOKE', 15), ('SundayMorning', 1), ('SNL', 1), ('Halloween', 1)]
# #################
# #################
# 195
# [('SundayMorning', 4), ('PodestaEmails9', 4), ('Wikileaks', 3), ('PodestaEmails', 3), ('MAGA', 3)]
# #################
# #################
# 196
# [('Trump', 9), ('HRC', 6), ('LaCasaBianca', 4), ('HillaryGropedMe', 3), ('RiggedElection', 2)]
# #################
# #################
# 198
# [('PodestaEmails', 2), ('MAGA', 2), ('TRUMP', 2), ('PaulRyan', 1), ('HillaryClinton', 1)]
# #################
# #################
# 199
# [('HillaryBecasue', 1), ('TRUMP', 1), ('Crooked', 1), ('PodestaEmails9', 1), ('Clintons', 1)]
# #################
# #################
# 200
# [('PodestaEmails9', 5), ('PodestaEmails', 3), ('Shitshow', 1), ('PodestaEmails8', 1), ('BringThemToHeel', 1)]
# #################
# #################
# 202
# [('PredatorDon', 16), ('debate', 12), ('Unhinged', 1), ('TemperamentallyUnfit', 1), ('debates', 1)]
# #################
# #################
# 203
# [('SundayMorning', 1), ('nevertrump', 1), ('Trump', 1), ('AgentOrange', 1), ('disqualifying', 1)]
# #################
# #################
# 204
# [('p2', 3), ('Trump', 2), ('TopProg', 1), ('NeverTrump', 1), ('USLatino', 1)]
# #################
# #################
# 205
# [('WeThePeople', 2), ('IOWA', 1), ('FLORIDA', 1), ('VIRGINIA', 1), ('TrumpForPresident', 1)]
# #################
# #################
# 206
# [('NeverTrump', 5), ('DonTheCon', 3), ('DumpTrump', 3), ('UniteBlue', 2), ('ImWithHer', 2)]
# #################
# #################
# 207
# [('Hillary', 2), ('CLINTON', 1), ('Trump', 1), ('IvankaTrump', 1), ('BringBernieBack', 1)]
# #################
# #################
# 208
# [('HillaryGropedMeToo', 2), ('Hannity', 1), ('SundayMorning', 1), ('Trump', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 209
# [('Election2016', 15), ('Trump', 3), ('trump', 2), ('leshow', 2), ('MAGA', 2)]
# #################
# #################
# 211
# [('ImWithHer', 7), ('NeverTrump', 5), ('DumpTrump', 3), ('Trump', 3), ('UniteBlue', 2)]
# #################
# #################
# 212
# [('PodestaEmails9', 4), ('NeverHillary', 3), ('BreakingNews', 2), ('MAGA', 2), ('Wikileaks', 2)]
# #################
# #################
# 214
# [('Trump', 4), ('Liars', 2), ('WakeUpAndVoteTrump', 1), ('DC', 1), ('poll', 1)]
# #################
# #################
# 215
# [('Trump', 7), ('MAGA', 3), ('Hillary', 2), ('tcot', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 216
# [('PodestaEmails9', 21), ('podestaemails9', 3), ('SundayMorning', 3), ('Trump', 3), ('PodestaEmails', 3)]
# #################
# #################
# 217
# [('UNFIT', 3), ('wikileaks', 2), ('TrumpPence16', 1), ('MAGA3X', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 218
# [('Trump', 4), ('MAGA', 3), ('AmericaFirst', 2), ('NeverHillary', 2), ('HillarysEmails', 1)]
# #################
# #################
# 220
# [('Trump', 9), ('Clinton', 6), ('MAGA', 4), ('HillaryGropedMe', 4), ('TruePundit', 3)]
# #################
# #################
# 221
# [('MAGA', 29), ('PodestaEmails9', 16), ('Trump', 13), ('Hillary', 9), ('Wikileaks', 7)]
# #################
# #################
# 223
# [('Trump', 3), ('p2', 1), ('trumploses', 1), ('RNC', 1), ('PutinTrump', 1)]
# #################
# #################
# 225
# [('trump', 11), ('America', 9), ('Debate', 7), ('Election2016', 3), ('Trump', 2)]
# #################
# #################
# 226
# [('Trump', 6), ('hillaryclinton', 5), ('USA', 2), ('northcarolina', 2), ('GOP', 2)]
# #################
# #################
# 227
# [('Trump', 4), ('HillaryClinton', 1), ('dumptrump', 1), ('CLINTON', 1), ('CHRISWALLACE', 1)]
# #################
# #################
# 228
# [('ImWithHer', 3), ('HillaryGropedMe', 3), ('PodestaEmails9', 2), ('rigged', 2), ('Chozick', 1)]
# #################
# #################
# 229
# [('Trump', 3), ('debate', 3), ('DonaldTrump', 2), ('SundayMorning', 1), ('Arizona', 1)]
# #################
# #################
# 230
# [('Syria', 1), ('Clinton', 1), ('Trump', 1), ('BorisJohnson', 1), ('Aleppo', 1)]
# #################
# #################
# 231
# [('Hillary', 2), ('HillaryClinton', 1), ('Georgia', 1), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 232
# [('MeetThePress', 2), ('SundayMorning', 1), ('MAGA', 1), ('NeverTrump', 1), ('Trump', 1)]
# #################
# #################
# 233
# [('MAGA', 3), ('Trump', 3), ('ImWithHer', 2), ('DEMOCRACY', 1), ('imwithher', 1)]
# #################
# #################
# 234
# [('SundayMorning', 3), ('HillaryGropedMe', 3), ('Trump', 2), ('Hillary', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 235
# [('Trump', 2), ('icanhazPulitzernow', 2), ('IcanhazPulitzernow', 1), ('Bills', 1), ('NeverTrump', 1)]
# #################
# #################
# 236
# [('KansasPlot', 1), ('Victims', 1), ('Trump', 1), ('USA', 1), ('GlobalConspiracy', 1)]
# #################
# #################
# 238
# [('trump', 2), ('hillary', 2), ('Trump', 2), ('police', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 239
# [('PodestaEmails9', 8), ('Trump', 6), ('HillaryGropedMeToo', 4), ('MAGA', 4), ('HillaryGropedMe', 4)]
# #################
# #################
# 241
# [('TRUMP', 18), ('HILLARY', 13), ('Trump', 6), ('Hillary', 3), ('PerrieExposedZaynParty', 2)]
# #################
# #################
# 242
# [('Trump', 2), ('HillaryBecause', 1), ('bluehand', 1), ('Clinton', 1), ('JamesComey', 1)]
# #################
# #################
# 243
# [('Trump', 27), ('PodestaEmails9', 19), ('MAGA', 15), ('Illinois', 9), ('Missouri', 9)]
# #################
# #################
# 245
# [('MAGA', 7), ('Trump', 5), ('Hillary', 4), ('TrumpTrain', 3), ('MakeAmericaGreatAgain', 2)]
# #################
# #################
# 246
# [('RiggedSystem', 2), ('DishonestMedia', 1), ('ClintonCorruption', 1), ('PodestaEmails9', 1), ('NeedyLatinos', 1)]
# #################
# #################
# 247
# [('Trump', 3), ('responsiblity', 1), ('morals', 1), ('personal', 1), ('ASHAT', 1)]
# #################
# #################
# 248
# [('Hillary', 18), ('Clinton', 16), ('Debate', 16), ('debate', 9), ('Trump', 4)]
# #################
# #################
# 249
# [('SundayMorning', 2), ('PodestaEmails9', 2), ('wwe', 2), ('TrumpHaiku', 2), ('p2', 1)]
# #################
# #################
# 250
# [('PodestaEmails9', 4), ('MAGA', 3), ('Election2016', 2), ('PodestaEmails', 2), ('TrumpTrain', 2)]
# #################
# #################
# 252
# [('Trump', 6), ('ImWithHer', 3), ('HillaryGropedMe', 3), ('p2', 3), ('PodestaEmails9', 3)]
# #################
# #################
# 253
# [('Trump', 12), ('Hillary', 5), ('MAGA', 4), ('GOP', 4), ('MAGA3X', 3)]
# #################
# #################
# 254
# [('Trump', 4), ('TrumpRape', 3), ('Wikileaks', 2), ('projection', 1), ('ClintonCartel', 1)]
# #################
# #################
# 257
# [('tRUMP', 4), ('ImWithHer', 4), ('Trump', 4), ('UniteBlue', 3), ('p2', 3)]
# #################
# #################
# 258
# [('MAGA', 5), ('PJNET', 3), ('TCOT', 3), ('AmericaFirst', 2), ('TrumpPence16', 2)]
# #################
# #################
# 259
# [('PodestaEmails9', 15), ('HillaryGropedMe', 7), ('Hillary', 4), ('MAGA', 4), ('trump', 3)]
# #################
# #################
# 260
# [('SundayMorning', 2), ('WomenWhoVoteTrump', 1), ('Clinton', 1), ('Trump', 1), ('Bosnia', 1)]
# #################
# #################
# 261
# [('Trump', 27), ('Clinton', 5), ('GOP', 4), ('RNC', 4), ('trump', 3)]
# #################
# #################
# 262
# [('NeverTrump', 4), ('Trump', 3), ('SNL', 3), ('VoteBlue', 3), ('POTUS', 2)]
# #################
# #################
# 263
# [('Trump', 5), ('PodestaEmails9', 2), ('Hillary', 2), ('Wikileaks', 2), ('VPDebate', 1)]
# #################
# #################
# 264
# [('Wikileaks', 3), ('Trump', 2), ('PodestaEmails', 2), ('HillaryBecause', 1), ('AboveTheLaw', 1)]
# #################
# #################
# 265
# [('prolife', 3), ('prowoman', 2), ('NeverTrump', 2), ('Trump', 1), ('NeverHillary', 1)]
# #################
# #################
# 266
# [('clownshow', 1), ('AmericaFirst', 1), ('NeverTrump', 1), ('TrumpKnowNothingism', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 267
# [('TrumpPence16', 6), ('AmericaFirst', 6), ('MAGA', 6), ('Jobs', 4), ('Ohio', 2)]
# #################
# #################
# 269
# [('Debates2016', 1), ('ChrisWallace', 1), ('ChooChoo', 1), ('SNL', 1), ('ImwithHer', 1)]
# #################
# #################
# 272
# [('SundayMorning', 3), ('PodestaEmails9', 3), ('CNNSOTU', 3), ('TrumpPence16', 2), ('MAGA', 2)]
# #################
# #################
# 273
# [('TRUMP', 2), ('DC', 1), ('MAGA3X', 1), ('PodestaEmail9', 1), ('MAGA', 1)]
# #################
# #################
# 275
# [('RiggedElection', 1), ('neverTrump', 1), ('RadicalChristianTerrorists', 1), ('whiner', 1), ('WhiteTRASH', 1)]
# #################
# #################
# 276
# [('Election2016', 2), ('HillarysEmails', 1), ('c4news', 1), ('FT', 1), ('Trump', 1)]
# #################
# #################
# 278
# [('Trump', 4), ('ImWithHer', 2), ('Rapist', 1), ('NeverTrump', 1), ('CelebApprentice', 1)]
# #################
# #################
# 279
# [('PodestaEmails', 1), ('BernieSanders', 1), ('Roadto270', 1), ('BigLie', 1), ('Trump', 1)]
# #################
# #################
# 280
# [('HillaryClinton', 2), ('ShesWithUs', 2), ('ImWithHer', 2), ('DemStorm', 2), ('TeenPeeper', 1)]
# #################
# #################
# 281
# [('SundayMorning', 3), ('Trump', 3), ('NeverTrump', 2), ('ImWithHer', 2), ('Clinton', 2)]
# #################
# #################
# 282
# [('POLL', 2), ('p2', 1), ('FPU', 1), ('WethePeople', 1), ('Clinton', 1)]
# #################
# #################
# 287
# [('Trump', 5), ('Wikileaks', 3), ('PodestaEmails', 3), ('Hillary', 2), ('ImSoSick', 1)]
# #################
# #################
# 289
# [('HillaryGropedMe', 3), ('FakeNutritionFacts', 1), ('PodestaEmails9', 1), ('GoldmanSach', 1), ('hillarygropedmetoo', 1)]
# #################
# #################
# 290
# [('tcot', 9), ('MAGA', 9), ('Trump', 7), ('PodestaEmails', 6), ('TrumpPence16', 6)]
# #################
# #################
# 292
# [('Trump', 2), ('KansasPlot', 1), ('GoingOutOnALimb', 1), ('uniteblue', 1), ('liar', 1)]
# #################
# #################
# 293
# [('ImWithHer', 4), ('DemStorm', 3), ('HillaryClinton', 2), ('Trump2016', 2), ('OrangeHitler', 2)]
# #################
# #################
# 294
# [('Trump', 3), ('Christian', 2), ('maddow', 2), ('Evangelical', 2), ('Florida', 2)]
# #################
# #################
# 295
# [('Trump', 4), ('NeverHillary', 2), ('PodestaEmails9', 2), ('PodestaEmails', 2), ('100YearsStrong', 1)]
# #################
# #################
# 297
# [('Trump', 2), ('SNL', 2), ('SundayMorning', 1), ('Clinton', 1), ('Strictly', 1)]
# #################
# #################
# 298
# [('Election2016', 3), ('ImWithHer', 3), ('PodestaEmails', 2), ('DeMOCKracy', 2), ('Corruption', 2)]
# #################
# #################
# 300
# [('Revolution', 1), ('Clinton', 1), ('SNL', 1), ('VoteTrump', 1), ('Axelrod', 1)]
# #################
# #################
# 301
# [('MAGA', 28), ('Trump', 24), ('TrumpPence16', 13), ('PodestaEmails', 7), ('Wikileaks', 7)]
# #################
# #################
# 302
# [('Trump2016', 3), ('SundayMorning', 1), ('Trump', 1), ('podestaemail', 1), ('WikiLeak', 1)]
# #################
# #################
# 304
# [('Trump', 3), ('ChristianWomenPreach', 1), ('SmartNews', 1), ('SNL', 1), ('LGBTQ', 1)]
# #################
# #################
# 305
# [('Trump', 3), ('Hillary', 3), ('GaryJohnson', 2), ('Wikileaks', 2), ('MakeAmericaSaneAgain', 1)]
# #################
# #################
# 306
# [('DumbDonald', 4), ('deleteyourself', 3), ('deleteyourcampain', 2), ('ImWithHer', 2), ('AL02', 1)]
# #################
# #################
# 307
# [('SundayMorning', 1), ('MAGA', 1), ('PodestaEmails10', 1), ('Hillary', 1), ('MidEast', 1)]
# #################
# #################
# 309
# [('Trump', 2), ('p2', 1), ('Libya', 1), ('Voters', 1), ('LawAndOrder', 1)]
# #################
# #################
# 310
# [('HillaryGropedMe', 6), ('Trump', 6), ('MAGA', 5), ('PodestaEmails', 4), ('PodestaEmails9', 4)]
# #################
# #################
# 311
# [('Trump', 3), ('centralparkfive', 1), ('BigGirlPanties', 1), ('SNL', 1), ('Hillary', 1)]
# #################
# #################
# 312
# [('HillaryGropedMe', 6), ('PodestaEmails9', 3), ('Wikileaks', 3), ('CrookedHillary', 2), ('MAGA3X', 1)]
# #################
# #################
# 313
# [('HillaryLiesMatter', 2), ('Trump', 2), ('HILLARY', 2), ('UniteBlue', 1), ('boycottthem', 1)]
# #################
# #################
# 314
# [('Trump', 14), ('MAGA', 11), ('TrumpTrain', 4), ('Trump2016', 3), ('Hillary', 3)]
# #################
# #################
# 315
# [('Trump', 5), ('imwithher', 2), ('Reflection', 2), ('WIBackHer', 1), ('nailedit', 1)]
# #################
# #################
# 316
# [('NeverTrump', 1), ('Trump', 1), ('TrumpTapes', 1), ('imwithher', 1), ('ClownTrain', 1)]
# #################
# #################
# 317
# [('SundayMorning', 3), ('LockHerUp', 2), ('trump', 1), ('BrockTurner', 1), ('PodestaEmail9', 1)]
# #################
# #################
# 319
# [('PodestaEmails9', 8), ('RiggedSystem', 2), ('Trump', 2), ('TrumpTrain', 1), ('USA', 1)]
# #################
# #################
# 320
# [('NeverTrump', 1), ('tcot', 1), ('Hillary', 1), ('PodestaEmails', 1), ('ClintonEmails', 1)]
# #################
# #################
# 321
# [('Trump', 10), ('GOP', 7), ('SteveBannon', 3), ('tlot', 2), ('AlexJones', 1)]
# #################
# #################
# 326
# [('Hillary', 3), ('MAGA', 2), ('ccot', 1), ('Christian', 1), ('MAGA3X', 1)]
# #################
# #################
# 327
# [('SundayMorning', 7), ('Trump', 3), ('CNNSotu', 2), ('Clinton', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 328
# [('Trump', 2), ('boycottpaypal', 2), ('Election2016', 2), ('NeverTrump', 1), ('LoveAndKindness', 1)]
# #################
# #################
# 329
# [('ImWithHer', 9), ('HillYes', 7), ('HFA', 6), ('Hillary2016', 6), ('VoteBlue', 6)]
# #################
# #################
# 330
# [('HatefulHillary', 7), ('RacistHillary', 7), ('PodestaEmails9', 5), ('RiggedSystem', 2), ('VOTE', 2)]
# #################
# #################
# 331
# [('MAGA', 39), ('Trump', 36), ('America1st', 28), ('HeartlessHillary', 21), ('PodestaEmails9', 7)]
# #################
# #################
# 332
# [('WakeUpAmerica', 7), ('MAGA', 5), ('Trump', 4), ('TrumpPence16', 3), ('AmericaFirst', 2)]
# #################
# #################
# 333
# [('TrumpPence16', 9), ('Trump', 6), ('hillaryshit', 5), ('trump', 4), ('MAGA', 4)]
# #################
# #################
# 335
# [('Trump', 3), ('CACD49', 2), ('p2', 1), ('India', 1), ('GOPfail', 1)]
# #################
# #################
# 336
# [('MAGA', 23), ('Election2016', 15), ('NeverHillary', 14), ('VoteYourFuture', 14), ('JillNotHill', 14)]
# #################
# #################
# 339
# [('p2', 5), ('ImWithHer', 4), ('FlipItDem', 3), ('t4a', 3), ('TrutherbotArmy', 3)]
# #################
# #################
# 340
# [('p2', 2), ('tcot', 2), ('HillaryClinton', 1), ('PodestaEmails7', 1), ('TRUMP', 1)]
# #################
# #################
# 343
# [('tcot', 7), ('Trump', 7), ('Hope', 2), ('DNCHack', 1), ('wikileaks', 1)]
# #################
# #################
# 345
# [('HelpWikileaks', 1), ('MAGA', 1), ('ISIS', 1), ('HillaryClinton', 1), ('fightfor15bc', 1)]
# #################
# #################
# 346
# [('Election2016', 9), ('HillaryClinton', 3), ('DonaldTrump', 3), ('Trump', 3), ('Clinton', 1)]
# #################
# #################
# 347
# [('RacistHillary', 5), ('HatefulHillary', 5), ('Trump', 3), ('Election2016', 2), ('SundayMorning', 2)]
# #################
# #################
# 348
# [('ImWithHer', 38), ('mediabias', 14), ('Wikileaks', 6), ('CORRUPTDOJ', 6), ('ISIS', 5)]
# #################
# #################
# 349
# [('PodestaEmails9', 2), ('SundayMorning', 1), ('uniteblue', 1), ('nevertrump', 1), ('Trump', 1)]
# #################
# #################
# 351
# [('Trump', 2), ('lifeofauggie', 1), ('Clinton', 1), ('selloutsanders', 1), ('Kansas', 1)]
# #################
# #################
# 352
# [('msnbc', 4), ('Trump', 3), ('MSNBC', 3), ('AMJoy', 2), ('BENGHAZI', 1)]
# #################
# #################
# 353
# [('ImWithHer', 2), ('NAFTA', 1), ('PayPal', 1), ('100YearsStrong', 1), ('AMJoy', 1)]
# #################
# #################
# 357
# [('Trump', 2), ('MAGA', 2), ('Wikileaks', 1), ('MSM', 1), ('HillarysHealth', 1)]
# #################
# #################
# 358
# [('Trump', 3), ('SexualPredatorTrump', 2), ('Arizona', 1), ('Iowa', 1), ('TrumpFatigue', 1)]
# #################
# #################
# 359
# [('WomenWhoVoteTrump', 19), ('Trump', 2), ('PodestaEmails', 2), ('deniers', 1), ('HillaryClinton', 1)]
# #################
# #################
# 361
# [('MAGA', 10), ('TrumpPence16', 7), ('HillaryGropedMe', 7), ('Hillary', 6), ('NeverHillary', 5)]
# #################
# #################
# 363
# [('Trump', 2), ('DanBowman', 1), ('media', 1), ('conspiracy', 1), ('treason', 1)]
# #################
# #################
# 364
# [('KansasPlot', 1), ('Clinton', 1), ('Trump', 1), ('RiggedSystem', 1), ('VoterFraud', 1)]
# #################
# #################
# 365
# [('PodestaEmails9', 5), ('SundayMorning', 3), ('MAGA', 3), ('Trump', 2), ('sundaymorning', 1)]
# #################
# #################
# 366
# [('MAGA', 28), ('NeverHillary', 25), ('BasketOfDeplorables', 24), ('PodestaEmails9', 6), ('Trump', 5)]
# #################
# #################
# 367
# [('MAGA', 5), ('trump', 3), ('Wikileaks', 3), ('Trump', 3), ('Hillary', 2)]
# #################
# #################
# 369
# [('Hillary', 3), ('SuperPredator', 2), ('Clinton', 2), ('Catholic', 1), ('NAFTA', 1)]
# #################
# #################
# 370
# [('SNL', 2), ('Trump', 1), ('Pitchforks', 1), ('mentalillness', 1), ('TrumpCheck', 1)]
# #################
# #################
# 371
# [('mtp', 5), ('AlexWitt', 5), ('Hillary', 2), ('gps', 2), ('MikePence', 2)]
# #################
# #################
# 372
# [('dumptrump', 2), ('falseflag', 2), ('Rigged2016', 1), ('blah', 1), ('rigged', 1)]
# #################
# #################
# 373
# [('Trump', 2), ('savedyouaclick', 1), ('ncpol', 1), ('NeverTrump', 1), ('JustSaying', 1)]
# #################
# #################
# 374
# [('LOSER', 2), ('ManBaby', 2), ('FlipItBlue', 1), ('HillaryClinton', 1), ('trump', 1)]
# #################
# #################
# 375
# [('Wikileaks', 3), ('Clintons', 2), ('Trump', 2), ('SNL', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 376
# [('Hillary', 4), ('Trump', 2), ('SundayMorning', 1), ('CrookedHillary', 1), ('TrumpPence16', 1)]
# #################
# #################
# 377
# [('msnbc', 2), ('ncgov', 1), ('Clinton', 1), ('Trump', 1), ('MH370Effect', 1)]
# #################
# #################
# 378
# [('Trump', 2), ('PodestaEmails', 2), ('MAGA', 2), ('SundayMorning', 1), ('WhiteHouse', 1)]
# #################
# #################
# 379
# [('Trump', 2), ('ThursdayThoughts', 1), ('SundayMorning', 1), ('CLTV', 1), ('tcot', 1)]
# #################
# #################
# 380
# [('MAGA', 8), ('Trump', 5), ('Trump2016', 4), ('VOTETRUMP', 4), ('Clinton', 3)]
# #################
# #################
# 381
# [('NeverTrump', 1), ('Trump', 1), ('ChooChoo', 1), ('MAGA', 1), ('Ghanacelebrity', 1)]
# #################
# #################
# 383
# [('Trump', 5), ('Clinton', 4), ('MAGA', 3), ('GOP', 2), ('SundayMorning', 2)]
# #################
# #################
# 384
# [('SundayMorning', 1), ('PodestaEmails', 1), ('NeverHillary', 1), ('MAGA', 1), ('NotQualified', 1)]
# #################
# #################
# 386
# [('RealElectionFraud', 1), ('Birther', 1), ('Trump', 1), ('WhatTyrantsDo', 1), ('TrumpRevolutionThreats', 1)]
# #################
# #################
# 387
# [('SNL', 4), ('VPDebate', 1), ('100YearsStrong', 1), ('NeverTrump', 1), ('Trump', 1)]
# #################
# #################
# 388
# [('EvanMcMullin2016', 2), ('WhichObama', 1), ('NeverHillaryNeverTrump', 1), ('ConstitutionalConservative', 1), ('FreeAmy', 1)]
# #################
# #################
# 389
# [('Trump', 6), ('Hillary', 3), ('MAGA', 3), ('TRUMP', 3), ('PodestaEmails9', 3)]
# #################
# #################
# 390
# [('CLINTON', 1), ('Hillary4WWIII', 1), ('HillaryGropes', 1), ('VoteRedOrGTFOOfAmerica', 1), ('WeWILLElectARepublicanPresidentIn2016', 1)]
# #################
# #################
# 391
# [('Trump', 3), ('Clinton', 2), ('Latinos', 1), ('NoMercy', 1), ('Breaking', 1)]
# #################
# #################
# 392
# [('RhodeIsland', 1), ('Vetted', 1), ('Trump', 1), ('Rapefugees', 1), ('America1st', 1)]
# #################
# #################
# 395
# [('PodestaEmails9', 3), ('HillarysHealth', 2), ('Anonymous', 2), ('SundayMorning', 2), ('MAGA', 2)]
# #################
# #################
# 396
# [('MAGA', 6), ('FuckTrump', 3), ('fucktrump', 3), ('NeverTrump', 3), ('Trump', 3)]
# #################
# #################
# 398
# [('SundayMorning', 1), ('ClintonCorruption', 1), ('podestaemails9', 1), ('IBelieveMyLyingEyes', 1), ('ClintonFoundation', 1)]
# #################
# #################
# 399
# [('SundayMorning', 2), ('PASen', 1), ('Trump', 1), ('CrookedHillary', 1), ('factcheck2016', 1)]
# #################
# #################
# 400
# [('Trump', 3), ('HillaryEmails', 1), ('Clinton', 1), ('BoycottHollywood', 1), ('vicious', 1)]
# #################
# #################
# 401
# [('Trump', 4), ('p2', 1), ('Catholics', 1), ('LATIMES', 1), ('Hillary', 1)]
# #################
# #################
# 402
# [('Trump', 2), ('WakeUpAmerica', 2), ('MAGA', 2), ('Hannity', 1), ('demvalues', 1)]
# #################
# #################
# 403
# [('RiggedElection', 1), ('clinton', 1), ('SundayMorning', 1), ('sellout', 1), ('Army', 1)]
# #################
# #################
# 405
# [('Trump', 2), ('MAGA', 2), ('HillarysEmails', 1), ('HillaryClinton', 1), ('AMJoy', 1)]
# #################
# #################
# 407
# [('MAGA3X', 1), ('PodestaEmails8', 1), ('MSM', 1), ('PodestaEmails', 1), ('GoldmanSach', 1)]
# #################
# #################
# 412
# [('MAGA', 4), ('Trump', 4), ('RiggedSystem', 3), ('Hillary', 3), ('NeverHillary', 3)]
# #################
# #################
# 413
# [('ImWithHer', 3), ('p2', 1), ('Trump', 1), ('AgentOrange', 1), ('TrumpTapes', 1)]
# #################
# #################
# 415
# [('Trump', 14), ('MAGA', 4), ('Clinton', 3), ('2A', 2), ('vote', 2)]
# #################
# #################
# 416
# [('quitit', 1), ('NeverTrump', 1), ('Trump', 1), ('PodestaEmails9', 1), ('NeedyLatinos', 1)]
# #################
# #################
# 417
# [('Prop64', 2), ('Trump', 1), ('tcot', 1), ('PodestaEmails9', 1), ('AnybodyButClinton', 1)]
# #################
# #################
# 418
# [('Trump', 3), ('Nieuwsuur', 2), ('VoteTrumpPence16', 1), ('journalism2016', 1), ('HillaryBecause', 1)]
# #################
# #################
# 421
# [('sundaypolitics', 4), ('tcot', 3), ('Trump', 3), ('MAGA', 2), ('AltRight', 2)]
# #################
# #################
# 423
# [('womendontreport', 1), ('NeverTrump', 1), ('FakeChristianForTrump', 1), ('FakeNutritionFacts', 1), ('DaisyandAudrie', 1)]
# #################
# #################
# 424
# [('Trump', 10), ('Hillary', 5), ('MAGA', 5), ('Wikileaks', 4), ('PodestaEmails9', 4)]
# #################
# #################
# 425
# [('PodestaEmails9', 4), ('MAGA3X', 4), ('EqualOpportunityFucker', 2), ('PodestaEmails7', 1), ('PodestaEmails6', 1)]
# #################
# #################
# 428
# [('MAGA', 9), ('AmericaFirst', 8), ('TrumpPence16', 8), ('PJNET', 6), ('Jobs', 4)]
# #################
# #################
# 431
# [('Trump', 14), ('Hillary', 2), ('LUNATIC', 2), ('Rapist', 1), ('ncpol', 1)]
# #################
# #################
# 432
# [('snl', 10), ('mtp', 7), ('tmz', 3), ('60minutes', 2), ('meetthepress', 2)]
# #################
# #################
# 433
# [('Trump', 3), ('SNL', 2), ('CrookedHillary', 1), ('AlecBaldwin', 1), ('BringItOn', 1)]
# #################
# #################
# 434
# [('AmericaFirst', 1), ('SNL', 1), ('TrumpPence16', 1), ('MAGA', 1), ('TrumpTrain', 1)]
# #################
# #################
# 435
# [('Vote4Jill', 7), ('DuopolyExit2016', 5), ('Trump2016', 4), ('Trump', 4), ('Wikileaks', 3)]
# #################
# #################
# 436
# [('HillaryClinton', 1), ('Clinton', 1), ('debates', 1), ('Crooked', 1), ('AMjoy', 1)]
# #################
# #################
# 438
# [('Trump', 3), ('HillaryClinton', 2), ('NeverTrump', 2), ('HillaryGropedMe', 2), ('women', 2)]
# #################
# #################
# 440
# [('TrumpTrain', 9), ('Trump', 5), ('HillaryGropedMe', 4), ('icanhazPulitzernow', 2), ('HillaryClinton', 2)]
# #################
# #################
# 442
# [('ImWithHer', 3), ('NeverTrump', 1), ('HillYes', 1), ('VoteBlueAmerica', 1), ('sports', 1)]
# #################
# #################
# 443
# [('TrumpPence16', 2), ('MAGA', 2), ('AmericaFirst', 1), ('Hillary', 1), ('NeverHillary', 1)]
# #################
# #################
# 444
# [('MAGA', 3), ('TRUMP', 3), ('Trump', 2), ('Hillary', 2), ('TrumpPence16', 2)]
# #################
# #################
# 445
# [('Trump', 5), ('MAGA', 3), ('TrumpTrain', 2), ('HillaryClinton', 1), ('lnyhbt', 1)]
# #################
# #################
# 446
# [('KellyFile', 1), ('Soros', 1), ('TrumpCheck', 1), ('HILLARY', 1), ('LockHerUp', 1)]
# #################
# #################
# 448
# [('Trump', 2), ('GoldmanSach', 2), ('HillaryClinton', 1), ('trump', 1), ('TrumpRally', 1)]
# #################
# #################
# 449
# [('PodestaEmails', 4), ('PodestaEmails9', 4), ('ClintonCoup', 3), ('Wikileaks', 2), ('TrumpforUC', 1)]
# #################
# #################
# 450
# [('PodestaEmails10', 23), ('PayToPlay', 4), ('ImWithHer', 2), ('Hillary2016', 2), ('GlobalMediaBagelBankers', 2)]
# #################
# #################
# 451
# [('Trump', 5), ('NeverTrump', 4), ('MAGA', 3), ('AMERICAFIRST', 2), ('SundayMorning', 2)]
# #################
# #################
# 455
# [('Trump', 3), ('CrookedHillary', 1), ('Cheating', 1), ('DishonestMedia', 1), ('PodestaEmails5', 1)]
# #################
# #################
# 456
# [('dliberate', 1), ('PotusGeeks', 1), ('Twitter', 1), ('croockedhillary', 1), ('wikileaks', 1)]
# #################
# #################
# 457
# [('Trump', 6), ('MAGA', 5), ('TruePundit', 4), ('SundayMorning', 3), ('HillaryClinton', 2)]
# #################
# #################
# 458
# [('VoteBlue', 1), ('StrongerTogether', 1), ('HillaryGropedMe', 1), ('ImWithHer', 1), ('Reflection', 1)]
# #################
# #################
# 460
# [('Clinton', 6), ('Hillary', 5), ('DiabolicalHillary', 4), ('HillaryHatesEveryone', 2), ('DOJ', 1)]
# #################
# #################
# 461
# [('HillaryGropedMe', 2), ('SundayMorning', 1), ('Trump', 1), ('CrookedHillary', 1), ('WakeUpAmerica', 1)]
# #################
# #################
# 462
# [('NeverTrump', 7), ('SundayMorning', 6), ('Trump', 5), ('AMJoy', 2), ('p2', 1)]
# #################
# #################
# 463
# [('MAGA', 3), ('Trump', 3), ('TrumpPence16', 2), ('Wikileaks', 2), ('RT', 1)]
# #################
# #################
# 465
# [('Trump', 90), ('NeverHillary', 6), ('MAGA3X', 5), ('PodestaEmails9', 3), ('HillaryGropedMe', 2)]
# #################
# #################
# 466
# [('PodestaEmails9', 2), ('MAGA', 2), ('FollowTheMoney', 2), ('SundayMorning', 1), ('NeverTrump', 1)]
# #################
# #################
# 467
# [('PodestaEmails9', 3), ('Poll', 3), ('FlyEaglesFly', 2), ('WikiLeaks', 2), ('Hillary', 2)]
# #################
# #################
# 468
# [('NeverHillary', 2), ('TrumpPence16', 1), ('CCOT', 1), ('Trump', 1), ('1A', 1)]
# #################
# #################
# 470
# [('trumptaxes', 1), ('Clinton', 1), ('trump', 1), ('ImWithHer', 1), ('HillaryBecause', 1)]
# #################
# #################
# 473
# [('Trump', 3), ('TrumpTapes', 2), ('ExplainYourVote', 2), ('DangerousDonnie', 1), ('NeverTrump', 1)]
# #################
# #################
# 475
# [('RhodeIsland', 4), ('Vetted', 4), ('Trump', 4), ('America1st', 4), ('IMMIGRATION', 4)]
# #################
# #################
# 476
# [('icanhazPulitzernow', 1), ('clinton', 1), ('TRUMP', 1), ('Trumpin1word', 1), ('trump', 1)]
# #################
# #################
# 477
# [('Trump', 25), ('PodestaEmails9', 17), ('MAGA', 14), ('HillaryGropedMe', 11), ('Hillary', 9)]
# #################
# #################
# 478
# [('Trump', 2), ('PodestaEmails', 2), ('Crooked', 1), ('PodestaEmails9', 1), ('IntelGroup', 1)]
# #################
# #################
# 479
# [('p2', 2), ('Trump', 2), ('TopProg', 1), ('LockHimUp', 1), ('ClimateChange', 1)]
# #################
# #################
# 481
# ...
# #################
# #################
# 705
# [('HillaryGropedMe', 4), ('PodestaEmails9', 3), ('HillaryGropedMeToo', 2), ('PodestaEmails', 2), ('SundayFunday', 1)]
# #################
# #################
# 711
# [('MAGA', 12), ('SundayMorning', 1), ('MAGA3X', 1), ('LatinosWithTrump', 1), ('DC', 1)]
# #################
# #################
# 712
# [('ABC', 1), ('Sundayfunday', 1), ('Hillary', 1), ('NFLSUNDAY', 1), ('CNN', 1)]
# #################
# #################
# 713
# [('Trump', 4), ('NeverTrump', 2), ('PodestaEmails9', 2), ('UniteBlue', 1), ('WomenWhoVoteTrump', 1)]
# #################
# #################
# 720
# [('MAGA', 2), ('AmericaFirst', 1), ('FoxReport', 1), ('TrumpPence16', 1), ('ChooChoo', 1)]
# #################
# #################
# 722
# [('ClintonScandals', 1), ('Trump', 1), ('Hillary', 1), ('Oops', 1), ('BananaRepublic', 1)]
# #################
# #################
# 723
# [('UkraineSpring', 1), ('PodestaEmails9', 1), ('RosebudElection', 1), ('RiggedMedia', 1), ('RiggedElection', 1)]
# #################
# #################
# 724
# [('media', 7), ('think', 3), ('blaze', 2), ('Brexit', 1), ('loser', 1)]
# #################
# #################
# 725
# [('PodestaEmails9', 25), ('HillaryGropedMe', 6), ('Hillary', 5), ('SundayMorning', 5), ('Trump', 5)]
# #################
# #################
# 726
# [('ImWithHer', 3), ('p2', 2), ('SolidArgument', 1), ('HillaryClinton', 1), ('tcot', 1)]
# #################
# #################
# 728
# [('Trump', 6), ('America', 4), ('bluehand', 2), ('Wikileaks', 2), ('NAFTA', 1)]
# #################
# #################
# 730
# [('NeverTrump', 2), ('tcot', 1), ('VoteKirkpatrick', 1), ('sotu', 1), ('ClintonKaine2016', 1)]
# #################
# #################
# 731
# [('Trump', 14), ('HillaryClinton', 2), ('DonaldTrump', 2), ('podestaemails9', 2), ('podestaemails8', 2)]
# #################
# #################
# 732
# [('MAGA', 3), ('Wikileaks', 2), ('Trump', 2), ('NeverHillary', 2), ('TeamTrump', 1)]
# #################
# #################
# 736
# [('womenwillstoptrump', 1), ('StayWoke', 1), ('Trump', 1), ('100YearsStrong', 1), ('Wikileaks', 1)]
# #################
# #################
# 738
# [('Trump', 6), ('debate', 2), ('Hillary', 2), ('MAGA', 2), ('trump', 1)]
# #################
# #################
# 740
# [('HillaryClinton', 2), ('Hillary', 2), ('tcot', 2), ('Trump', 2), ('CrookedHillary', 2)]
# #################
# #################
# 743
# [('ClintonBodyCount', 1), ('PodestaEmails8', 1), ('PodestaEmails7', 1), ('Trump', 1), ('DNC', 1)]
# #################
# #################
# 744
# [('PodestaEmails9', 4), ('MAGA', 3), ('TrumpPence16', 1), ('PodestaEmails7', 1), ('PodestaEmails6', 1)]
# #################
# #################
# 745
# [('PodestaEmails', 5), ('MAGA', 5), ('Clinton', 5), ('ImWithHer', 3), ('SundayMorning', 3)]
# #################
# #################
# 746
# [('SundayMorning', 1), ('HillaryEmails', 1), ('TrumpPence2016', 1), ('Trump', 1), ('Clinton', 1)]
# #################
# #################
# 749
# [('p2', 1), ('McMullinFinn', 1), ('NeverTrump', 1), ('HillaryGropedMe', 1), ('VoteYourConscience', 1)]
# #################
# #################
# 753
# [('Trump', 13), ('trump', 2), ('USPresidentialDebate', 1), ('NeverTrump', 1), ('thisweek', 1)]
# #################
# #################
# 756
# [('Trump', 3), ('TrumpTapes', 2), ('SNL', 2), ('RT', 1), ('Christian', 1)]
# #################
# #################
# 757
# [('Election2016', 3), ('clintonfluffers', 2), ('NeverTrump', 2), ('TrumpPence16', 2), ('wikileaks', 2)]
# #################
# #################
# 758
# [('Canada', 1), ('Trump', 1), ('PodestaEmails9', 1), ('Hillary', 1), ('US', 1)]
# #################
# #################
# 761
# [('DJT', 4), ('ImWithHer', 3), ('NeverTrump', 2), ('Predator', 2), ('DemStorm', 2)]
# #################
# #################
# 764
# [('CrookedHillary', 1), ('tcot', 1), ('Hillary', 1), ('GaysforTrump', 1), ('CrookedMedia', 1)]
# #################
# #################
# 768
# [('Trump', 2), ('HillaryGropedMe', 2), ('HILLARY', 2), ('HillaryClinton', 1), ('USA', 1)]
# #################
# #################
# 770
# [('Rapist', 1), ('Trump', 1), ('Predator', 1), ('Sexist', 1), ('Boycott', 1)]
# #################
# #################
# 772
# [('PodestaEmails9', 2), ('diversity', 1), ('reasontovoteforTrump', 1), ('Trump', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 774
# [('Trump', 11), ('MAGA', 3), ('PodestaEmails9', 3), ('poll', 2), ('Election2016', 2)]
# #################
# #################
# 776
# [('MAGA', 6), ('Trump', 6), ('Trump2016', 2), ('MakeAmericaGreatAgain', 2), ('DonaldTrump', 2)]
# #################
# #################
# 778
# [('Trump', 5), ('SNL', 2), ('scary', 1), ('TranslatingTrumpy', 1), ('NEVERTRUMP', 1)]
# #################
# #################
# 779
# [('Trump', 2), ('Hillary', 2), ('Clinton', 1), ('SadHumans', 1), ('LatinosWithTrump', 1)]
# #################
# #################
# 780
# [('TrumpPence16', 3), ('MAGA', 3), ('TrumpTrain', 3), ('Trump', 3), ('NeverTrump', 2)]
# #################
# #################
# 783
# [('Trump', 2), ('PodestaEmails9', 2), ('MAGA', 2), ('CNNSOTU', 2), ('SundayMorning', 1)]
# #################
# #################
# 785
# [('Trump', 6), ('NeverHillary', 5), ('PodestaEmails9', 2), ('SundayMorning', 1), ('HillaryClinton', 1)]
# #################
# #################
# 787
# [('bluehand', 3), ('America', 3), ('BlackTwitter', 2), ('RiggedElection', 1), ('trump', 1)]
# #################
# #################
# 789
# [('Trump', 1), ('WikiLeak', 1), ('NeedyLatinos', 1), ('TrumpPence16', 1), ('Latinos4Trump', 1)]
# #################
# #################
# 790
# [('PodestaEmails9', 8), ('MAGA', 7), ('Hillary', 5), ('Wikileaks', 5), ('TrumpTrain', 5)]
# #################
# #################
# 793
# [('SundayMorning', 1), ('trump', 1), ('TrumpTapes', 1), ('PodestaEmails9', 1), ('GOPRapeCulture', 1)]
# #################
# #################
# 794
# [('Wikileaks', 6), ('Debate', 3), ('PodestaEmails10', 2), ('Trump', 2), ('Clinton', 1)]
# #################
# #################
# 795
# [('MAGA', 3), ('Clinton', 2), ('PodestaEmails9', 2), ('Brexit', 1), ('Trump', 1)]
# #################
# #################
# 797
# [('MAGA', 5), ('Trump', 5), ('Hillary', 3), ('PodestaEmails9', 3), ('Trump2016', 2)]
# #################
# #################
# 800
# [('Trump', 2), ('WhinyLittleBitch', 2), ('LOSERTRUMP', 2), ('DonaldTrump', 2), ('voteblue', 1)]
# #################
# #################
# 803
# [('Trump', 5), ('MAGA', 2), ('Clinton', 2), ('TrumpPence2016', 1), ('CorruptTrump', 1)]
# #################
# #################
# 805
# [('p2', 2), ('topprog', 2), ('Trump', 2), ('BoycottNordstrom', 2), ('NCPol', 1)]
# #################
# #################
# 813
# [('PodestaEmails9', 13), ('MeetThePress', 7), ('Trump', 4), ('SundayMorning', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 815
# [('EXCLUSIVE', 4), ('Clinton', 4), ('Trump', 4), ('BillClinton', 2), ('biased', 1)]
# #################
# #################
# 817
# [('Papal', 8), ('Pope', 8), ('Trump', 6), ('TRUMP', 3), ('GOP', 2)]
# #################
# #################
# 820
# [('NuclearNightmare', 2), ('NorthKoreanKOOK', 2), ('DonTheThinSkinnedCON', 2), ('StarWars', 1), ('ohwait', 1)]
# #################
# #################
# 821
# [('PodestaEmails9', 3), ('AmericaFirst', 2), ('TrumpPence16', 2), ('MAGA', 2), ('girlpower', 1)]
# #################
# #################
# 822
# [('MAGA', 2), ('TrumpPence16', 1), ('WomenWhoVoteTrump', 1), ('FollowTheMoney', 1), ('NeverHillary', 1)]
# #################
# #################
# 828
# [('Trump', 4), ('RINOS', 2), ('Globalist', 2), ('CrookedHillary', 2), ('HillaryBecause', 2)]
# #################
# #################
# 830
# [('Trump', 2), ('PodestaEmails9', 2), ('TrumpPence16', 2), ('Wikileaks', 2), ('MAGA3X', 2)]
# #################
# #################
# 831
# [('Trump', 10), ('NeverHillary', 4), ('Hillary', 3), ('MAGA', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 834
# [('trumpismplusinmypants', 1), ('Trump', 1), ('imwithher', 1), ('Hillary', 1), ('USElection', 1)]
# #################
# #################
# 835
# [('PodestaEmails9', 2), ('HillaryGropedMe', 2), ('SundayMorning', 1), ('HillaryClinton', 1), ('Clinton', 1)]
# #################
# #################
# 836
# [('Clinton', 1), ('Trump', 1), ('Jacinallhonesty', 1), ('InvestYourVote', 1), ('PodestaEmails', 1)]
# #################
# #################
# 839
# [('TeamTrump', 1), ('HillaryClinton', 1), ('debates', 1), ('PodestaEmails9', 1), ('debate', 1)]
# #################
# #################
# 840
# [('TrumpCheck', 5), ('PodestaEmails9', 3), ('HillaryGropedMe', 2), ('WhinyLittleBitch', 1), ('PodestaEmails8', 1)]
# #################
# #################
# 842
# [('PodestaEmails9', 1), ('CARvsNO', 1), ('VoteTrump', 1), ('Wikeleaks', 1), ('Trump', 1)]
# #################
# #################
# 843
# [('MAGA', 3), ('HillaryClinton', 2), ('Trump', 2), ('MAGA3X', 1), ('Debate', 1)]
# #################
# #################
# 846
# [('PodestaEmails9', 6), ('MAGA', 4), ('Trump', 3), ('GOPBombing', 3), ('HillaryClinton', 2)]
# #################
# #################
# 848
# [('TrumpSupporters', 1), ('Trump', 1), ('SNL', 1), ('NeverHas', 1), ('sad', 1)]
# #################
# #################
# 850
# [('Trump', 5), ('TrumpPence16', 1), ('Trump2016', 1), ('Georgia', 1), ('TRUMP', 1)]
# #################
# #################
# 853
# [('Welfarefortherich', 1), ('MSM', 1), ('Systemriggedfortherich', 1), ('debate', 1), ('Trump', 1)]
# #################
# #################
# 858
# [('Trump', 5), ('HillaryGropedMe', 3), ('MainstreamVsSocialMedia', 2), ('NeverHillary', 2), ('MAGA', 2)]
# #################
# #################
# 860
# [('UniteBlue', 3), ('GOPMustGo', 1), ('MAGA', 1), ('NeverTrump', 1), ('SNL', 1)]
# #################
# #################
# 861
# [('Trump', 3), ('Hillary2016', 1), ('Putin', 1), ('Clinton', 1), ('SNL', 1)]
# #################
# #################
# 864
# [('Georgia', 1), ('Hypocrisy', 1), ('NeedyLatinos', 1), ('ImWithHer', 1), ('TruePundit', 1)]
# #################
# #################
# 865
# [('Trump2016', 4), ('MakeAmericaGreatAgain', 3), ('TrumpTrain', 3), ('Wikileaks', 2), ('Time', 2)]
# #################
# #################
# 870
# [('AmericaKnows', 1), ('DNCleak', 1), ('Clinton', 1), ('Trump', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 871
# [('PodestaEmails9', 2), ('sundaymorning', 1), ('PodestaEmails', 1), ('ClintonEmails', 1), ('Wikileaks', 1)]
# #################
# #################
# 872
# [('PodestaEmails9', 4), ('CrookedHillaryPaidTrolls', 1), ('WorldWar3', 1), ('Wikeleaks', 1), ('crookedhillary', 1)]
# #################
# #################
# 873
# [('trump', 5), ('NEVERTRUMP', 1), ('Pence', 1), ('hillary', 1), ('NeverTrumpNeverHillary', 1)]
# #################
# #################
# 874
# [('biased', 1), ('TrumpTrain', 1), ('McMullinFin', 1), ('PJNET', 1), ('Trump2016', 1)]
# #################
# #################
# 876
# [('TeamTrump', 1), ('GrossMedia', 1), ('Trump2016', 1), ('NastyBillAndHill', 1), ('NeverHillary', 1)]
# #################
# #################
# 879
# [('PodestaEmails9', 6), ('MAGA', 5), ('Trump', 5), ('NeverHillary', 4), ('USA', 2)]
# #################
# #################
# 881
# [('Trump', 3), ('CrookedHillary', 3), ('Trump2016', 2), ('debate', 2), ('HillaryClinton', 1)]
# #################
# #################
# 886
# [('NeverTrump', 1), ('Trump', 1), ('freedom', 1), ('bigly', 1), ('abortion', 1)]
# #################
# #################
# 888
# [('Trump', 1), ('TrumpCheck', 1), ('TerrifyingTrump', 1), ('100YearsStrong', 1), ('TrumpsterFire', 1)]
# #################
# #################
# 890
# [('SNL', 2), ('icanhazPulitzernow', 1), ('TrumpFatigue', 1), ('loser', 1), ('whiner', 1)]
# #################
# #################
# 892
# [('Clinton', 1), ('Trump', 1), ('PodestaEmails9', 1), ('wikileakemails', 1), ('Debate', 1)]
# #################
# #################
# 893
# [('TrumpTapes', 1), ('100YearsStrong', 1), ('TrumpPence16', 1), ('TrumpCheck', 1), ('rigged', 1)]
# #################
# #################
# 895
# [('Hillary2016', 3), ('HillYes', 3), ('VoteBlue', 3), ('ImWithHer', 2), ('HFA', 2)]
# #################
# #################
# 897
# [('Trump', 4), ('WA', 1), ('ak', 1), ('WI', 1), ('WV', 1)]
# #################
# #################
# 898
# [('Obama', 2), ('Soros', 1), ('1A', 1), ('HillaryBecause', 1), ('2A', 1)]
# #################
# #################
# 899
# [('Undecidedvoter', 1), ('CCOT', 1), ('Trump', 1), ('realtalk', 1), ('stupidDOPE', 1)]
# #################
# #################
# 903
# [('Trump', 3), ('TrumpPence16', 3), ('PodestaEmails9', 2), ('neverhillary', 2), ('maga3x', 1)]
# #################
# #################
# 904
# [('MAGA', 3), ('NeverHillary', 2), ('Trump', 2), ('TLOT', 1), ('1A', 1)]
# #################
# #################
# 906
# [('PodestaEmails9', 3), ('trump', 2), ('RiggedSystem', 2), ('MAGA3X', 2), ('ClintonNewsNetwork', 1)]
# #################
# #################
# 908
# [('MAGA', 8), ('TeamTrump', 7), ('Trump', 7), ('TrumpPence16', 7), ('TrumpTrain', 7)]
# #################
# #################
# 910
# [('SundayMorning', 1), ('HillaryClinton', 1), ('TRUMP', 1), ('RobertDeNiro', 1), ('KellyFile', 1)]
# #################
# #################
# 912
# [('PodestaEmails9', 5), ('Trump', 3), ('HillaryClinton', 2), ('100YearsStrong', 1), ('HillaryBecause', 1)]
# #################
# #################
# 915
# [('PodestaEmails9', 2), ('Reflection', 1), ('ImWithHer', 1), ('VoteBlue', 1), ('HillaryBecause', 1)]
# #################
# #################
# 917
# [('TrumpEffect', 1), ('p2', 1), ('SNL', 1), ('VotingRights', 1), ('GOP', 1)]
# #################
# #################
# 921
# [('MAGA', 5), ('Trump', 4), ('TrumpTrain', 3), ('NCGOPHeadquarters', 3), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 926
# [('SHOWUSYOURTRUMP', 2), ('Trump', 2), ('HillaryBecause', 2), ('PodestaEmails', 2), ('MAGA', 2)]
# #################
# #################
# 927
# [('Trump', 14), ('HillaryClinton', 3), ('GOP', 3), ('TrumpTapes', 2), ('HillaryBecause', 2)]
# #################
# #################
# 929
# [('Trump', 4), ('PodestaEmails9', 4), ('Crooked', 1), ('scared', 1), ('Trump2016', 1)]
# #################
# #################
# 932
# [('Trump', 2), ('HillaryClinton', 1), ('Sisi', 1), ('RealityisSurreal', 1), ('justice', 1)]
# #################
# #################
# 933
# [('comtntests', 1), ('dementia', 1), ('media', 1), ('winner', 1), ('loser', 1)]
# #################
# #################
# 935
# [('PodestaEmails', 2), ('SundayMorning', 1), ('TCOT', 1), ('Crooked', 1), ('2A', 1)]
# #################
# #################
# 937
# [('Trump2016', 3), ('Trump', 3), ('MAGA', 3), ('PodestaEmails9', 2), ('Debate', 1)]
# #################
# #################
# 939
# [('MAGA', 5), ('Trump', 5), ('AmericaFirst', 2), ('HillaryBecause', 2), ('trump', 1)]
# #################
# #################
# 942
# [('VoteTrumpPence16', 1), ('Arizona', 1), ('Clinton', 1), ('TRUMP', 1), ('nohyphenatedAmericans', 1)]
# #################
# #################
# 944
# [('TRUMP', 2), ('PodestaEmails9', 2), ('tcot', 2), ('Hillary', 2), ('p2', 1)]
# #################
# #################
# 946
# [('TrumpPence16', 3), ('Trump', 2), ('debate', 2), ('AmericaFirst', 1), ('USA', 1)]
# #################
# #################
# 948
# [('Wikileaks', 1), ('HillaryClinton', 1), ('StopGlobalization', 1), ('MSMsucks', 1), ('NoMoreWAR', 1)]
# #################
# #################
# 951
# [('PodestaEmails', 2), ('TeamTrump', 1), ('JamesWoods', 1), ('CLINTON', 1), ('Trump', 1)]
# #################
# #################
# 952
# [('Trump', 2), ('PodestaEmails9', 2), ('icanhazPulitzernow', 1), ('NeverTrump', 1), ('Romney', 1)]
# #################
# #################
# 955
# [('PodestaEmails', 1), ('bernieorbust', 1), ('demexit', 1), ('0Sale', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 957
# [('fascist', 2), ('Trump', 2), ('sniff', 1), ('TrumpTapes', 1), ('AMJoy', 1)]
# #################
# #################
# 958
# [('NeverHillary', 5), ('GOPe', 2), ('BernieforTrump', 1), ('ClintonEmails', 1), ('Bernie', 1)]
# #################
# #################
# 959
# [('NeverTrump', 1), ('HillYes', 1), ('VoteYourFuture', 1), ('FlipItDem', 1), ('ImWithHer', 1)]
# #################
# #################
# 963
# [('clinton', 1), ('Trump', 1), ('2016election', 1), ('Utah', 1), ('TrumpCheck', 1)]
# #################
# #################
# 964
# [('SundayMorning', 3), ('Election2016', 3), ('SNL', 2), ('AmericaFirst', 1), ('Corruption', 1)]
# #################
# #################
# 967
# [('OrangeBuffoon', 1), ('Republicans', 1), ('Black', 1), ('usa', 1), ('Election2016', 1)]
# #################
# #################
# 968
# [('Hillary', 1), ('crookedHillary', 1), ('breaking', 1), ('saints', 1), ('RIPJournalism', 1)]
# #################

# %%
mention_cluster_counter = Counter()
for user in user_to_cluster:
    mention_cluster_counter[user_to_cluster[user]] += 1
    
print "mention network top 3 biggest cluster sizes"
print mention_cluster_counter.most_common(3)
    
retweet_cluster_counter = Counter()

for user in user_to_cluster_retweet:
    retweet_cluster_counter[user_to_cluster_retweet[user]] += 1
    
print "retweet network top 3 biggest cluster sizes"
print retweet_cluster_counter.most_common(3)

replies_cluster_counter = Counter()

for user in user_to_cluster_replies:
    replies_cluster_counter[user_to_cluster_replies[user]] += 1
    
print "replies network top 3 biggest cluster sizes"
print replies_cluster_counter.most_common(3)
# Out:
# mention network top 3 biggest cluster sizes
# [(0, 147798), (1, 2334), (93, 2043)]
# retweet network top 3 biggest cluster sizes
# [(1, 57106), (0, 47981), (3, 2370)]
# replies network top 3 biggest cluster sizes
# [(1, 27116), (4, 3505), (44, 766)]
