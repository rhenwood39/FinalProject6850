# %%
ls
# Out:
# PLaw.ipynb             mentions_clust.txt     replies_randhist.png
# PopHashtags.ipynb      mentions_randhist.png  retweet.txt
# hashtags.txt           replies.txt            retweet_analysis.txt
# mentions.txt           replies_analysis.txt   retweet_clust.txt
# mentions_analysis.txt  replies_clust.txt      retweet_randhist.png

# %%
from collections import Counter
hashtags_per_person = {} 
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        hashtag = split_line[1]
        if user_id not in hashtags_per_person:
            hashtags_per_person[user_id] = Counter()
        hashtags_per_person[user_id][hashtag] += 1

# %%
user_to_cluster = {} 
with open('mentions_clust.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        cluster_id = int(split_line[1])
        user_id = int(split_line[0])
        user_to_cluster[user_id] = cluster_id

# %%
counter_per_cluster = {}
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        if user_id not in user_to_cluster:
            continue
        hashtag = split_line[1]
        cluster_id = user_to_cluster[user_id]
        
        if cluster_id not in counter_per_cluster:
            counter_per_cluster[cluster_id] = Counter()
        counter_per_cluster[cluster_id][hashtag] += 1

# %%
# for mentions
for cluster in counter_per_cluster:
    most_common = counter_per_cluster[cluster].most_common(5)
    if len(most_common) < 5:
        continue
    print "#################"
    print cluster
    print most_common
    print "#################"
# Out:
# #################
# 0
# [('Trump', 16638), ('MAGA', 9833), ('PodestaEmails9', 7028), ('HillaryGropedMe', 4460), ('Hillary', 4307)]
# #################
# #################
# 1
# [('WomenWhoVoteTrump', 7), ('RepealThe19th', 3), ('Election2016', 3), ('CounterStrikeGlobalOffensive', 1), ('triggered', 1)]
# #################
# #################
# 2
# [('Snap_Politics', 198), ('washingtonpost', 179), ('Reuters', 87), ('WSJ', 52), ('CNN', 52)]
# #################
# #################
# 5
# [('Election2016', 3), ('ImWithHer', 3), ('OMFCM', 3), ('trump', 2), ('NeverHillary', 2)]
# #################
# #################
# 7
# [('Trump', 1), ('EnoughisEnough', 1), ('ImWithHer', 1), ('traitor', 1), ('stuffmydadtaughtme', 1)]
# #################
# #################
# 8
# [('Trump', 8), ('Election2016', 5), ('100YearsStrong', 2), ('IceCreamConvos', 2), ('OITNB', 2)]
# #################
# #################
# 13
# [('Trump', 4), ('Uber', 1), ('Google', 1), ('USA', 1), ('ToriesOut', 1)]
# #################
# #################
# 16
# [('breakdown', 1), ('WomenCanStopTrump', 1), ('fact', 1), ('awesome', 1), ('immolation', 1)]
# #################
# #################
# 20
# [('Trump', 550), ('ImWithHer', 19), ('Election2016', 15), ('Hillary', 12), ('Taxes', 10)]
# #################
# #################
# 2070
# [('Trump', 13), ('xenophobia', 13), ('WitneyByElection', 3), ('Equality', 1), ('LGBT', 1)]
# #################
# #################
# 26
# [('trumpismplusinmypants', 1), ('Trump', 1), ('twitter', 1), ('Hillary', 1), ('DonaldTrump', 1)]
# #################
# #################
# 27
# [('Election2016', 7), ('Trump', 2), ('LGBT', 2), ('GameofThrones', 1), ('TheAnswerIsUs', 1)]
# #################
# #################
# 28
# [('sastorms', 3), ('Election2016', 3), ('Regina', 2), ('VoteDonaldson', 2), ('vote', 2)]
# #################
# #################
# 30
# [('Trump', 3), ('SNL', 2), ('ImWithHer', 1), ('HillaryBecause', 1), ('WRONG', 1)]
# #################
# #################
# 31
# [('100YearsStrong', 2), ('SundayMorning', 1), ('RapeCulture', 1), ('Feminists', 1), ('JillStein2016', 1)]
# #################
# #################
# 35
# [('whinylittlebitch', 1), ('NuclearNightmare', 1), ('BreakingNews', 1), ('dumptrump', 1), ('Imwithher', 1)]
# #################
# #################
# 36
# [('satire', 4), ('debate', 4), ('election2016', 4), ('thirdparty', 3), ('dystopian', 2)]
# #################
# #################
# 40
# [('vtmnieuws', 1), ('vrtnieuws', 1), ('Clinton', 1), ('Trump', 1), ('Mondelenvers', 1)]
# #################
# #################
# 348
# [('QueNoSeTePase', 4), ('NoEsBroma', 3), ('Video', 2), ('Enterate', 2), ('WhyWomanDontReport', 1)]
# #################
# #################
# 44
# [('TrumpTrain', 5), ('MakeAmericaGreatAgain', 4), ('TrumpForPresident', 2), ('MSM', 2), ('Trump', 2)]
# #################
# #################
# 48
# [('nevertrump', 1), ('Trump', 1), ('yourapig', 1), ('lovenothate', 1), ('TrumpTrain', 1)]
# #################
# #################
# 49
# [('HILLARY', 158), ('TRUMP', 145), ('CLINTON', 80), ('AXELROD', 68), ('DEBATE', 68)]
# #################
# #################
# 56
# [('Obama4Life', 2), ('boycottpaypal', 1), ('FuckElection2k16', 1), ('100YearsStrong', 1), ('Election2016', 1)]
# #################
# #################
# 57
# [('Election2016', 4), ('SNL', 2), ('muniland', 2), ('TIDALX1015', 1), ('ImWithHer', 1)]
# #################
# #################
# 62
# [('Trump', 1), ('SNL', 1), ('sexualassault', 1), ('vote', 1), ('Donald', 1)]
# #################
# #################
# 63
# [('HILLARY2016', 3), ('TRUMP', 2), ('Hillary2016', 1), ('tcot', 1), ('FUNNY', 1)]
# #################
# #################
# 65
# [('Election2016', 757), ('BoycottPaypal', 1), ('PassionateEye', 1), ('SNL', 1), ('PayPal', 1)]
# #################
# #################
# 70
# [('TrumpNo', 1), ('Trump', 1), ('TYbravewomen', 1), ('SNL', 1), ('ImWithHer', 1)]
# #################
# #################
# 71
# [('Trump', 3), ('ImWithHer', 2), ('AlecBaldwin2016', 1), ('TrumpCheck', 1), ('boycottpaypal', 1)]
# #################
# #################
# 74
# [('cdnpoli', 2), ('Trump', 1), ('SNL', 1), ('ImWithHer', 1), ('MAGA', 1)]
# #################
# #################
# 82
# [('Election2016', 3), ('ImWithHer', 2), ('getinformation', 1), ('WomenWhoVoteTrump', 1), ('TrumpInDallas', 1)]
# #################
# #################
# 83
# [('Election2016', 5), ('ImWithHer', 4), ('LetMeStay', 2), ('factstho', 1), ('Trump', 1)]
# #################
# #################
# 2138
# [('hillaryclinton', 1), ('Trump', 1), ('mychannel', 1), ('smallyoutuber', 1), ('subscribe', 1)]
# #################
# #################
# 2143
# [('trump', 1), ('Debate', 1), ('ImWithHer', 1), ('debate', 1), ('AMAs', 1)]
# #################
# #################
# 96
# [('TerrifyingTrump', 47), ('Trump', 7), ('SaturdayNightLive', 5), ('TrumpSorrogates', 3), ('CNN', 3)]
# #################
# #################
# 99
# [('Election2016', 4), ('WomenWarriors', 1), ('electionburnout', 1), ('HindusforTrump', 1), ('ImWithHer', 1)]
# #################
# #################
# 2406
# [('boycottpaypal', 9), ('narcissists', 1), ('NeverTrump', 1), ('Trump', 1), ('humour', 1)]
# #################
# #################
# 105
# [('Election2016', 2), ('p2', 1), ('FeelTheBern', 1), ('UniteBlue', 1), ('ImWithHer', 1)]
# #################
# #################
# 2156
# [('RT', 1), ('Brexit', 1), ('SaySomethingCompletelyHonest', 1), ('Democracy', 1), ('Like', 1)]
# #################
# #################
# 111
# [('WomenCanStopTrump', 76), ('RISE', 2), ('benghazi', 1), ('votehillary', 1), ('FlyEaglesFly', 1)]
# #################
# #################
# 112
# [('debatenight', 2), ('TrumpTrain', 1), ('SundayMorning', 1), ('TrumpForPresident', 1), ('TrumpSucks', 1)]
# #################
# #################
# 2408
# [('Clinton', 1), ('Trump', 1), ('cyber', 1), ('ClintonEmails', 1), ('hacking', 1)]
# #################
# #################
# 115
# [('deplorable', 2), ('HillaryClinton', 1), ('Trump', 1), ('voters', 1), ('turnup', 1)]
# #################
# #################
# 117
# [('whiteboymagic', 18), ('trump', 3), ('fungshui', 3), ('election2016', 3), ('WhiteBoyMagic', 1)]
# #################
# #################
# 122
# [('Clinton', 76), ('Daesh', 7), ('Trump', 6), ('Jupp', 6), ('US', 3)]
# #################
# #################
# 125
# [('Election2016', 3), ('WhatsWrongWithAmerica', 2), ('WhyWomenDontReport', 2), ('LockerRoomTalk', 1), ('Irony', 1)]
# #################
# #################
# 135
# [('ModisInnovativeDiplomacy', 15), ('UriAttacks', 5), ('Mensday19Nov', 3), ('AbkiBaarTrumpSarkaar', 2), ('Mind_it', 1)]
# #################
# #################
# 2187
# [('Clinton', 8), ('Trump', 8), ('Hillary', 8), ('Debate', 3), ('MAGA', 3)]
# #################
# #################
# 144
# [('ImWithHer', 3), ('debate', 2), ('Election2016', 2), ('WomenWhoVoteTrump', 1), ('Trump', 1)]
# #################
# #################
# 159
# [('Trump', 8), ('Clinton', 6), ('Mxico', 3), ('WikiLeaks', 3), ('Ficrea', 3)]
# #################
# #################
# 169
# [('Wikileaks', 2), ('Trump', 2), ('MAGA3X', 1), ('PodestaEmails9', 1), ('RiggedSystem', 1)]
# #################
# #################
# 179
# [('NeverTrump', 1), ('YesEveryWoman', 1), ('WasteHisTime2016', 1), ('TrumpPence16', 1), ('TrumpCheck', 1)]
# #################
# #################
# 189
# [('HindusForTrump', 2), ('Grabthembythe', 1), ('ProudTrumpKakaFan', 1), ('WalterRobinson', 1), ('religious', 1)]
# #################
# #################
# 206
# [('MakeSNLGreatAgain', 2), ('SNL', 1), ('LEMONADE', 1), ('ImWithHer', 1), ('1A', 1)]
# #################
# #################
# 208
# [('NarendraTrumpLIVE', 4), ('Trump', 1), ('Breaking', 1), ('HindusForTrump', 1), ('JustAsking', 1)]
# #################
# #################
# 215
# [('PodestaEmails9', 2), ('maga', 2), ('brexit', 1), ('Trump', 1), ('RapeCulture', 1)]
# #################
# #################
# 217
# [('ThingsTrumpClaimsRigged', 2), ('totalblowoutcoming', 1), ('nevertrump', 1), ('Trump', 1), ('disqualifying', 1)]
# #################
# #################
# 226
# [('PanamaPapers', 2), ('wearehismedia', 2), ('JillNotHill', 1), ('NeverHillary', 1), ('Demexit', 1)]
# #################
# #################
# 236
# [('trump', 183), ('dumptrump', 106), ('debates', 106), ('IAmWithHer', 53), ('Ciao', 44)]
# #################
# #################
# 238
# [('Trump', 10), ('jorgeramosnews', 4), ('HispanicHeritageMonth', 3), ('SundayMorning', 1), ('Fed', 1)]
# #################
# #################
# 244
# [('ImWithHer', 6), ('Trump', 5), ('BatmanVSuperman', 3), ('MakeMeSmileIn3Words', 2), ('100YearsStrong', 2)]
# #################
# #################
# 251
# [('ImWithHer', 3), ('Clinton', 2), ('trump', 2), ('TrumpPence16', 2), ('zerotoleranceforhate', 1)]
# #################
# #################
# 256
# [('Trump', 19), ('NewHampshire', 2), ('MediasVendus', 2), ('Clinton', 1), ('DANGER', 1)]
# #################
# #################
# 258
# [('Trump', 4), ('India', 2), ('IndianElectio', 1), ('I', 1), ('ModisInnovativeDiplomacy', 1)]
# #################
# #################
# 262
# [('NopetoTrump', 6), ('ImWithHer', 5), ('nopetotrump', 2), ('likea5yearold', 1), ('GameofThrones', 1)]
# #################
# #################
# 264
# [('Trump', 1), ('indyref', 1), ('SNP', 1), ('SNP16', 1), ('MAGA', 1)]
# #################
# #################
# 270
# [('News', 41), ('Election', 31), ('Politics', 31), ('Hillary', 9), ('Clinton', 2)]
# #################
# #################
# 279
# [('Trump', 3), ('Forbes400', 2), ('KellyKatharin', 2), ('whyTrumpLovesPoorlyEducated', 1), ('HillaryClinton', 1)]
# #################
# #################
# 286
# [('Reuters', 3), ('NACIONALES', 3), ('LockHerUp', 1), ('IMPEACHobama', 1), ('PrimeraPgina', 1)]
# #################
# #################
# 293
# [('Eagles', 2), ('eventho', 1), ('livinginLA', 1), ('ImWithHer', 1), ('iamcanadian', 1)]
# #################
# #################
# 304
# [('p2', 1), ('trump', 1), ('tcot', 1), ('IAccidentallyThrewOut', 1), ('PrisonStrike', 1)]
# #################
# #################
# 311
# [('DJMissGem', 1), ('Celeb', 1), ('AHS', 1), ('djmissgem', 1), ('Social', 1)]
# #################
# #################
# 316
# [('Sunday', 2), ('UnusualWords', 2), ('Trump', 2), ('XFactor', 2), ('Hillary', 1)]
# #################
# #################
# 318
# [('Trump', 5), ('election', 4), ('DVAM', 1), ('emotionalabuse', 1), ('gaslighting', 1)]
# #################
# #################
# 323
# [('BoycottPayPal', 47), ('boycottpaypal', 16), ('BoycottPaypal', 6), ('Trump', 4), ('HB2', 3)]
# #################
# #################
# 338
# [('SNL', 57), ('LEMONADE', 49), ('KenBone', 24), ('debates', 20), ('RealTime', 2)]
# #################
# #################
# 339
# [('EaglesTalk', 2), ('CarsonWentz', 1), ('DMCPhiladelphia', 1), ('RedskinsRule', 1), ('JordanMatthews', 1)]
# #################
# #################
# 340
# [('Trump', 2), ('Media', 2), ('ImWithHer', 2), ('p2', 1), ('icanhazPulitzernow', 1)]
# #################
# #################
# 2396
# [('TienesQueVerlo', 3), ('Sonora', 3), ('VIDEO', 2), ('Trump', 1), ('NACIN', 1)]
# #################
# #################
# 351
# [('LGBT', 5), ('Gay', 2), ('AndrewGiuliani', 1), ('gay', 1), ('CarolineGiuliani', 1)]
# #################
# #################
# 355
# [('Election2016', 8), ('NeverEverTrump', 1), ('Trump', 1), ('election2016', 1), ('TrumpTape', 1)]
# #################
# #################
# 364
# [('Trump', 13), ('Hillary', 5), ('Clinton', 4), ('debate', 4), ('tcot', 2)]
# #################
# #################
# 372
# [('ImWithHer', 1917), ('TheTylerOakleyShow', 4), ('debate', 3), ('Election2016', 2), ('100YearsStrong', 1)]
# #################
# #################
# 379
# [('AAP', 6), ('PbElections', 3), ('MPElections', 3), ('RajasthanElections', 3), ('KtkElections', 3)]
# #################
# #################
# 382
# [('ImZentrum', 5), ('Trump', 3), ('pussygate', 2), ('wasgehtbitte', 2), ('athletes', 1)]
# #################
# #################
# 2431
# [('Debate', 2), ('LaughAtTrump', 1), ('SundayMorning', 1), ('hillarygropedme', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 393
# [('Election2016', 2), ('TrumpCheck', 1), ('FIXED', 1), ('WasteHisTime2016', 1), ('100YearsStrong', 1)]
# #################
# #################
# 2443
# [('Trump', 2), ('riggedelection', 1), ('corruptobama', 1), ('Clinton', 1), ('trump', 1)]
# #################
# #################
# 402
# [('Trump', 4), ('ImWithHer', 2), ('Election2016', 2), ('lol', 1), ('freespeech', 1)]
# #################
# #################
# 2453
# [('clinton', 3), ('trump', 3), ('SEO', 3), ('ripple', 3), ('fintech', 3)]
# #################
# #################
# 416
# [('unityforfreedom', 11), ('unionforfreedom', 5), ('UnityForFreedom', 4), ('___', 4), ('_', 4)]
# #################
# #################
# 419
# [('EdBalls', 23), ('Strictly', 23), ('Trump', 6), ('USPresidentialElections', 3), ('c4news', 2)]
# #################
# #################
# 426
# [('GaelGarcaBernal', 1), ('Trump', 1), ('USA', 1), ('Opinin', 1), ('EEUU', 1)]
# #################
# #################
# 430
# [('RiseUpAsOne', 54), ('ImWithHer', 2), ('Jerk', 1), ('PiataTrump', 1), ('PredatorTrump', 1)]
# #################
# #################
# 435
# [('Clinton', 17), ('Trump', 4), ('600pages', 2), ('clown', 1), ('US', 1)]
# #################
# #################
# 2504
# [('EEUU', 3), ('Clinton', 3), ('Rusia', 1), ('Pence', 1), ('Trump', 1)]
# #################
# #################
# 467
# [('LaCasaBianca', 66), ('RaiUsa2016', 16), ('Trump', 14), ('Clinton', 9), ('Sanders', 7)]
# #################
# #################
# 470
# [('Trump', 2), ('NuclearNightmare', 1), ('NorthKoreanKOOK', 1), ('auspol', 1), ('DonTheThinSkinnedCON', 1)]
# #################
# #################
# 474
# [('Trump', 3), ('EuropeGoesUS', 1), ('clinton', 1), ('bodylanguage', 1), ('trump', 1)]
# #################
# #################
# 479
# [('ToryElectionFraud', 3), ('Tory', 2), ('snpfail', 1), ('Conservative', 1), ('toryelectionfraud', 1)]
# #################
# #################
# 491
# [('Republicans', 3), ('GOP', 3), ('NYT', 3), ('CIA', 2), ('cyber', 2)]
# #################
# #################
# 2543
# [('bluegrasslife', 3), ('bluegrass', 3), ('AlisonKrauss', 3), ('Clinton', 3), ('Trump', 3)]
# #################
# #################
# 498
# [('Trump', 4), ('SouthAsiansDumpTrump', 3), ('Dalits', 2), ('Modi', 2), ('SouthasiansDumpTrump', 2)]
# #################
# #################
# 502
# [('EuropeGoesUs', 18), ('EEUU', 1), ('CarolinaDelNorte', 1), ('Trump', 1), ('URGENTE', 1)]
# #################
# #################
# 2559
# [('Paypal', 5), ('Trump', 4), ('paypal', 4), ('boycottpaypal', 4), ('PayPal', 2)]
# #################
# #################
# 518
# [('Trump', 2), ('AKRoarsInGujarat', 2), ('whiteboymagic', 1), ('HillaryClinton', 1), ('USA', 1)]
# #################
# #################
# 2569
# [('auspol', 8), ('uspoli', 8), ('TrumpTrain', 8), ('Trump', 8), ('oops', 8)]
# #################
# #################
# 523
# [('TRUMP', 2), ('HILLARY', 2), ('Fed', 1), ('WashPost', 1), ('CLINTON', 1)]
# #################
# #################
# 2580
# [('Funny', 2), ('Trump', 2), ('LockerRoomTalk', 2), ('NFL', 2), ('Birdgang', 2)]
# #################
# #################
# 2322
# [('PERSONAL', 1), ('ACCOUNTANTS', 1), ('trump', 1), ('FINANCE', 1), ('cpa', 1)]
# #################
# #################
# 573
# [('ForeignMinister', 4), ('US', 4), ('election', 4), ('Russian', 4), ('Lavrov', 4)]
# #################
# #################
# 2623
# [('Brexit', 3), ('wato', 3), ('Tory', 3), ('c4news', 3), ('bbcdp', 3)]
# #################
# #################
# 581
# [('polqc', 20), ('polQc', 2), ('Election2016', 2), ('polUSA', 1), ('Trump', 1)]
# #################
# #################
# 606
# [('SNL', 3), ('edballs', 1), ('trump', 1), ('bansatire', 1), ('LEMONADE', 1)]
# #################
# #################
# 617
# [('HillarysEmails', 4), ('c4news', 4), ('Trump', 4), ('Foghorn', 4), ('TheBitch', 4)]
# #################
# #################
# 2152
# [('vote', 1), ('WikiLeaks', 1), ('MAGA', 1), ('election2016', 1), ('getoutandvote', 1)]
# #################
# #################
# 2677
# [('ImWithHer', 13), ('GameofThrones', 12), ('lovetrumpshate', 12), ('comics', 1), ('SNL', 1)]
# #################
# #################
# 630
# [('VOTE', 19), ('HBCUs4Hillary', 14), ('NC', 14), ('ImWithHer', 14), ('Durham', 14)]
# #################
# #################
# 634
# [('Trump', 3), ('p2', 1), ('tcot', 1), ('potus', 1), ('maga', 1)]
# #################
# #################
# 642
# [('Trump', 7), ('Election2016', 3), ('Clinton', 3), ('Hillary', 2), ('cognitive_dissononce', 2)]
# #################
# #################
# 653
# [('GaryJohnson', 9), ('libertarian', 5), ('JohnsonWeld', 4), ('JohnsonWeld2016', 2), ('MakeAmericaSaneAgain', 2)]
# #################
# #################
# 2707
# [('HillaryGropedMe', 3), ('TrumpTrain', 2), ('ChelseaClinton', 1), ('HillaryClinton', 1), ('Corruption', 1)]
# #################
# #################
# 2159
# [('Trump', 12), ('leadership', 2), ('lockerroom', 2), ('leaders', 1), ('integrity', 1)]
# #################
# #################
# 2719
# [('trump', 53), ('furniture', 53), ('hillary', 42), ('unfit', 42), ('debate', 7)]
# #################
# #################
# 674
# [('EEUU', 3), ('USA', 3), ('LandingPage', 1), ('IntersEnElMundo', 1), ('MovidaEnFacebook', 1)]
# #################
# #################
# 2506
# [('auspol', 2), ('Trump', 1), ('USA', 1), ('financ', 1), ('politics', 1)]
# #################
# #################
# 2165
# [('BoycottPayPal', 16), ('BoycottPaypal', 8), ('PayPal', 2), ('NeverTrump', 1), ('Trump', 1)]
# #################
# #################
# 705
# [('SNL', 2), ('GCPR', 1), ('AP', 1), ('NEWS', 1), ('HEADLINES', 1)]
# #################
# #################
# 708
# [('ImWithHer', 7), ('Election2016', 2), ('Trump', 1), ('LatinosWithTrump', 1), ('GaysforTrump', 1)]
# #################
# #################
# 709
# [('Trump2016', 37), ('Republicans', 37), ('Ebay', 37), ('Democrats', 37), ('SWASTIKA', 37)]
# #################
# #################
# 710
# [('Trump2016', 1), ('Republicans', 1), ('US', 1), ('Ebay', 1), ('Democrats', 1)]
# #################
# #################
# 721
# [('Debat2016', 1), ('polqc', 1), ('Debates2016', 1), ('USA', 1), ('Dbat', 1)]
# #################
# #################
# 729
# [('TheNationOfISRAELnUnbornBabiesIntoConsideration', 7), ('HaveABlessedSONDay', 7), ('WhenYouCastUrVotePut', 7), ('Election2016', 7), ('November8', 7)]
# #################
# #################
# 736
# [('BoycottPayPal', 4), ('taxi', 2), ('con', 2), ('closeyourPayPalaccount', 1), ('Election2016', 1)]
# #################
# #################
# 742
# [('realDonaldTrump', 22), ('LoMasVisto', 4), ('CadenaDeSeguidores', 4), ('backstabber', 1), ('HRC', 1)]
# #################
# #################
# 750
# [('gaysfortrump', 2), ('WomenWhoVoteTrump', 1), ('LGBTQ', 1), ('ImWithHer', 1), ('BoycottPayPal', 1)]
# #################
# #################
# 2515
# [('Trump', 9), ('Clinton', 5), ('M5S', 4), ('Hillary', 4), ('Grillo', 4)]
# #################
# #################
# 759
# [('Trump', 2), ('lifeofauggie', 1), ('Clinton', 1), ('selloutsanders', 1), ('Kansas', 1)]
# #################
# #################
# 774
# [('Clinton', 14), ('US', 11), ('WikiLeaks', 11), ('Trump', 1), ('Chine', 1)]
# #################
# #################
# 776
# [('Chilcot', 1), ('isis', 1), ('trump', 1), ('TerrifyingTrump', 1), ('syria', 1)]
# #################
# #################
# 783
# [('Clinton', 2), ('USA', 2), ('ClintonFoundation', 2), ('Hillary', 2), ('Ethics', 2)]
# #################
# #################
# 2521
# [('clinton', 17), ('trump', 17), ('kenbone', 17), ('jokes', 1), ('vote', 1)]
# #################
# #################
# 2092
# [('HillarysEmails', 1), ('pencenotrump', 1), ('billclinton', 1), ('humanrights', 1), ('droptrump', 1)]
# #################
# #################
# 2868
# [('Russian', 15), ('MindGames', 15), ('hacking', 15), ('Putin', 15), ('US', 15)]
# #################
# #################
# 825
# [('Trump', 3), ('Esquire', 3), ('Election2016', 3), ('HillaryGropedMe', 2), ('wikileaks', 2)]
# #################
# #################
# 853
# [('news', 2), ('Trump', 1), ('USA', 1), ('BBC', 1), ('HilaryClinton', 1)]
# #################
# #################
# 855
# [('podestaemails9', 12), ('SundayMorning', 11), ('Putin', 1), ('US', 1), ('MindGames', 1)]
# #################
# #################
# 866
# [('Witney', 1), ('labourdoorstep', 1), ('smearaday', 1), ('Duncan4Witney', 1), ('WitneyByElection', 1)]
# #################
# #################
# 877
# [('TiSA', 1), ('Clinton', 1), ('Trump', 1), ('Congress', 1), ('PodestaEmails', 1)]
# #################
# #################
# 937
# [('PrisonStrike', 66), ('13th', 5), ('Election2016', 2), ('NeverTrump', 1), ('13thfilm', 1)]
# #################
# #################
# 959
# [('Clinton', 3), ('Sputnik', 3), ('feignant', 2), ('Wilileaks', 2), ('Trump', 1)]
# #################
# #################
# 994
# [('FOLLE', 12), ('burattinaio', 6), ('Soros', 6), ('HitlaryClinton', 6), ('massona', 6)]
# #################
# #################
# 995
# [('Farrakhan', 710), ('HDOA16', 675), ('Election2016', 172), ('Trump', 87), ('Hillary', 73)]
# #################
# #################
# 998
# [('Mundo', 3), ('EU', 2), ('EstadosUnidos', 1), ('Ficrea', 1), ('Mxico', 1)]
# #################
# #################
# 1004
# [('Election2016', 6), ('99cents', 3), ('kindle', 3), ('Amazon', 3), ('RT', 3)]
# #################
# #################
# 1014
# [('Trump', 2), ('Farrakhan', 1), ('Lucifer', 1), ('Hillary', 1), ('HDOA16', 1)]
# #################
# #################
# 1021
# [('Trump', 2), ('Elecciones2016', 2), ('MikePence', 2), ('EEUU', 2), ('EncuestaDLA', 1)]
# #################
# #################
# 1031
# [('Noticias', 3), ('ElPais', 3), ('News', 2), ('Brasil', 1), ('folheando', 1)]
# #################
# #################
# 1055
# [('trending', 21), ('HB', 7), ('hacking', 5), ('cyber', 3), ('Trump', 2)]
# #################
# #################
# 1057
# [('HillaryClinton', 1), ('ImWithHer', 1), ('LaganjaEstranja', 1), ('RPDR', 1), ('100YearsStrong', 1)]
# #################
# #################
# 1060
# [('TrumpPence2016', 1), ('Trump', 1), ('USA', 1), ('MakeAmericaGreatAgain', 1), ('FACT', 1)]
# #################
# #################
# 1071
# [('NYC', 1), ('DonTheThinSkinnedCON', 1), ('Buffalo', 1), ('NorthKoreanKOOK', 1), ('NuclearNightmare', 1)]
# #################
# #################
# 1081
# [('Hillary', 3), ('sondeos', 3), ('Tendencia', 3), ('Clinton', 1), ('Correos', 1)]
# #################
# #################
# 1095
# [('HillaryClinton', 7), ('Trump', 7), ('USA', 7), ('dibattito', 7), ('antidroga', 7)]
# #################
# #################
# 2232
# [('rochdale', 2), ('labour', 2), ('salford', 1), ('BNP', 1), ('middleton', 1)]
# #################
# #################
# 1128
# [('NeverTrump', 1), ('Trump', 1), ('CrookedHillary', 1), ('Trumpunists', 1), ('block', 1)]
# #################
# #################
# 1134
# [('IsraeltheRegion', 2), ('Trump', 2), ('JewishTimes', 2), ('polls', 1), ('HillaryClinton', 1)]
# #################
# #################
# 1145
# [('Election2016', 2), ('RentControl', 2), ('Alameda', 2), ('Housing', 2), ('AlamedaVotes', 2)]
# #################
# #################
# 1157
# [('antisemitism', 11), ('UsePens', 1), ('LabourPurge2', 1), ('incredibly', 1), ('Chickencoup', 1)]
# #################
# #################
# 1164
# [('MAGA', 3), ('Trump', 2), ('clinton', 1), ('democracy', 1), ('media', 1)]
# #################
# #################
# 1176
# [('Trump', 19), ('SundayTabloid', 19), ('newyork', 10), ('stutiuniti', 4), ('NewYork', 3)]
# #################
# #################
# 1188
# [('SNL', 2), ('PresidentialDebate', 1), ('LEMONADE', 1), ('NeverTrump', 1), ('WhyWomenDontReport', 1)]
# #################
# #################
# 1194
# [('Trump', 2), ('HillaryClinton', 1), ('Clinton', 1), ('USA', 1), ('dibattito', 1)]
# #################
# #################
# 1203
# [('Trump', 14), ('Wendt', 13), ('Polizei', 13), ('SwingStateTour', 1), ('KopfAufTisch', 1)]
# #################
# #################
# 1207
# [('Trump', 9), ('Clinton', 6), ('Usa2016', 3), ('ClintonBoia', 1), ('giornalistiTerroristi', 1)]
# #################
# #################
# 1229
# [('ImWithHer', 5), ('Election2016', 1), ('PodestaEmails8', 1), ('PUSSYGRABSBACK', 1), ('Debate', 1)]
# #################
# #################
# 1237
# [('WikiLeaks', 1), ('Candidacy', 1), ('Clinton', 1), ('Emails', 1), ('Hacked', 1)]
# #################
# #################
# 1239
# [('Trump', 1), ('notokay', 1), ('whywomendontreport', 1), ('retirewillie', 1), ('williebrown', 1)]
# #################
# #################
# 1246
# [('Trump', 4), ('HinduAmericans', 4), ('Modi', 4), ('USA', 1), ('India', 1)]
# #################
# #################
# 1266
# [('AFP', 17), ('Stop', 1), ('Hillary', 1), ('WakeUpAmerica', 1), ('Trump', 1)]
# #################
# #################
# 1278
# [('NorthKoreanKOOK', 63), ('NuclearNightmare', 63), ('DonTheThinSkinnedCON', 63), ('NeverTrump', 2), ('RapistTrump', 1)]
# #################
# #################
# 1281
# [('CNCNet', 15), ('pjnet', 13), ('rednationrising', 7), ('ccot', 4), ('tcot', 4)]
# #################
# #################
# 1285
# [('HairHeads', 5), ('BaldGuysForHillary', 5), ('My', 5), ('Trump', 5), ('ImWithHer', 5)]
# #################
# #################
# 1290
# [('Trump', 16), ('Sexismus', 4), ('Clinton', 1), ('USA', 1), ('wethepeople', 1)]
# #################
# #################
# 2263
# [('Trump', 5), ('Russia', 3), ('Clinton', 2), ('sinistra', 2), ('sessismo', 1)]
# #################
# #################
# 1295
# [('Trump', 2), ('CleanYourMuteList', 2), ('TrumpPence16', 2), ('MAGA', 2), ('TrumpTrain', 2)]
# #################
# #################
# 1296
# [('nevertrump', 7), ('trump', 7), ('CaptainAmerica', 7), ('art', 7), ('Election2016', 7)]
# #################
# #################
# 1355
# [('Trump', 2), ('USA', 2), ('Dessin', 2), ('election', 2), ('usavotes', 2)]
# #################
# #################
# 1359
# [('bcotqmc', 11), ('Trump', 8), ('Clinton', 6), ('Farage', 2), ('Brexit', 1)]
# #################
# #################
# 1380
# [('AKHT', 2), ('Info', 1), ('actualits', 1), ('Important', 1), ('Belgique', 1)]
# #################
# #################
# 1390
# [('clinton', 7), ('trump', 7), ('hilary', 7), ('vote', 2), ('president', 2)]
# #################
# #################
# 1429
# [('OnikaForPresident2k16', 2), ('HillaryClinton', 1), ('indyre2', 1), ('WomenStopTrumpParty', 1), ('FUCKDONALDTRUMP', 1)]
# #################
# #################
# 1430
# [('IG', 8), ('NEWS', 4), ('FASHION', 2), ('DAILY', 2), ('TRENDS', 2)]
# #################
# #################
# 239
# [('Trump', 3), ('Clown', 1), ('Perplexed', 1), ('HRC', 1), ('grabthembythe', 1)]
# #################
# #################
# 1444
# [('EEUU', 1), ('Elecciones2016', 1), ('EncuestaDLA', 1), ('Trump', 1), ('MikePence', 1)]
# #################
# #################
# 1458
# [('Trump', 5), ('Clinton', 2), ('Elections2016', 2), ('polqc', 1), ('Palin', 1)]
# #################
# #################
# 1464
# [('Video', 5), ('Trump', 2), ('HillaryClinton', 1), ('Clinton', 1), ('Internacional', 1)]
# #################
# #################
# 2635
# [('Trump', 4), ('sondages', 2), ('Clinton', 2), ('USA', 2), ('Prsidentielle', 2)]
# #################
# #################
# 1476
# [('ImWithHer', 3), ('GameofThrones', 2), ('lovetrumpshate', 2), ('NuclearNightmare', 1), ('NorthKoreanKOOK', 1)]
# #################
# #################
# 1485
# [('debates', 8), ('mustwatch', 8), ('Ellen', 8), ('Election2016', 8), ('TrumpTapes', 4)]
# #################
# #################
# 1494
# [('ItWasEvenASong', 1), ('DontEvenTry', 1), ('Melanianade', 1), ('NoBetterMelaniaThanBenanti', 1), ('WasteHisTime2016', 1)]
# #################
# #################
# 1501
# [('13h15', 4), ('Trump', 4), ('Hollande', 4), ('PrimaireLeDebat', 4), ('Trierweiler', 4)]
# #################
# #################
# 1511
# [('Putin', 2), ('Russia', 2), ('MQMatGround', 1), ('Trump', 1), ('Encryption', 1)]
# #################
# #################
# 1512
# [('Syria', 9), ('Clinton', 6), ('rebels', 4), ('Taliban', 4), ('Emails', 2)]
# #################
# #################
# 2643
# [('vtpoli', 2), ('dumptrump', 1), ('vtdems', 1), ('VT', 1), ('vtgop', 1)]
# #################
# #################
# 1564
# [('AFP', 10), ('Trump', 7), ('Hillary', 6), ('GoldmanSachs', 5), ('USElection', 5)]
# #################
# #################
# 1565
# [('FOLLE', 2), ('HillaryClinton', 1), ('Trump', 1), ('USA', 1), ('dibattito', 1)]
# #################
# #################
# 1633
# [('tcot', 2), ('terrorism', 1), ('NorthCarolina', 1), ('NeverTrump', 1), ('DonaldTrump', 1)]
# #################
# #################
# 1697
# [('LPC', 3), ('elxn42', 3), ('medhat', 2), ('LittleNewt', 1), ('RealChangeAtWork', 1)]
# #################
# #################
# 625
# [('golf', 1), ('trump', 1), ('turnberry', 1), ('muggles', 1), ('theopen', 1)]
# #################
# #################
# 1770
# [('Clinton', 1), ('stopwhining', 1), ('tax', 1), ('ImWithHer', 1), ('Clarify', 1)]
# #################
# #################
# 1773
# [('trump', 2), ('buitenhof', 2), ('hillary', 2), ('koningshuis', 1), ('Trump', 1)]
# #################
# #################
# 2349
# [('WarrenBuffett', 16), ('HillaryClinton', 5), ('DonaldTrump', 3), ('Trump', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 1811
# [('NoProp60', 11), ('Election2016', 11), ('California', 7), ('Vote', 3), ('Prop60', 1)]
# #################
# #################
# 1813
# [('Trump', 1), ('SundayScrum', 1), ('liberallover', 1), ('disappointing', 1), ('sundayscrum', 1)]
# #################
# #################
# 1828
# [('DEATH', 8), ('CLINTON', 8), ('deathsentence', 8), ('YOUNG', 8), ('TEXAS', 8)]
# #################
# #################
# 2508
# [('Trump', 2), ('HillaryClinton', 1), ('Clinton', 1), ('Politics', 1), ('Killary', 1)]
# #################
# #################
# 1873
# [('Trump', 2), ('Corbyn', 2), ('duh', 1), ('Piketty', 1), ('globalization', 1)]
# #################
# #################
# 1908
# [('EEUU', 51), ('MundoCurioso', 1), ('Clinton', 1), ('PrimeraPgina', 1), ('Trump', 1)]
# #################
# #################
# 1927
# [('Trump2016', 1), ('NeverTrump', 1), ('ImWithHer', 1), ('FollowTheMoney', 1), ('TeamClinton', 1)]
# #################
# #################
# 1960
# [('notinmyname', 2), ('TerrifyingTrump', 2), ('remain', 2), ('DOH', 1), ('UKIP', 1)]
# #################
# #################
# 1979
# [('politics', 4), ('election', 3), ('Trump', 2), ('evangelical', 1), ('NOW', 1)]
# #################
# #################
# 1982
# [('educhat', 5), ('homeschool', 5), ('edchat', 5), ('parents', 5), ('princhat', 5)]
# #################
# #################
# 1996
# [('Hillary', 9), ('Clinton', 9), ('Trump', 4), ('TRUMP2016', 2), ('Trump2016', 2)]
# #################
# #################
# 2613
# [('Trump', 1), ('AlecBaldwin', 1), ('Hillary', 1), ('AndersonCooper', 1), ('KateMcKinnon', 1)]
# #################
# #################
# 2009
# [('Clinton', 11), ('Trump', 11), ('fucked', 11), ('president', 11), ('Farrakhan', 1)]
# #################
# #################
# 2013
# [('CrookedHillary', 1), ('AmericaFirst', 1), ('Trump', 1), ('3terms', 1), ('AccordingParticipant', 1)]
# #################

# %%
user_to_cluster_retweet = {} 
with open('retweet_clust.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        cluster_id = int(split_line[1])
        user_id = int(split_line[0])
        user_to_cluster_retweet[user_id] = cluster_id

# %%
counter_per_cluster_retweet = {}
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        if user_id not in user_to_cluster_retweet:
            continue
        hashtag = split_line[1]
        cluster_id = user_to_cluster_retweet[user_id]
        
        if cluster_id not in counter_per_cluster_retweet:
            counter_per_cluster_retweet[cluster_id] = Counter()
        counter_per_cluster_retweet[cluster_id][hashtag] += 1

# %%
# for retweet
for cluster in counter_per_cluster_retweet:
    most_common = counter_per_cluster_retweet[cluster].most_common(5)
    if len(most_common) < 5:
        continue
    print "#################"
    print cluster
    print most_common
    print "#################"
# Out:
# #################
# 0
# [('Trump', 4173), ('ImWithHer', 2059), ('NeverTrump', 1479), ('TrumpCheck', 1224), ('SNL', 1192)]
# #################
# #################
# 1
# [('Trump', 11581), ('MAGA', 9029), ('PodestaEmails9', 6770), ('Hillary', 3777), ('HillaryGropedMe', 3659)]
# #################
# #################
# 2
# [('WomenWhoVoteTrump', 7), ('Election2016', 4), ('RepealThe19th', 3), ('trumpspeaks', 2), ('WasteHisTime2016', 1)]
# #################
# #################
# 5
# [('tcot', 2), ('SNL', 2), ('Election2016', 2), ('isis', 1), ('TruthHurts', 1)]
# #################
# #################
# 6
# [('Trump', 7), ('whinylittlebitch', 5), ('SNL', 5), ('ImWithHer', 4), ('Election2016', 3)]
# #################
# #################
# 9
# [('Trump', 8), ('Election2016', 7), ('100YearsStrong', 2), ('SundayMorning', 1), ('freespeechmatters', 1)]
# #################
# #################
# 12
# [('CNNSOTU', 152), ('Trumpkin', 31), ('Trump', 4), ('MSNBC', 3), ('NeverTrump', 3)]
# #################
# #################
# 2050
# [('FOLLE', 2), ('burattinaio', 1), ('TerzaGuerraMondiale', 1), ('Soros', 1), ('HitlaryClinton', 1)]
# #################
# #################
# 20
# [('breakdown', 1), ('WomenCanStopTrump', 1), ('awesome', 1), ('ImWithHer', 1), ('immolation', 1)]
# #################
# #################
# 24
# [('Canberra', 2), ('ACTvotes', 2), ('HillaryClinton', 1), ('NeverTrump', 1), ('Trump', 1)]
# #################
# #################
# 28
# [('trump', 5), ('Election2016', 5), ('ImWithHer', 5), ('tcot', 4), ('SNL', 4)]
# #################
# #################
# 33
# [('auspol', 2), ('SundayMorning', 1), ('IMadeAFunny', 1), ('poll', 1), ('Trump', 1)]
# #################
# #################
# 34
# [('Trump', 3), ('ImWithHer', 2), ('lyingTrump', 2), ('HindusForTrump', 1), ('SundayMorning', 1)]
# #################
# #################
# 36
# [('Election2016', 6), ('Trump', 3), ('ImWithHer', 2), ('LGBT', 2), ('GameofThrones', 1)]
# #################
# #################
# 37
# [('clinton', 7), ('trump', 7), ('hilary', 7), ('Election2016', 3), ('democracy', 2)]
# #################
# #################
# 39
# [('SNL', 2), ('insidejob', 1), ('WRONG', 1), ('ImWithHer', 1), ('HillaryBecause', 1)]
# #################
# #################
# 44
# [('Polls', 1), ('NeverTrump', 1), ('Debates', 1), ('whinylittlebitch', 1), ('BreakingNews', 1)]
# #################
# #################
# 2093
# [('tinyhands', 1), ('CounterStrikeGlobalOffensive', 1), ('fuckdrumpf', 1), ('triggered', 1), ('DonaldTrump', 1)]
# #################
# #################
# 49
# [('Election2016', 9), ('ImWithHer', 2), ('OnikaForPresident2k16', 2), ('FeelTheBern', 1), ('HillaryClinton', 1)]
# #################
# #################
# 56
# [('TrumpTrain', 5), ('MakeAmericaGreatAgain', 4), ('TrumpForPresident', 2), ('MSM', 2), ('Trump', 2)]
# #################
# #################
# 58
# [('CheetoHitler', 1), ('UniteBlue', 1), ('Trump', 1), ('WhineyBaby', 1), ('SNL', 1)]
# #################
# #################
# 59
# [('HILLARY', 170), ('TRUMP', 157), ('CLINTON', 84), ('AXELROD', 71), ('DEBATE', 71)]
# #################
# #################
# 2058
# [('polQc', 2), ('polqc', 1), ('polUSA', 1), ('Trump', 1), ('Verdun', 1)]
# #################
# #################
# 64
# [('Trump', 6), ('Esquire', 5), ('Election2016', 5), ('HillaryGropedMe', 2), ('wikileaks', 2)]
# #################
# #################
# 67
# [('SNL', 215), ('Debate', 210), ('trump', 2), ('Election2016', 2), ('snl', 2)]
# #################
# #################
# 70
# [('Obama4Life', 2), ('FuckElection2k16', 1), ('TrumpCheck', 1), ('100YearsStrong', 1), ('ImWithHer', 1)]
# #################
# #################
# 73
# [('Election2016', 5), ('SNL', 2), ('boycottpaypal', 2), ('FUCKDONALDTRUMP', 1), ('TIDALX1015', 1)]
# #################
# #################
# 2122
# [('Election', 2), ('Election2016', 2), ('Evangelical', 1), ('YouIn', 1), ('TeamGov', 1)]
# #################
# #################
# 2124
# [('Election2016', 4), ('WomenCanStopTrump', 2), ('stopwhining', 1), ('ImWithHer', 1), ('Clarify', 1)]
# #################
# #################
# 78
# [('HILLARY2016', 3), ('TRUMP', 2), ('Hillary2016', 1), ('tcot', 1), ('FUNNY', 1)]
# #################
# #################
# 80
# [('Election2016', 775), ('Obama', 3), ('TidalX1015', 2), ('getinformation', 1), ('LGBTQ', 1)]
# #################
# #################
# 81
# [('Trump', 4), ('Clinton', 1), ('TheRightQuestionsMatter', 1), ('cuckooTrump', 1), ('TaxReturns', 1)]
# #################
# #################
# 85
# [('ImWithHer', 4), ('Trump', 3), ('MAGA', 2), ('Evangelical', 1), ('AlecBaldwin2016', 1)]
# #################
# #################
# 86
# [('Trump', 2), ('LoveIsLove', 1), ('Wisdom', 1), ('TrumpCheck', 1), ('Leadership', 1)]
# #################
# #################
# 88
# [('Election2016', 3), ('ImWithHer', 2), ('p2', 1), ('Trump', 1), ('SNL', 1)]
# #################
# #################
# 16
# [('ComedianStonefree63', 11), ('RunMilaRun', 1), ('NeverTrump', 1), ('UnfitToLead', 1), ('TerrifyingTrump', 1)]
# #################
# #################
# 98
# [('NeverTrump', 3), ('SNL', 3), ('ImWithHer', 2), ('ibelieveher', 2), ('Realitycheck', 2)]
# #################
# #################
# 100
# [('Election2016', 4), ('ImWithHer', 3), ('TIDALX1015', 1), ('LetMeStay', 1), ('WhyWomenDontReport', 1)]
# #################
# #################
# 105
# [('Election2016', 2), ('trumpismplusinmypants', 1), ('trump', 1), ('twitter', 1), ('ImWithHer', 1)]
# #################
# #################
# 109
# [('Election2016', 2), ('cheese', 1), ('Oprah', 1), ('food', 1), ('MikePence', 1)]
# #################
# #################
# 115
# [('TerrifyingTrump', 46), ('Trump', 5), ('TrumpSorrogates', 3), ('CNN', 3), ('SaturdayNightLive', 3)]
# #################
# #################
# 117
# [('BoycottTrump', 2), ('ProtectThe2nd', 2), ('Trump', 2), ('Clarify', 2), ('Election2016', 2)]
# #################
# #################
# 2169
# [('BoycottPayPal', 17), ('boycottpaypal', 5), ('debates2016', 1), ('Trump', 1), ('SexualPredator', 1)]
# #################
# #################
# 125
# [('LGBTQ', 57), ('ImWithHer', 9), ('trumpthreat', 4), ('HillaryArmy', 2), ('byetrump', 2)]
# #################
# #################
# 126
# [('BoycottPayPal', 1), ('boycottpaypal', 1), ('debates', 1), ('ImWithHer', 1), ('WomenCanStopTrump', 1)]
# #################
# #################
# 127
# [('FeminismForever', 1), ('whineylittlebitch', 1), ('nevertrump', 1), ('Trump', 1), ('riggedelection', 1)]
# #################
# #################
# 2176
# [('Tory', 2), ('toryelectionfraud', 1), ('ToryElectionFraud', 1), ('marr', 1), ('Conservative', 1)]
# #################
# #################
# 129
# [('SNL', 2), ('whiteboymagic', 1), ('nevertrump', 1), ('yourapig', 1), ('ImWithHer', 1)]
# #################
# #################
# 132
# [('Sociology', 1), ('DJT', 1), ('GHS', 1), ('alecbaldwin', 1), ('SNL', 1)]
# #################
# #################
# 140
# [('Clinton', 67), ('Jupp', 6), ('Daesh', 6), ('Trump', 5), ('Montenegro', 3)]
# #################
# #################
# 146
# [('Election2016', 3), ('WhatsWrongWithAmerica', 2), ('WhyWomenDontReport', 2), ('WomenWhoVoteTrump', 1), ('WhinyLittleBitch', 1)]
# #################
# #################
# 2756
# [('trumppence16', 3), ('DonaldTrump', 3), ('Sacramento', 1), ('MyHappyPlace', 1), ('politics', 1)]
# #################
# #################
# 2204
# [('UniteBlue', 1), ('Iran', 1), ('Republicans', 1), ('whitesupremacists', 1), ('ImWithHer', 1)]
# #################
# #################
# 164
# [('Election2016', 4), ('WomenWhoVoteTrump', 1), ('Trump', 1), ('BabyHitler', 1), ('TidalX1015', 1)]
# #################
# #################
# 165
# [('WikiLeak', 36), ('HillaryGropeMe', 31), ('wikileaks', 22), ('HillaryGropedMe', 12), ('RiggedElection', 11)]
# #################
# #################
# 176
# [('Trump', 3), ('Time', 2), ('NYTLetters', 2), ('nonrassegna', 2), ('merka', 1)]
# #################
# #################
# 181
# [('Clinton', 1), ('ShortEnd', 1), ('TrumpPence16', 1), ('Hacked', 1), ('corrupt', 1)]
# #################
# #################
# 182
# [('PrimeraPgina', 28), ('EEUU', 1), ('Reuters', 1), ('LockHerUp', 1), ('IMPEACHobama', 1)]
# #################
# #################
# 184
# [('Clinton', 2), ('Trump', 2), ('WikiLeaks', 1), ('OPININ', 1), ('MundoDD', 1)]
# #################
# #################
# 193
# [('GOP', 2), ('RT', 1), ('never', 1), ('Trump', 1), ('nc', 1)]
# #################
# #################
# 2423
# [('Trumpism', 2), ('democracy', 2), ('TerrifyingTrump', 1), ('exposed', 1), ('Trump', 1)]
# #################
# #################
# 206
# [('tinafey', 1), ('groping', 1), ('democrazy', 1), ('TrumpTapes', 1), ('snl', 1)]
# #################
# #################
# 207
# [('LostInAmerica', 1), ('NeverTrump', 1), ('YesEveryWoman', 1), ('WasteHisTime2016', 1), ('TrumpPence16', 1)]
# #################
# #################
# 2530
# [('trumpgate', 3), ('Logic', 3), ('TrumpTV', 1), ('ImWithHer', 1), ('Trumpocalypse', 1)]
# #################
# #################
# 215
# [('AAP', 2), ('LSElections', 1), ('Trump', 1), ('ProudTrumpKakaFan', 1), ('HindusForTrump', 1)]
# #################
# #################
# 2265
# [('Evangelical', 12), ('TeamGov', 12), ('Election2016', 12), ('YouIn', 12), ('Trump', 1)]
# #################
# #################
# 228
# [('Trump', 5), ('ImWithHer', 3), ('OhSen', 3), ('Media', 2), ('100YearsStrong', 2)]
# #################
# #################
# 2279
# [('Trump', 22), ('Hillary', 8), ('Election2016', 5), ('Fox', 4), ('Decision2016', 4)]
# #################
# #################
# 233
# [('Clinton', 1), ('Trump', 1), ('AlecBaldwin', 1), ('ImWithHer', 1), ('Hillary', 1)]
# #################
# #################
# 2061
# [('news', 2), ('Trump', 1), ('USA', 1), ('BBC', 1), ('HilaryClinton', 1)]
# #################
# #################
# 238
# [('NarendraTrumpLIVE', 4), ('Trump', 1), ('Breaking', 1), ('HindusForTrump', 1), ('JustAsking', 1)]
# #################
# #################
# 239
# [('Clinton', 1), ('OMFCM', 1), ('AFP', 1), ('Trump', 1), ('TriggeredTrump', 1)]
# #################
# #################
# 244
# [('ImWithHer', 1947), ('TheTylerOakleyShow', 4), ('RiseUpAsOne', 2), ('100YearsStrong', 2), ('debate', 2)]
# #################
# #################
# 245
# [('100YearsStrong', 2), ('SNL', 2), ('1A', 2), ('MakeSNLGreatAgain', 2), ('LEMONADE', 1)]
# #################
# #################
# 249
# [('freespeech', 5), ('Election2016', 2), ('totalblowoutcoming', 1), ('nevertrump', 1), ('Trump', 1)]
# #################
# #################
# 2301
# [('13h15', 4), ('Trump', 4), ('Hollande', 4), ('PrimaireLeDebat', 4), ('Trierweiler', 4)]
# #################
# #################
# 257
# [('debate', 3), ('climatechange', 1), ('SNL', 1), ('Debate', 1), ('TPP', 1)]
# #################
# #################
# 270
# [('trump', 184), ('dumptrump', 107), ('debates', 106), ('IAmWithHer', 54), ('Ciao', 45)]
# #################
# #################
# 272
# [('Trump', 4), ('Debates2016', 1), ('Clown', 1), ('HRC', 1), ('grabthembythe', 1)]
# #################
# #################
# 274
# [('Trump', 2), ('HillaryClinton', 1), ('MikePence', 1), ('VoterSuppression', 1), ('HateSpeech', 1)]
# #################
# #################
# 281
# [('election2016', 40), ('Election2016', 3), ('RealTime', 3), ('ImWithHer', 3), ('NewRule', 3)]
# #################
# #################
# 283
# [('SundayMorning', 105), ('podestaemails9', 53), ('NoMercy', 1), ('TrumpBush2016', 1), ('ImWithHer', 1)]
# #################
# #################
# 289
# [('AmericaFirst', 1), ('TrumpPence16', 1), ('MAGA', 1), ('Dobbs', 1), ('TrumpTrain', 1)]
# #################
# #################
# 291
# [('Trump', 2), ('VoteHillary', 1), ('SaveMckinnon', 1), ('KateMcKinnon', 1), ('WomenCanStopTrump', 1)]
# #################
# #################
# 2343
# [('NeverTrump', 1), ('Trump', 1), ('IamWithHer', 1), ('Hillary', 1), ('ClintonKaine2016', 1)]
# #################
# #################
# 297
# [('NopetoTrump', 7), ('ImWithHer', 6), ('SNL', 5), ('KenBone', 2), ('debates', 2)]
# #################
# #################
# 308
# [('News', 46), ('Election', 34), ('Politics', 34), ('Hillary', 9), ('Clinton', 2)]
# #################
# #################
# 2358
# [('BoycottPaypal', 2), ('BoycottPayPal', 2), ('NeverTrump', 1), ('LGBT', 1), ('PayPal', 1)]
# #################
# #################
# 319
# [('TCOT', 3), ('THEMBNG', 3), ('LibDems', 2), ('CommonSense', 2), ('Trump', 2)]
# #################
# #################
# 321
# [('Forbes400', 31), ('Trump', 2), ('TrumpPence16', 1), ('debate', 1), ('MAGA', 1)]
# #################
# #################
# 2381
# [('nevertrump', 7), ('trump', 7), ('CaptainAmerica', 7), ('art', 7), ('Election2016', 7)]
# #################
# #################
# 337
# [('Second', 3), ('Trump', 1), ('uhoh', 1), ('second', 1), ('dumb', 1)]
# #################
# #################
# 341
# [('MeetThePress', 2), ('NeverTrump', 1), ('DNC', 1), ('RapeCulture', 1), ('NeverHillary', 1)]
# #################
# #################
# 351
# [('CNNSOTU', 2), ('BBCWorld', 1), ('SNL', 1), ('AHS', 1), ('Trumpkin', 1)]
# #################
# #################
# 2048
# [('eqgrp_auction', 2), ('equationgroup', 2), ('shadowbroker', 1), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 367
# [('RFDE', 13), ('HackTheVote', 13), ('Trump', 12), ('CYBER', 12), ('Election2016', 3)]
# #################
# #################
# 368
# [('GlennBeck', 2), ('delegates', 1), ('NWO', 1), ('Forbes400', 1), ('Killary', 1)]
# #################
# #################
# 2417
# [('Trump', 2), ('riggedelection', 1), ('corruptobama', 1), ('Clinton', 1), ('trump', 1)]
# #################
# #################
# 373
# [('BoycottPayPal', 5), ('IceCreamConvos', 4), ('OITNB', 4), ('HB2', 3), ('Trump', 1)]
# #################
# #################
# 377
# [('TrumpGirls', 1), ('Trump', 1), ('FoxNews', 1), ('incest', 1), ('MakeAmericaGullibleAgain', 1)]
# #################
# #################
# 386
# [('QueNoSeTePase', 4), ('NoEsBroma', 3), ('WhyWomanDontReport', 3), ('Video', 3), ('Enterate', 2)]
# #################
# #################
# 394
# [('Election2016', 8), ('NeverEverTrump', 1), ('Trump', 1), ('election2016', 1), ('TrumpTape', 1)]
# #################
# #################
# 396
# [('NuclearNightmare', 3), ('dishonestdonald', 3), ('DonTheThinSkinnedCON', 3), ('NorthKoreanKOOK', 3), ('trump', 2)]
# #################
# #################
# 401
# [('DumpTrump', 46), ('Trump', 27), ('GOP', 12), ('NeverTrump', 8), ('RememberCecil', 4)]
# #################
# #################
# 404
# [('Trump', 3), ('ImWithHer', 2), ('freespeech', 2), ('notokay', 1), ('TrumpCheck', 1)]
# #################
# #################
# 407
# [('LGBT', 2), ('ImWithHer', 2), ('xenophobia', 1), ('racism', 1), ('misogeny', 1)]
# #################
# #################
# 413
# [('Trump', 15), ('animals', 7), ('HillaryBecause', 6), ('wildlife', 4), ('WednesdayWisdom', 4)]
# #################
# #################
# 423
# [('EvenABlindGroperFindsANut', 3), ('NoQuarter', 2), ('Libertarian', 2), ('OpenDebates', 1), ('2partyscam', 1)]
# #################
# #################
# 424
# [('Election2016', 4), ('Trump', 1), ('hypocrisy', 1), ('damndirtyapes', 1), ('GAdems', 1)]
# #################
# #################
# 425
# [('AAP', 3), ('PbElections', 2), ('MPElections', 2), ('RajasthanElections', 2), ('KtkElections', 2)]
# #################
# #################
# 426
# [('TrumpCheck', 2), ('loser', 2), ('boycottpaypal', 2), ('UniteBlue', 1), ('IsntThisOver', 1)]
# #################
# #################
# 432
# [('SNL', 70), ('WomenStopTrumpParty', 2), ('Debate', 2), ('HillaryClinton', 1), ('Iwillvote', 1)]
# #################
# #################
# 2483
# [('EEUU', 5), ('Clinton', 4), ('Rusia', 1), ('Pence', 1), ('Trump', 1)]
# #################
# #################
# 2486
# [('Trump', 2), ('HillaryClinton', 1), ('Clinton', 1), ('Politics', 1), ('Killary', 1)]
# #################
# #################
# 442
# [('SNL', 26), ('PowerOfWomen', 7), ('IWillnotBeSilenced', 1), ('TrumpCheck', 1), ('PowerofWomen', 1)]
# #################
# #################
# 2493
# [('clinton', 17), ('trump', 17), ('kenbone', 17), ('jokes', 1), ('vote', 1)]
# #################
# #################
# 446
# [('TrumpCheck', 3), ('Election2016', 2), ('trump', 1), ('WasteHisTime2016', 1), ('SNL', 1)]
# #################
# #################
# 447
# [('VileTrump', 2), ('whineylittlebitch', 2), ('republican', 1), ('Clinton', 1), ('trump', 1)]
# #################
# #################
# 2503
# [('Hillary', 2), ('sondeos', 2), ('Tendencia', 2), ('Clinton', 1), ('Correos', 1)]
# #################
# #################
# 456
# [('Trump', 2), ('ExtinctionEvent', 1), ('JulianAssange', 1), ('DonVoyage', 1), ('Grope', 1)]
# #################
# #################
# 466
# [('Trump', 6), ('LindsayLohan', 3), ('ExclsiorTv', 1), ('Hillary', 1), ('NoEsBroma', 1)]
# #################
# #################
# 468
# [('NuclearNightmare', 74), ('NorthKoreanKOOK', 74), ('DonTheThinSkinnedCON', 74), ('NeverTrump', 2), ('StarWars', 1)]
# #################
# #################
# 474
# [('EdBalls', 23), ('Strictly', 23), ('Trump', 5), ('c4news', 1), ('ChooChoo', 1)]
# #################
# #################
# 2525
# [('Paypal', 5), ('Trump', 4), ('paypal', 4), ('boycottpaypal', 4), ('PayPal', 3)]
# #################
# #################
# 481
# [('insane', 1), ('Prospective', 1), ('crazy', 1), ('From', 1), ('Trump', 1)]
# #################
# #################
# 484
# [('DonaldTrump', 11), ('Trump', 7), ('HillaryClinton', 4), ('mashable', 2), ('threat', 2)]
# #################
# #################
# 490
# [('TRUMP', 5), ('CLINTON', 3), ('HILLARY', 3), ('WashPost', 2), ('DRUGS', 2)]
# #################
# #################
# 2542
# [('Funny', 2), ('Trump', 2), ('LockerRoomTalk', 2), ('NFL', 2), ('Birdgang', 2)]
# #################
# #################
# 500
# [('unityforfreedom', 11), ('unionforfreedom', 5), ('UnityForFreedom', 4), ('___', 4), ('_', 4)]
# #################
# #################
# 507
# [('Obama', 4), ('Michelle', 1), ('HillaryClinton', 1), ('Putin', 1), ('Trump', 1)]
# #################
# #################
# 528
# [('LaCasaBianca', 62), ('Trump', 16), ('RaiUsa2016', 16), ('Sanders', 7), ('Clinton', 7)]
# #################
# #################
# 531
# [('Trump', 4), ('ChristianWomenPreach', 2), ('NeverTrump', 1), ('LGBTQ', 1), ('usvotes', 1)]
# #################
# #################
# 535
# [('FYI', 4), ('FakeNews', 4), ('Drumpt', 1), ('Trump', 1), ('Howard', 1)]
# #################
# #################
# 550
# [('Republicans', 3), ('GOP', 3), ('NYT', 3), ('CIA', 2), ('cyber', 2)]
# #################
# #################
# 551
# [('NeverTrump', 1), ('SNL', 1), ('WhyWomenDontReport', 1), ('loser', 1), ('soreloser', 1)]
# #################
# #################
# 552
# [('Election2016', 4), ('Trump', 2), ('BoycottPaypal', 2), ('LGBTQS', 2), ('p2', 1)]
# #################
# #################
# 556
# [('Trump', 9), ('SNL', 7), ('ClintonVsTrump', 2), ('Clinton', 2), ('DesertTrip', 1)]
# #################
# #################
# 563
# [('Trump', 3), ('SouthAsiansDumpTrump', 2), ('Modi', 2), ('SouthasiansDumpTrump', 2), ('Dalit', 1)]
# #################
# #################
# 564
# [('100YearsStrong', 467), ('ImWithHer', 2), ('giuliani', 1), ('neverTrump', 1), ('lovetrumpshate', 1)]
# #################
# #################
# 568
# [('EuropeGoesUs', 19), ('Trump', 1), ('EEUU', 1), ('Debate', 1), ('OPININ', 1)]
# #################
# #################
# 2484
# [('auspol', 2), ('Trump', 1), ('USA', 1), ('financ', 1), ('politics', 1)]
# #################
# #################
# 574
# [('whiteboymagic', 19), ('trump', 3), ('fungshui', 3), ('election2016', 3), ('FightFor15', 2)]
# #################
# #################
# 2145
# [('trump', 1), ('Debate', 1), ('ImWithHer', 1), ('debate', 1), ('AMAs', 1)]
# #################
# #################
# 586
# [('DontheCon', 1), ('weirdhair', 1), ('WomenCanStopTrump', 1), ('OurVoteCounts', 1), ('WRONG', 1)]
# #################
# #################
# 2638
# [('Trump', 5), ('Hillary', 4), ('911Day', 3), ('Debates2016', 3), ('MichelleObama', 3)]
# #################
# #################
# 602
# [('Hitler', 3), ('Nazi', 3), ('Trump', 3), ('TerrifyingTrump', 1), ('SaturdayNightLive', 1)]
# #################
# #################
# 2066
# [('Trump', 14), ('xenophobia', 13), ('WitneyByElection', 2), ('DwyforMeirionnydd', 1), ('Putin', 1)]
# #################
# #################
# 613
# [('HillaryClinton', 3), ('realdonaldtrump', 2), ('Trump', 1), ('FX', 1), ('Brexit', 1)]
# #################
# #################
# 624
# [('OKElections16', 2), ('Trump', 2), ('49ers', 1), ('Patriots', 1), ('oklaed', 1)]
# #################
# #################
# 2674
# [('Clinton', 3), ('gendergap', 2), ('Trump', 2), ('womenandwork', 2), ('race', 2)]
# #################
# #################
# 2067
# [('misogyny', 1), ('journalism', 1), ('WomensRights', 1), ('fascism', 1), ('hacking', 1)]
# #################
# #################
# 2700
# [('TakeTheMoney', 11), ('TaketheMoney', 5), ('AdmissionOfGuilt', 2), ('WomenForTrump', 2), ('PodestaForPrison', 2)]
# #################
# #################
# 2157
# [('vote', 1), ('WikiLeaks', 1), ('MAGA', 1), ('election2016', 1), ('getoutandvote', 1)]
# #################
# #################
# 2726
# [('networks', 12), ('business', 7), ('marketing', 7), ('social', 7), ('news', 7)]
# #################
# #################
# 2162
# [('RT', 1), ('Brexit', 1), ('SaySomethingCompletelyHonest', 1), ('Democracy', 1), ('Like', 1)]
# #################
# #################
# 692
# [('mariagepourtous', 2), ('IVG', 2), ('Trump', 2), ('USA', 2), ('journalistes', 1)]
# #################
# #################
# 2164
# [('Trump', 13), ('leadership', 2), ('lockerroom', 2), ('leaders', 1), ('integrity', 1)]
# #################
# #################
# 700
# [('golf', 1), ('trump', 1), ('turnberry', 1), ('muggles', 1), ('theopen', 1)]
# #################
# #################
# 2506
# [('Ohio', 1), ('Georgia', 1), ('Arizona', 1), ('Iowa', 1), ('Nevada', 1)]
# #################
# #################
# 703
# [('VOTE', 19), ('NC', 15), ('HBCUs4Hillary', 14), ('ImWithHer', 14), ('Durham', 14)]
# #################
# #################
# 707
# [('Trump', 3), ('p2', 1), ('tcot', 1), ('potus', 1), ('maga', 1)]
# #################
# #################
# 708
# [('Trump', 4), ('ImWithHer', 4), ('BatmanVSuperman', 3), ('debate', 2), ('DontheCon', 1)]
# #################
# #################
# 715
# [('Russia', 13), ('debates', 1), ('Kuwait', 1), ('tcot', 1), ('Trump', 1)]
# #################
# #################
# 734
# [('Hillary', 2), ('CNNSOTU', 2), ('Hillary2016', 1), ('Trump', 1), ('ClintonFoundation', 1)]
# #################
# #################
# 747
# [('USA', 4), ('EEUU', 4), ('Opinin', 4), ('LandingPage', 2), ('Trump', 1)]
# #################
# #################
# 2514
# [('bluegrasslife', 3), ('bluegrass', 3), ('AlisonKrauss', 3), ('Clinton', 3), ('Trump', 3)]
# #################
# #################
# 769
# [('Sputnik', 3), ('feignant', 2), ('Clinton', 2), ('trump', 1), ('Trump', 1)]
# #################
# #################
# 785
# [('Clinton', 4), ('Trump', 3), ('us', 2), ('usa', 1), ('GOP', 1)]
# #################
# #################
# 793
# [('Debat2016', 1), ('polqc', 1), ('Debates2016', 1), ('USA', 1), ('Dbat', 1)]
# #################
# #################
# 798
# [('deplorable', 2), ('HillaryClinton', 1), ('Trump', 1), ('voters', 1), ('turnup', 1)]
# #################
# #################
# 803
# [('TheNationOfISRAELnUnbornBabiesIntoConsideration', 7), ('HaveABlessedSONDay', 7), ('WhenYouCastUrVotePut', 7), ('Election2016', 7), ('November8', 7)]
# #################
# #################
# 809
# [('Trump', 2), ('VoteTrumpPence16', 1), ('SNL', 1), ('ImWithHer', 1), ('VoteTrump', 1)]
# #################
# #################
# 2583
# [('Brexit', 3), ('wato', 3), ('Tory', 3), ('c4news', 3), ('bbcdp', 3)]
# #################
# #################
# 477
# [('rigged', 1), ('Clarify', 1), ('ProtectThe2nd', 1), ('PorSiNoLoViste', 1), ('Election2016', 1)]
# #################
# #################
# 819
# [('gaysfortrump', 2), ('WomenWhoVoteTrump', 1), ('LGBTQ', 1), ('ImWithHer', 1), ('BoycottPayPal', 1)]
# #################
# #################
# 820
# [('Trump', 4), ('Clinton', 3), ('HillaryForPrison', 3), ('LockHerUp', 3), ('sondages', 1)]
# #################
# #################
# 830
# [('SNL', 62), ('LEMONADE', 54), ('KenBone', 25), ('debates', 21), ('RealTime', 2)]
# #################
# #################
# 2529
# [('auspol', 9), ('uspoli', 9), ('TrumpTrain', 9), ('Trump', 9), ('oops', 9)]
# #################
# #################
# 2188
# [('Independents', 1), ('Latinos', 1), ('Trump', 1), ('TrumpTapes', 1), ('Millennials', 1)]
# #################
# #################
# 846
# [('AtHome', 3), ('benefits', 1), ('SNL', 1), ('immigrants', 1), ('FreeVideo', 1)]
# #################
# #################
# 851
# [('Latinos', 1), ('Clinton', 1), ('Trump', 1), ('Renzi', 1), ('scarystuff', 1)]
# #################
# #################
# 858
# [('presstitute', 1), ('CorruptClintonClan', 1), ('trump', 1), ('BarkhaDefamesIndia', 1), ('hillary', 1)]
# #################
# #################
# 882
# [('TRUMP', 68), ('Perino', 62), ('Fox', 62), ('DRUGS', 5), ('POLLS', 4)]
# #################
# #################
# 911
# [('TrumpTapes', 3), ('debates2016', 3), ('TrumpRape', 3), ('NeverTrump', 3), ('debate', 3)]
# #################
# #################
# 916
# [('Election2016', 240), ('MakeAmericaRiotAgain', 1), ('ElectionFun', 1), ('TooFunny', 1), ('ItsWorthAShot', 1)]
# #################
# #################
# 922
# [('ForeignMinister', 3), ('US', 3), ('election', 3), ('Russian', 3), ('Lavrov', 3)]
# #################
# #################
# 950
# [('Trump', 5), ('HinduAmericans', 5), ('Modi', 5), ('USA', 2), ('India', 2)]
# #################
# #################
# 2214
# [('BNP', 3), ('rochdale', 3), ('labour', 3), ('salford', 1), ('middleton', 1)]
# #################
# #################
# 964
# [('BiggBoss10', 9), ('BB10', 3), ('100YearsStrong', 1), ('debates', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 2419
# [('trump', 3), ('imwither', 3), ('Trump2016', 1), ('NeverTrump', 1), ('dnc', 1)]
# #################
# #################
# 2283
# [('HillaryClinton', 3), ('p2', 2), ('tcot', 2), ('SNL', 1), ('ImWithHer', 1)]
# #################
# #################
# 984
# [('Trump', 4), ('Senado', 4), ('Clinton', 2), ('WallStreet', 2), ('LibertadFILZocalo', 1)]
# #################
# #################
# 997
# [('DumpTrump', 21), ('dumptrump', 16), ('Trump', 10), ('ImWithHer', 6), ('SNL', 6)]
# #################
# #################
# 1008
# [('BoycottPaypal', 8), ('AMJoy', 4), ('BoyCottPayPal', 3), ('SundayMorning', 1), ('TellAmericaItsGreat', 1)]
# #################
# #################
# 1015
# [('Clinton', 28), ('US', 13), ('WikiLeaks', 13), ('Wikileaks', 4), ('Chine', 3)]
# #################
# #################
# 2219
# [('hillaryclinton', 4), ('ilikeher', 3), ('imwithher', 3), ('hillary', 3), ('maga3x', 2)]
# #################
# #################
# 1029
# [('Clinton', 1), ('Trump', 1), ('sakpol', 1), ('Moldova', 1), ('Europea', 1)]
# #################
# #################
# 1030
# [('MuteTrump', 1), ('tidalx1015', 1), ('trump', 1), ('100YearsStrong', 1), ('nickiminaj', 1)]
# #################
# #################
# 1053
# [('Farrakhan', 717), ('HDOA16', 684), ('Election2016', 172), ('Trump', 88), ('Hillary', 73)]
# #################
# #################
# 1059
# [('Election2016', 6), ('99cents', 3), ('kindle', 3), ('Amazon', 3), ('RT', 3)]
# #################
# #################
# 1061
# [('Trump', 2), ('trump', 1), ('buitenhof', 1), ('hillary', 1), ('koningshuis', 1)]
# #################
# #################
# 2567
# [('BoycottPaypal', 22), ('PayPal', 1), ('bitcoin', 1), ('TrumpIsTheWorst', 1), ('boycottPayPal', 1)]
# #################
# #################
# 1083
# [('BoycottPaypal', 4), ('boycottPayPal', 2), ('whiteboymagic', 1), ('boycottpaypal', 1), ('InvestYourVote', 1)]
# #################
# #################
# 1090
# [('TRUMP', 2), ('HILLARY', 2), ('SundayMorning', 1), ('Clinton', 1), ('NovaScotia411', 1)]
# #################
# #################
# 1105
# [('trending', 21), ('HB', 7), ('hacking', 5), ('cyber', 3), ('Trump', 2)]
# #################
# #################
# 1107
# [('HillaryClinton', 1), ('ImWithHer', 1), ('LaganjaEstranja', 1), ('RPDR', 1), ('100YearsStrong', 1)]
# #################
# #################
# 1120
# [('Trump', 8), ('M5S', 5), ('Grillo', 5), ('Clinton', 3), ('Hillary', 3)]
# #################
# #################
# 2576
# [('NursesforTrump', 2), ('nursesfortrump', 1), ('militaryfor', 1), ('vote4trump', 1), ('gop', 1)]
# #################
# #################
# 1124
# [('Art', 1), ('Trump', 1), ('people', 1), ('MakeAmericaGreatAgain', 1), ('TrumpTrain', 1)]
# #################
# #################
# 1133
# [('ROIMentor', 5), ('politics', 4), ('DonaldTrump', 3), ('videos', 2), ('funny', 2)]
# #################
# #################
# 1151
# [('HillaryClinton', 9), ('Trump', 9), ('USA', 9), ('dibattito', 9), ('antidroga', 9)]
# #################
# #################
# 1153
# [('HillarysEmails', 3), ('c4news', 3), ('Trump', 3), ('Foghorn', 3), ('TheBitch', 3)]
# #################
# #################
# 1168
# [('WTF', 12), ('wtf', 7), ('TRUMP', 5), ('Cousins', 3), ('FLORIDA', 3)]
# #################
# #################
# 1182
# [('GaryJohnson', 10), ('libertarian', 5), ('JohnsonWeld', 4), ('LetGaryDebate', 4), ('JohnsonWeld2016', 2)]
# #################
# #################
# 1186
# [('Espectaculos', 3), ('16oct', 1), ('I', 1), ('100YearsStrong', 1), ('Internacional', 1)]
# #################
# #################
# 1191
# [('Trump', 5), ('LTE', 3), ('Narcissistic', 2), ('LDS', 1), ('NeverTrump', 1)]
# #################
# #################
# 2589
# [('SaudiArabia', 1), ('MadamPresident', 1), ('ImWithHer', 1), ('palin', 1), ('UAE', 1)]
# #################
# #################
# 1202
# [('Market', 2), ('Clownpocalyse', 1), ('2ndAmendment', 1), ('standmyground', 1), ('Patriots', 1)]
# #################
# #################
# 2252
# [('Trump', 5), ('Russia', 3), ('Clinton', 2), ('sinistra', 2), ('sessismo', 1)]
# #################
# #################
# 2595
# [('Trump', 4), ('sondages', 2), ('Clinton', 2), ('USA', 2), ('Prsidentielle', 2)]
# #################
# #################
# 1236
# [('Blacks4Trump', 1), ('Merkel', 1), ('TrumpSupporter', 1), ('MakeAmericaGreatAgain', 1), ('Trump', 1)]
# #################
# #################
# 1246
# [('SNL', 29), ('Trump', 24), ('Clinton', 6), ('Debate', 5), ('concession', 1)]
# #################
# #################
# 1256
# [('Trump', 12), ('HesCountingTheSecondsTilItsOver', 1), ('FakeNutritionFacts', 1), ('ZEERO', 1), ('Oops', 1)]
# #################
# #################
# 1278
# [('Trump', 13), ('Clinton', 5), ('Johnson', 1), ('Romney', 1), ('McCain', 1)]
# #################
# #################
# 1292
# [('Duncan4Witney', 2), ('SNL', 1), ('brexit', 1), ('Debate', 1), ('trump', 1)]
# #################
# #################
# 1294
# [('Trump', 24), ('MAGA', 24), ('CrookedHillary', 23), ('PodestaEmails9', 1), ('TrumpPence16', 1)]
# #################
# #################
# 1310
# [('RT', 20), ('OPININ', 9), ('WikiLeaks', 1), ('pasajerofeliz', 1), ('Clinton', 1)]
# #################
# #################
# 1318
# [('notinmyname', 2), ('remain', 2), ('LabourLeadership', 1), ('Broadstone', 1), ('DOH', 1)]
# #################
# #################
# 1329
# [('HairHeads', 5), ('BaldGuysForHillary', 5), ('My', 5), ('Trump', 5), ('ImWithHer', 5)]
# #################
# #################
# 1334
# [('Trump', 19), ('SundayTabloid', 19), ('newyork', 10), ('stutiuniti', 4), ('NewYork', 3)]
# #################
# #################
# 1338
# [('debate', 1), ('GaryJohnson', 1), ('clinton', 1), ('Election', 1), ('trump', 1)]
# #################
# #################
# 1339
# [('277Days', 26), ('sexcrimes', 10), ('MartinsvilleSexCrimes', 7), ('RNCinCLE', 3), ('Trump', 3)]
# #################
# #################
# 2274
# [('DumpTrump', 2), ('dumpTrump', 2), ('HillaryGropedMe', 2), ('pervert', 1), ('dirtyoldman', 1)]
# #################
# #################
# 1361
# [('ChooChoo', 52), ('MAGA', 52), ('Trump', 2), ('Equality', 1), ('xenophobia', 1)]
# #################
# #################
# 1376
# [('Mentallyill', 3), ('Meltdown', 3), ('OntheBlow', 3), ('TrumpCheck', 2), ('SNL', 1)]
# #################
# #################
# 1386
# [('Trump', 1), ('StopWhining', 1), ('SNL', 1), ('violence', 1), ('rigged', 1)]
# #################
# #################
# 1398
# [('HillaryClinton', 64), ('hillaryclinton', 20), ('Hillary', 18), ('TrumpDumb', 16), ('Election2016', 13)]
# #################
# #################
# 1401
# [('ImWithHer', 24), ('DesperateDonald', 1), ('SpoiledSport', 1), ('Brat', 1), ('Unprofessional', 1)]
# #################
# #################
# 1428
# [('Trump', 5), ('India', 2), ('Rule', 2), ('Dynasty', 2), ('Hellery', 2)]
# #################
# #################
# 1441
# [('TommyGetsSecurity', 8), ('BiggBoss10', 6), ('ModisInnovativeDiplomacy', 2), ('PbElections', 1), ('MPElections', 1)]
# #################
# #################
# 1450
# [('ACloserLookBack', 8), ('ACloserLook', 3), ('Ohio', 1), ('Trump', 1), ('LNSM', 1)]
# #################
# #################
# 1476
# [('IG', 8), ('NEWS', 4), ('FASHION', 2), ('DAILY', 2), ('TRENDS', 2)]
# #################
# #################
# 1486
# [('EEUU', 1), ('Elecciones2016', 1), ('EncuestaDLA', 1), ('Trump', 1), ('MikePence', 1)]
# #################
# #################
# 1511
# [('Trump', 5), ('CarolinaDelNorte', 3), ('URGENTE', 3), ('EUA', 2), ('EU', 1)]
# #################
# #################
# 1516
# [('Trump', 11), ('Clinton', 6), ('DonVoyage', 5), ('POTUS', 4), ('WomenForTrump', 3)]
# #################
# #################
# 1537
# [('debates', 8), ('mustwatch', 8), ('Ellen', 8), ('Election2016', 8), ('TrumpTapes', 4)]
# #################
# #################
# 1550
# [('FestivalPeople', 12), ('BullshitArtists', 2), ('Trump', 2), ('MediaMatters', 2), ('CNN', 2)]
# #################
# #################
# 1553
# [('RT', 1), ('FlashAlert', 1), ('Trump', 1), ('Registered', 1), ('State', 1)]
# #################
# #################
# 1557
# [('CNCNet', 15), ('pjnet', 13), ('rednationrising', 7), ('ccot', 4), ('tcot', 4)]
# #################
# #################
# 1564
# [('Syria', 7), ('Clinton', 5), ('rebels', 3), ('Taliban', 3), ('Emails', 2)]
# #################
# #################
# 2650
# [('Russian', 16), ('MindGames', 16), ('hacking', 16), ('Putin', 16), ('US', 16)]
# #################
# #################
# 1581
# [('journalistes', 7), ('Trump', 3), ('Brady', 2), ('NFL', 2), ('LastRT', 1)]
# #################
# #################
# 1591
# [('ImWithHer', 17), ('GameofThrones', 15), ('lovetrumpshate', 15), ('comics', 1), ('SNL', 1)]
# #################
# #################
# 1592
# [('Video', 6), ('Trump', 2), ('Clinton', 1), ('TheNewYorkTimes', 1), ('SaturdayNightLive', 1)]
# #################
# #################
# 1594
# [('VOTEBLUE', 6), ('ImWithHer', 6), ('Election2016', 6), ('reallymike', 1), ('election2016', 1)]
# #################
# #################
# 1603
# [('AFP', 9), ('Trump', 5), ('Hillary', 5), ('GoldmanSachs', 4), ('USElection', 4)]
# #################
# #################
# 1604
# [('Trump', 4), ('Clinton', 3), ('Usa2016', 2), ('HillaryClinton', 1), ('USA', 1)]
# #################
# #################
# 1611
# [('WomenCanStopTrump', 67), ('Election2016', 2), ('FlyEaglesFly', 1), ('WomenWontForget', 1), ('vote', 1)]
# #################
# #################
# 2317
# [('Trump', 2), ('Beyonce', 2), ('Melania', 2), ('CNN', 2), ('BBCNews', 1)]
# #################
# #################
# 1627
# [('trump', 4), ('debate', 2), ('HillaryGropedMe', 2), ('HillaryClinton', 1), ('natashastoynoff', 1)]
# #################
# #################
# 1647
# [('ClintonEmails', 4), ('Wikileaks', 4), ('Clinton', 1), ('Trump', 1), ('LOL', 1)]
# #################
# #################
# 1680
# [('TrumpPence16', 2), ('TrumpTrain', 2), ('MAGA', 2), ('CleanYourMuteList', 2), ('Trump', 2)]
# #################
# #################
# 1689
# [('BoycottPayPal', 33), ('BoycottPaypal', 4), ('boycottpaypal', 3), ('Trump', 3), ('boycottPayPal', 2)]
# #################
# #################
# 1750
# [('ProLife', 2), ('abortion', 2), ('Trump', 1), ('WhiteMasculinitySoFragile', 1), ('NEWSWIRE', 1)]
# #################
# #################
# 1785
# [('UriAttacks', 7), ('Trending_India', 2), ('MyGuess', 2), ('AbkiBaarTrumpSarkaar', 2), ('Mind_it', 1)]
# #################
# #################
# 1787
# [('OpDrumpf', 7), ('VoteBlue', 1), ('Sniffling', 1), ('Debates', 1), ('ImWithHer', 1)]
# #################
# #################
# 1800
# [('msnbc', 9), ('MSNBC', 3), ('cnn', 1), ('AMJoy', 1), ('takedownthedonald', 1)]
# #################
# #################
# 1818
# [('polqc', 1), ('HumaAbedin', 1), ('Clinton', 1), ('Hillary', 1), ('HillarysHuma', 1)]
# #################
# #################
# 1820
# [('Latinos', 1), ('Clinton', 1), ('HumaAbedin', 1), ('HillaryBecause', 1), ('Hillary', 1)]
# #################
# #################
# 1830
# [('PodestaEmails9', 1), ('neverhillary', 1), ('SaveAmyGoodman', 1), ('HILLNO', 1), ('NeverHillary', 1)]
# #################
# #################
# 1837
# [('DEATH', 7), ('CLINTON', 7), ('deathsentence', 7), ('YOUNG', 7), ('TEXAS', 7)]
# #################
# #################
# 1852
# [('RiseUpAsOne', 46), ('CrookedTrump', 1), ('Jerk', 1), ('PredatorTrump', 1), ('PiataTrump', 1)]
# #################
# #################
# 1857
# [('Tyranny', 2), ('CrookedHillary', 2), ('Election', 2), ('MAGA', 2), ('Clinton', 1)]
# #################
# #################
# 1864
# [('Trump', 62), ('Hillary', 50), ('Libertarian', 43), ('HillaryClinton', 9), ('BruceCCarter', 4)]
# #################
# #################
# 1881
# [('Trump', 2), ('Corbyn', 2), ('duh', 1), ('Piketty', 1), ('globalization', 1)]
# #################
# #################
# 1890
# [('Trump', 50), ('theview', 2), ('surreal', 2), ('wilkesbarre', 2), ('abcnews', 2)]
# #################
# #################
# 1895
# [('FOLLE', 2), ('clinton', 1), ('burattinaio', 1), ('TerzaGuerraMondiale', 1), ('Soros', 1)]
# #################
# #################
# 1907
# [('Clinton', 12), ('Trump', 12), ('fucked', 12), ('president', 12), ('Farrakhan', 1)]
# #################
# #################
# 1921
# [('Podesta', 2), ('ImWithHillary', 1), ('TurnUSABlue', 1), ('HillaryClinton', 1), ('NarcissistTrump', 1)]
# #################
# #################
# 2369
# [('TienesQueVerlo', 3), ('Sonora', 3), ('VIDEO', 2), ('Trump', 1), ('NACIN', 1)]
# #################
# #################
# 1930
# [('bospoli', 3), ('Clinton', 2), ('dnc', 2), ('dncc', 2), ('Hitler', 2)]
# #################
# #################
# 2315
# [('WarrenBuffett', 15), ('HillaryClinton', 6), ('DonaldTrump', 3), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 1948
# [('Trump', 6), ('election', 5), ('DVAM', 1), ('emotionalabuse', 1), ('gaslighting', 1)]
# #################
# #################
# 2714
# [('Trump', 6), ('obama', 5), ('GoldmanSachs', 1), ('Hillary', 1), ('USElection', 1)]
# #################
# #################
# 1957
# [('FOLLE', 10), ('burattinaio', 5), ('Soros', 5), ('HitlaryClinton', 5), ('massona', 5)]
# #################
# #################
# 1976
# [('trump', 14), ('asshat', 13), ('Trump', 9), ('maga', 9), ('polqc', 1)]
# #################
# #################
# 1980
# [('Trump', 2), ('WomensLivesMatter', 1), ('WomansLivesMatter', 1), ('Loudobbs', 1), ('victims', 1)]
# #################
# #################
# 1989
# [('educhat', 6), ('homeschool', 6), ('edchat', 6), ('parents', 6), ('princhat', 6)]
# #################
# #################
# 1997
# [('Trump', 8), ('Brexit', 5), ('TrumpWatch', 1), ('debatenight2016', 1), ('satire', 1)]
# #################
# #################
# 2007
# [('CrookedHillary', 1), ('AmericaFirst', 1), ('Trump', 1), ('3terms', 1), ('AccordingParticipant', 1)]
# #################
# #################
# 2032
# [('thirdparty', 1), ('NeverTrump', 1), ('Trump', 1), ('voteSocialist', 1), ('Democrats', 1)]
# #################
# #################
# 2387
# [('Farrakhan', 1), ('blackcommunity', 1), ('victimculture', 1), ('Chicago', 1), ('Played', 1)]
# #################
# #################
# 2043
# [('Family', 1), ('BUSHfamily', 1), ('GOP', 1), ('BasketOfDeplorables', 1), ('Moms', 1)]
# #################

# %%
ls
# Out:
# PLaw.ipynb             mentions_clust.txt     replies_randhist.png
# PopHashtags.ipynb      mentions_randhist.png  retweet.txt
# hashtags.txt           replies.txt            retweet_analysis.txt
# mentions.txt           replies_analysis.txt   retweet_clust.txt
# mentions_analysis.txt  replies_clust.txt      retweet_randhist.png

# %%
user_to_cluster_replies = {} 
with open('replies_clust.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        cluster_id = int(split_line[1])
        user_id = int(split_line[0])
        user_to_cluster_replies[user_id] = cluster_id

# %%
counter_per_cluster_replies = {}
with open('hashtags.txt', 'rb') as f:
    for line in f:
        split_line = line.split()
        if len(split_line) < 2:
            continue
        user_id = int(split_line[0])
        
        if user_id not in user_to_cluster_replies:
            continue
        
        hashtag = split_line[1]
        cluster_id = user_to_cluster_replies[user_id]
        
        if cluster_id not in counter_per_cluster_replies:
            counter_per_cluster_replies[cluster_id] = Counter()
        counter_per_cluster_replies[cluster_id][hashtag] += 1

# %%
# for replies
for cluster in counter_per_cluster_replies:
    most_common = counter_per_cluster_replies[cluster].most_common(5)
    if len(most_common) < 5:
        continue
    print "#################"
    print cluster
    print most_common
    print "#################"
# Out:
# #################
# 0
# [('Trump', 30), ('NeverTrump', 16), ('PodestaEmails9', 9), ('ImWithHer', 9), ('PodestaEmails', 7)]
# #################
# #################
# 1
# [('Trump', 13), ('p2', 12), ('Democrats', 4), ('PJNET', 3), ('Blacks4Trump', 3)]
# #################
# #################
# 2
# [('Trump', 2422), ('MAGA', 1718), ('PodestaEmails9', 798), ('ImWithHer', 591), ('Hillary', 579)]
# #################
# #################
# 4
# [('Trump', 7), ('natashastoynoff', 2), ('Brexit', 1), ('CLTV', 1), ('DumbAmerica', 1)]
# #################
# #################
# 5
# [('SNL', 3), ('Trump', 2), ('DumpTrump', 1), ('VotingRights', 1), ('KimKardashian', 1)]
# #################
# #################
# 6
# [('EvangelicalsAgainstTrump', 1), ('NeverHillaryNeverTrump', 1), ('liar', 1), ('Trump', 1), ('SNL', 1)]
# #################
# #################
# 7
# [('Trump', 435), ('MAGA', 353), ('PodestaEmails9', 277), ('trump', 205), ('TrumpPence16', 134)]
# #################
# #################
# 10
# [('Trump', 32), ('MAGA', 29), ('TrumpTrain', 17), ('TrumpPence16', 14), ('Hillary', 12)]
# #################
# #################
# 11
# [('NeverTrump', 2), ('p2', 1), ('TopProg', 1), ('Trump', 1), ('TrumpTapes', 1)]
# #################
# #################
# 12
# [('Trump', 13), ('PodestaEmails', 7), ('PodestaEmails9', 7), ('MAGA', 7), ('NeverHillary', 6)]
# #################
# #################
# 13
# [('dumpTrump', 1), ('Romney', 1), ('loser', 1), ('McCain', 1), ('BlackTwitter', 1)]
# #################
# #################
# 15
# [('Trump', 24), ('MAGA', 17), ('NeverHillary', 9), ('SundayMorning', 8), ('PodestaEmails9', 7)]
# #################
# #################
# 16
# [('Trump', 15), ('PodestaEmails9', 15), ('MAGA', 11), ('PodestaEmails', 9), ('HillaryGropedMe', 9)]
# #################
# #################
# 17
# [('Trump', 5), ('HillaryGropedMe', 3), ('debate', 2), ('KenStarr', 2), ('McCarthyism', 2)]
# #################
# #################
# 18
# [('Trump', 3), ('NHSen', 1), ('PodestaEmails9', 1), ('WISen', 1), ('FLSen', 1)]
# #################
# #################
# 19
# [('MAGA', 3), ('CrookedHillary', 2), ('HillaryClinton', 1), ('ISIS', 1), ('USA', 1)]
# #################
# #################
# 20
# [('MAGA', 5), ('HillaryGropedMe', 5), ('Trump', 5), ('PodestaEmails9', 3), ('GOP', 2)]
# #################
# #################
# 21
# [('BillClinton', 4), ('NeverHillary', 2), ('MSM', 2), ('BLM', 1), ('HillaryClinton', 1)]
# #################
# #################
# 22
# [('Trump', 5), ('SNL', 4), ('NeverTrump', 3), ('trump', 2), ('TrumpHaiku', 2)]
# #################
# #################
# 23
# [('Trump', 2), ('p2', 1), ('tcot', 1), ('theonlyadult', 1), ('EstoyConElla', 1)]
# #################
# #################
# 24
# [('PodestaEmails9', 10), ('NeverHillary', 6), ('Wikileaks', 5), ('Trump', 5), ('PodestaEmails', 4)]
# #################
# #################
# 25
# [('Trump', 29), ('MAGA', 19), ('TrumpPence16', 11), ('maga', 8), ('HillaryGropedMe', 7)]
# #################
# #################
# 26
# [('Trump', 3), ('NeverHillary', 2), ('TeamTrump', 1), ('SundayMorning', 1), ('Clinton', 1)]
# #################
# #################
# 28
# [('Trump', 5), ('nevertrump', 3), ('dumptrump', 3), ('Hillary', 2), ('TheTruthHurts', 1)]
# #################
# #################
# 30
# [('trump', 3), ('TrumpsAmerica', 1), ('HillaryClinton', 1), ('ISIS', 1), ('Libya', 1)]
# #################
# #################
# 31
# [('PodestaEmails9', 5), ('politics', 4), ('Independant', 4), ('Republican', 4), ('Democrat', 4)]
# #################
# #################
# 32
# [('p2', 11), ('tcot', 10), ('NeverTrump', 5), ('media', 5), ('NeverHillary', 5)]
# #################
# #################
# 34
# [('Trump', 3), ('WorseThanWeEvenThought', 1), ('lies', 1), ('ModernGOP', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 35
# [('Vote', 5), ('FaceTheNation', 4), ('MeetThePress', 3), ('Election2016', 2), ('ImWithHer', 2)]
# #################
# #################
# 36
# [('Trump', 14), ('MAGA', 7), ('SundayMorning', 5), ('HillaryGropedMe', 5), ('Hillary', 5)]
# #################
# #################
# 37
# [('RiggedSystem', 2), ('JamesWoods', 1), ('Republicans', 1), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 38
# [('Trump', 7), ('Hillary', 4), ('BoycottTrump', 3), ('HillaryGropedMe', 3), ('PodestaEmails9', 3)]
# #################
# #################
# 39
# [('Trump', 2), ('Debate', 2), ('RT', 1), ('SundayMorning', 1), ('NeverTrump', 1)]
# #################
# #################
# 40
# [('Uber', 1), ('Google', 1), ('NeverTrump', 1), ('Apple', 1), ('USA', 1)]
# #################
# #################
# 42
# [('Trump', 11), ('Modi', 2), ('jihad', 1), ('beef', 1), ('PodestaEmails', 1)]
# #################
# #################
# 43
# [('PodestaEmails9', 21), ('MAGA', 18), ('Trump', 10), ('PodestaEmails', 8), ('nevertrump', 7)]
# #################
# #################
# 44
# [('HillaryGropedMe', 22), ('MAGA', 7), ('TRUMP', 6), ('Trump', 6), ('Wikileaks', 5)]
# #################
# #################
# 45
# [('MAGA', 4), ('Trump', 3), ('AmericaFirst', 2), ('Clinton', 1), ('CrookedHillary', 1)]
# #################
# #################
# 46
# [('Trump', 21), ('MAGA', 10), ('TrumpPence16', 7), ('FLSen', 4), ('ImWithHer', 4)]
# #################
# #################
# 48
# [('Trump', 4), ('PodestaEmails9', 3), ('TRUMP', 2), ('Virginia', 1), ('HeartlessHillary', 1)]
# #################
# #################
# 51
# [('PodestaEmails', 3), ('trump', 3), ('HillaryClinton', 1), ('Trump', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 52
# [('PodestaEmails9', 16), ('Trump', 8), ('2A', 7), ('MAGA', 7), ('Hillary', 5)]
# #################
# #################
# 53
# [('Trump', 85), ('PodestaEmails9', 74), ('MAGA', 50), ('PodestaEmails', 44), ('CorruptMedia', 36)]
# #################
# #################
# 54
# [('Trump', 3), ('biasliberalmedia', 2), ('SundayMorning', 1), ('SNL', 1), ('NeverHillary', 1)]
# #################
# #################
# 55
# [('hypocrite', 3), ('sexualpredator', 2), ('Trump', 2), ('Clinton', 1), ('MAGA3X', 1)]
# #################
# #################
# 56
# [('Wikileaks', 4), ('PodestaEmails9', 4), ('Hillary', 3), ('PodestaEmails', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 57
# [('SundayMorning', 2), ('hypocrite', 1), ('Arizona', 1), ('Trump', 1), ('NeverTrumpOrHillary', 1)]
# #################
# #################
# 58
# [('Hillary2016', 6), ('VoteBlue', 6), ('ImWithHer', 5), ('HillYes', 5), ('HFA', 4)]
# #################
# #################
# 59
# [('Trump', 155), ('MAGA', 98), ('PodestaEmails9', 98), ('TrumpPence16', 49), ('HillaryGropedMe', 41)]
# #################
# #################
# 61
# [('NeverTrump', 13), ('StandUpWithEvan', 12), ('McMullinFinn', 12), ('NeverHillary', 11), ('Trump', 4)]
# #################
# #################
# 62
# [('MAGA', 7), ('Trump', 4), ('TrumpPence16', 3), ('Hillary', 3), ('NeverHillary', 3)]
# #################
# #################
# 63
# [('FeelTheBern', 11), ('BernieSanders', 10), ('Hillary2016', 9), ('ImWithHer', 9), ('Hillary', 9)]
# #################
# #################
# 64
# [('PodestaEmails', 2), ('ImWithHer', 2), ('DNCLeaks', 2), ('TrumpEffect', 1), ('SundayMorning', 1)]
# #################
# #################
# 65
# [('Trump', 3), ('PodestaLeaks', 2), ('PodestaEmails', 2), ('PodestaEmails5', 2), ('Cheating', 1)]
# #################
# #################
# 66
# [('MAGA', 17), ('Trump', 10), ('Wikileaks', 9), ('PodestaEmails9', 9), ('TrumpPence16', 9)]
# #################
# #################
# 67
# [('Trump', 81), ('Hillary', 30), ('MAGA', 17), ('Trump2016', 12), ('Obama', 11)]
# #################
# #################
# 69
# [('Trump', 26), ('MAGA', 20), ('PodestaEmails9', 12), ('Hillary', 12), ('HillaryGropedMe', 9)]
# #################
# #################
# 70
# [('Trump', 3), ('MAGA', 3), ('Hillary', 2), ('hillaryclinton', 1), ('AmericaFirst', 1)]
# #################
# #################
# 71
# [('VoteBlue', 4), ('StopTrump', 3), ('TrumpTapes', 2), ('SNL', 2), ('VoteForDemocracy', 1)]
# #################
# #################
# 73
# [('NeverTrump', 2), ('MeetThePress', 2), ('HILLARYCLINTON', 1), ('JoeBiden', 1), ('WearRED', 1)]
# #################
# #################
# 74
# [('MAGA', 20), ('Trump', 14), ('PodestaEmails9', 11), ('HillaryGropedMe', 7), ('Trump2016', 6)]
# #################
# #################
# 75
# [('TRUTHDONTLIE', 3), ('TrumpTrain', 3), ('BoycottPayPal', 2), ('VoteTrumpPence16', 2), ('WeThePeople', 2)]
# #################
# #################
# 76
# [('Trump', 18), ('MAGA', 11), ('NotHillary', 10), ('ImWithHer', 4), ('TrumpTrain', 4)]
# #################
# #################
# 77
# [('PodestaEmails9', 12), ('Trump', 10), ('MAGA', 7), ('SundayMorning', 6), ('TrumpTrain', 4)]
# #################
# #################
# 78
# [('StrongerTogether', 3), ('Arizona', 2), ('Georgia', 2), ('YesWeKaine', 2), ('Ohio', 2)]
# #################
# #################
# 79
# [('whinylittlebitch', 4), ('TrumpLies', 3), ('ClintonTapes', 3), ('PodestaEmails9', 3), ('Election2016', 2)]
# #################
# #################
# 81
# [('Wikileaks', 2), ('TeamTrump', 1), ('SundayMorning', 1), ('AmericaFirst', 1), ('Clinton', 1)]
# #################
# #################
# 82
# [('nevertrump', 1), ('Trump', 1), ('PodestaEmails9', 1), ('IWillVote', 1), ('IMWithHer', 1)]
# #################
# #################
# 83
# [('Trump', 4), ('MAGA', 1), ('Hillary', 1), ('TRUMP', 1), ('tcot', 1)]
# #################
# #################
# 84
# [('RememberBenghazi', 1), ('AmericaFirst', 1), ('SundayMorning', 1), ('Trump2016', 1), ('TrumpPence', 1)]
# #################
# #################
# 85
# [('trump', 2), ('Hillarygropedme', 2), ('KIDS', 1), ('Guillian', 1), ('CrookedHillary', 1)]
# #################
# #################
# 86
# [('ImWithHer', 3), ('p2', 1), ('HillaryClinton', 1), ('ShesWithUs', 1), ('NeverTrump', 1)]
# #################
# #################
# 88
# [('HillaryVoter', 1), ('Losers', 1), ('DumpTrump', 1), ('PodestaEmails7', 1), ('DNCLeaks', 1)]
# #################
# #################
# 90
# [('YouAreWhatYouEat', 8), ('sundaypolitics', 4), ('Trump', 4), ('Hillary', 3), ('AltRight', 2)]
# #################
# #################
# 91
# [('TruePundit', 4), ('Clinton', 3), ('ResignDonna', 2), ('ClintonCash', 2), ('COpolitics', 2)]
# #################
# #################
# 92
# [('ImWithHer', 7), ('StrongerTogether', 6), ('AfricanAmericans', 2), ('BLM', 2), ('HillaryGropedMe', 2)]
# #################
# #################
# 93
# [('p2', 5), ('ctl', 5), ('Trump', 3), ('RT', 2), ('TopProg', 1)]
# #################
# #################
# 96
# [('ElectionFraud', 1), ('PodestaEmails9', 1), ('snifflingtrump', 1), ('InvestYourVote', 1), ('GNW', 1)]
# #################
# #################
# 97
# [('MAGA', 2), ('NoMercy', 1), ('HispanicWomen4Trump', 1), ('DC', 1), ('HillaryBecause', 1)]
# #################
# #################
# 98
# [('HillaryGropedMe', 2), ('SundayMorning', 1), ('HillaryClinton', 1), ('trump', 1), ('Crooked', 1)]
# #################
# #################
# 99
# [('SundayMorning', 2), ('Trump', 2), ('Trump2016', 2), ('throwhillaryinjail', 1), ('USA', 1)]
# #################
# #################
# 100
# [('Trump', 11), ('PodestaEmails9', 6), ('Hillary', 4), ('MAGA', 3), ('TrumpPence16', 3)]
# #################
# #################
# 102
# [('WhinyLittleBitch', 3), ('TrumpLoser', 1), ('TrumpSucks', 1), ('Trump', 1), ('DumpTrump', 1)]
# #################
# #################
# 104
# [('RiggedElection', 4), ('CNN', 4), ('DonaldTrump', 3), ('Russia', 3), ('Trump', 3)]
# #################
# #################
# 105
# [('Trump', 7), ('p2', 3), ('100YearsStrong', 2), ('debate', 2), ('NeverTrump', 2)]
# #################
# #################
# 106
# [('TrumpRape', 3), ('SundayMorning', 3), ('TrumpPence16', 2), ('MAGA', 2), ('HillaryGropedMe', 2)]
# #################
# #################
# 108
# [('MAGA', 6), ('Trump2016', 4), ('trumptrain', 3), ('2A', 3), ('TRUMP', 3)]
# #################
# #################
# 109
# [('Wikileaks', 5), ('Trump', 5), ('Hillary', 4), ('Clinton', 3), ('MAGA3X', 2)]
# #################
# #################
# 110
# [('neverTrump', 1), ('Trump', 1), ('Dems4Trump', 1), ('Literally', 1), ('TrumpPence16', 1)]
# #################
# #################
# 111
# [('trumpRigsElection', 1), ('BlockBrockBot', 1), ('PodestaEmails8', 1), ('bernieorbust', 1), ('PosestaEmails', 1)]
# #################
# #################
# 114
# [('PodestaEmails9', 7), ('Trump', 6), ('Trump2016', 2), ('Hillary', 2), ('SNL', 2)]
# #################
# #################
# 115
# [('TrumpVsEverybody', 2), ('SundayMorning', 1), ('NextFakeTrumpVictim', 1), ('Trump', 1), ('WeWillRise', 1)]
# #################
# #################
# 116
# [('chelseacooleyaltman', 1), ('Clinton', 1), ('Hillary', 1), ('WikiLeaks', 1), ('LockHerUp', 1)]
# #################
# #################
# 117
# [('debate', 2), ('ChooChoo', 1), ('RestoreTheVRA', 1), ('MTP', 1), ('InvestYourVote', 1)]
# #################
# #################
# 118
# [('Trump', 4), ('SundayMorning', 1), ('Wikileaks', 1), ('TrumpRally', 1), ('crookedhillary', 1)]
# #################
# #################
# 119
# [('Trump', 16), ('MAGA', 9), ('PodestaEmails9', 9), ('HillaryGropedMe', 8), ('Hillary', 6)]
# #################
# #################
# 120
# [('MAGA', 4), ('ImWithPeace', 3), ('Trump', 3), ('PodestaEmails9', 3), ('WakeUpAmerica', 2)]
# #################
# #################
# 121
# [('Trump', 17), ('ImWithHer', 7), ('ME', 6), ('TRUMP', 4), ('WIKILEAKS', 4)]
# #################
# #################
# 123
# [('HillaryGropedMe', 4), ('SundayMorning', 3), ('Maga3x', 2), ('RIPJournalism', 2), ('FNCE', 1)]
# #################
# #################
# 124
# [('TrumpTrain', 7), ('imwithher', 5), ('MAGA', 5), ('USA', 4), ('TrumpPence16', 4)]
# #################
# #################
# 125
# [('Trump', 18), ('MAGA', 15), ('PodestaEmails9', 15), ('SundayMorning', 6), ('PodestaEmails', 6)]
# #################
# #################
# 126
# [('Trump', 7), ('TrumpPence16', 4), ('MAGA', 3), ('AmericaFirst', 2), ('NeverTrump', 2)]
# #################
# #################
# 127
# [('RhodeIsland', 1), ('Vetted', 1), ('NeverTrump', 1), ('Trump', 1), ('America1st', 1)]
# #################
# #################
# 129
# [('Trump', 3), ('democratic', 2), ('GOP', 2), ('RealElectionFraud', 1), ('VPDebate', 1)]
# #################
# #################
# 130
# [('MAGA', 4), ('Trump', 4), ('trump', 3), ('PodestaEmails9', 3), ('election', 2)]
# #################
# #################
# 131
# [('TRUMP', 1), ('CrookedHillary', 1), ('RobertDeNiro', 1), ('WakeUpAmerica', 1), ('Hillary', 1)]
# #################
# #################
# 132
# [('PodestaEmails9', 5), ('Hillary', 3), ('Trump', 3), ('Corruption', 2), ('NeverHillary', 2)]
# #################
# #################
# 133
# [('PodestaEmails9', 22), ('Trump', 9), ('MAGA', 5), ('HillaryGropedMe', 4), ('TrumpPence16', 3)]
# #################
# #################
# 134
# [('PollsArePhony', 1), ('HillaryClinton', 1), ('ISIS', 1), ('HillaryGropedMeToo', 1), ('ImWithHer', 1)]
# #################
# #################
# 135
# [('PodestaEmails9', 7), ('HillaryForPrison', 5), ('RIPJournalism', 5), ('Trump', 4), ('NeverHillary', 3)]
# #################
# #################
# 136
# [('NeverTrump', 6), ('Trump', 2), ('MAGA', 2), ('LockerRoomTalk', 1), ('BoycottHollywood', 1)]
# #################
# #################
# 138
# [('MAGA', 18), ('MSMbias', 10), ('Trump', 5), ('TrumpPence16', 4), ('Election2016', 3)]
# #################
# #################
# 140
# [('NeverTrump', 9), ('UniteBlue', 7), ('Sanity', 7), ('ClintonKaine', 7), ('BoycottTrump', 6)]
# #################
# #################
# 142
# [('Trump', 3), ('VoteTrumpPence16', 1), ('OhHillNo', 1), ('Zucker', 1), ('Clinton', 1)]
# #################
# #################
# 143
# [('PodestaEmails', 2), ('MAGA', 2), ('Clintonclan', 1), ('MillennialsForTrump', 1), ('Trump', 1)]
# #################
# #################
# 144
# [('FDT', 4), ('NeverTrump', 3), ('Trump', 3), ('PodestaEmails9', 3), ('ImWithHer', 2)]
# #################
# #################
# 145
# [('Trump', 4), ('1U', 2), ('NeverTrump', 2), ('HillaryGropedMe', 2), ('p2', 2)]
# #################
# #################
# 146
# [('Trump', 28), ('MAGA', 23), ('PodestaEmails9', 14), ('Wikileaks', 12), ('HillaryGropedMe', 10)]
# #################
# #################
# 147
# [('Trump', 13), ('MAGA', 12), ('NeverHillary', 9), ('100YearsStrong', 8), ('HillaryGropedMe', 7)]
# #################
# #################
# 148
# [('PodestaEmails9', 6), ('Clinton', 3), ('Trump', 3), ('CrookedHillary', 3), ('ImWithHer', 2)]
# #################
# #################
# 150
# [('Trump', 4), ('MAGA', 4), ('DC', 2), ('HillaryClinton', 1), ('NeverTrump', 1)]
# #################
# #################
# 151
# [('FeelTheBern', 3), ('OurRevolution', 3), ('Election2016', 3), ('Clinton', 2), ('Trump', 2)]
# #################
# #################
# 152
# [('Trump', 58), ('MAGA', 55), ('PodestaEmails9', 38), ('HillaryGropedMe', 30), ('SundayMorning', 28)]
# #################
# #################
# 153
# [('Trump', 16), ('SNL', 4), ('trump', 3), ('BoycottTrump', 1), ('WhinyLittleBitch', 1)]
# #################
# #################
# 154
# [('RiggedSystem', 2), ('Hillary', 2), ('HillaryGropedMe', 2), ('Trump', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 156
# [('WhinyLittleBitch', 2), ('rapist', 1), ('Clinton', 1), ('Trump', 1), ('SexualPredator', 1)]
# #################
# #################
# 157
# [('HillaryForPrison', 14), ('CrookedHillary', 14), ('Hillary2016', 13), ('Trump', 10), ('MAGA', 6)]
# #################
# #################
# 158
# [('Trump', 6), ('ImWithHer', 5), ('Wikileaks', 5), ('MAGA', 4), ('PodestaEmails9', 4)]
# #################
# #################
# 159
# [('yourownname', 15), ('PodestaEmails9', 7), ('Trump', 3), ('podestaemails9', 2), ('Wikileaks', 2)]
# #################
# #################
# 160
# [('PodestaEmails9', 14), ('Trump', 7), ('MAGA', 4), ('HillaryGropedMe', 3), ('CNN', 2)]
# #################
# #################
# 161
# [('Trump', 6), ('NeverHillary', 3), ('Wikileaks', 3), ('HillaryGropedMe', 3), ('maga', 2)]
# #################
# #################
# 163
# [('TRUMP', 3), ('Trump', 2), ('MAGA3X', 1), ('CrookedHillary', 1), ('BillTheRapist', 1)]
# #################
# #################
# 164
# [('Trump', 3), ('ImWithHer', 2), ('leshow', 2), ('MTP', 1), ('LostInAmerica', 1)]
# #################
# #################
# 165
# [('Trump', 13), ('MAGA', 4), ('SNL', 4), ('ImWithHer', 3), ('BillsRapes', 3)]
# #################
# #################
# 166
# [('MAGA', 6), ('PodestaEmails9', 5), ('Trump', 4), ('MAGA3X', 4), ('TrumpArmy', 3)]
# #################
# #################
# 168
# [('TrumpPence2016', 1), ('media', 1), ('ImWithHer', 1), ('BlackLivesMatter', 1), ('wikileaks', 1)]
# #################
# #################
# 170
# [('Trump', 5), ('MAGA', 4), ('TrumpPence16', 2), ('NeverHillary', 2), ('SundayMorning', 2)]
# #################
# #################
# 172
# [('Trump', 7), ('NorthCarolina', 6), ('Arizona', 5), ('Michigan', 5), ('Utah', 5)]
# #################
# #################
# 173
# [('totalblowoutcoming', 1), ('VoteItalianPeter', 1), ('CLTV', 1), ('falseflags', 1), ('USA', 1)]
# #################
# #################
# 174
# [('Rigged', 2), ('PodestEmails9', 1), ('Hillary', 1), ('HillaryClinton', 1), ('ISIS', 1)]
# #################
# #################
# 175
# [('MAGA', 3), ('AmericaFirst', 1), ('LGBTQ', 1), ('LatinosWithTrump', 1), ('GaysforTrump', 1)]
# #################
# #################
# 176
# [('Trump', 9), ('MAGA', 5), ('SundayMorning', 4), ('Trump2016', 3), ('Hillary', 3)]
# #################
# #################
# 177
# [('Hillary2016', 1), ('UniteBlue', 1), ('HillYes', 1), ('ImWithHer', 1), ('VoteBlue', 1)]
# #################
# #################
# 178
# [('HillaryGropedMe', 18), ('Trump', 6), ('maga', 2), ('Election', 2), ('hillarygropedme', 2)]
# #################
# #################
# 179
# [('Trump', 4), ('HappySunday', 3), ('MAGA', 3), ('FL', 2), ('California', 2)]
# #################
# #################
# 181
# [('NeverTrump', 8), ('Trump', 3), ('NeverTyranny', 2), ('Election2016', 2), ('NeverHillary', 2)]
# #################
# #################
# 182
# [('p2', 3), ('trump', 2), ('nevertrump', 2), ('TrumpTapes', 2), ('WATCH', 2)]
# #################
# #################
# 185
# [('PodestaEmails9', 2), ('HillaryGropedMe', 2), ('SundayMorning', 1), ('trump', 1), ('hillaryforprison', 1)]
# #################
# #################
# 186
# [('PodestaEmails9', 2), ('PayToPlay', 2), ('MAGA3X', 1), ('HillaryScandals', 1), ('Crooked', 1)]
# #################
# #################
# 187
# [('ClintonCoup', 3), ('PodestaEmails9', 3), ('PodestaEmails', 2), ('PodestEmails9', 1), ('TrumpforUC', 1)]
# #################
# #################
# 188
# [('NPD', 4), ('TrumpTapes', 3), ('Trump', 2), ('SNL', 2), ('GOP', 2)]
# #################
# #################
# 189
# [('Trump', 9), ('SNL', 5), ('MAGA', 4), ('GOP', 4), ('ChooChoo', 3)]
# #################
# #################
# 190
# [('trump', 2), ('hillary', 2), ('Trump', 2), ('police', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 191
# [('Trump', 8), ('Obama', 5), ('neverHillary', 3), ('Election2016', 3), ('USA', 2)]
# #################
# #################
# 192
# [('trump', 8), ('Islamic', 1), ('Muslim', 1), ('ISIS', 1), ('DumpTrump', 1)]
# #################
# #################
# 193
# [('Hillary', 5), ('Clinton', 3), ('Trump', 3), ('SundayMorning', 2), ('coup', 1)]
# #################
# #################
# 196
# [('Trump', 7), ('ImWithHer', 4), ('100YearsStrong', 3), ('dumptrump', 3), ('enoughisenough', 2)]
# #################
# #################
# 197
# [('Trump', 45), ('MAGA', 26), ('SundayMorning', 17), ('PodestaEmails9', 17), ('HillaryGropedMe', 14)]
# #################
# #################
# 198
# [('MAGA', 3), ('Trump', 3), ('SundayMorning', 2), ('LatinosForTrump', 2), ('Wikileaks', 2)]
# #################
# #################
# 199
# [('TrumpFatigue', 1), ('NeverTrump', 1), ('Trump', 1), ('ImWithHer', 1), ('DonaldTrump', 1)]
# #################
# #################
# 202
# [('Trump', 2), ('SNL', 2), ('NBC', 2), ('stopTrump', 1), ('NeverTrump', 1)]
# #################
# #################
# 203
# [('ImWithHer', 8), ('TrumpIsARapist', 3), ('DonaldTrump', 2), ('ShesMyShero', 1), ('1U', 1)]
# #################
# #################
# 205
# [('donaldtrump', 25), ('imwithher', 24), ('hillaryclinton', 24), ('Election2016', 7), ('Trump', 5)]
# #################
# #################
# 206
# [('HillaryGropedMe', 7), ('CNN', 4), ('JillNotHill', 2), ('MAGA', 2), ('TrumpTrain', 2)]
# #################
# #################
# 207
# [('Trump', 5), ('ClintonVsTrump', 2), ('NeverTrump', 2), ('SNL', 2), ('Election2016', 2)]
# #################
# #################
# 208
# [('Trump', 6), ('NeverTrump', 3), ('HillaryClinton', 1), ('CLTV', 1), ('NotOkay', 1)]
# #################
# #################
# 211
# [('GOPUnite', 2), ('SundayMorning', 1), ('Clinton', 1), ('TCOT', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 212
# [('ImWithHer', 6), ('Trump', 4), ('SNL', 4), ('icanhazPulitzernow', 2), ('Election2016', 2)]
# #################
# #################
# 214
# [('CNN', 1), ('PodestaEmails9', 1), ('scampaign', 1), ('Trump', 1), ('CrookedHillary', 1)]
# #################
# #################
# 215
# [('PodestaEmails9', 6), ('SundayMorning', 3), ('MAGA', 2), ('CNNsotu', 2), ('ThisWeek', 2)]
# #################
# #################
# 216
# [('Trump', 13), ('MAGA', 11), ('PodestaEmails9', 9), ('Clinton', 8), ('NeverHillary', 6)]
# #################
# #################
# 218
# [('BlackLivesMatter', 2), ('voter', 1), ('Trump', 1), ('OhioVotesEarly', 1), ('Undecided2016', 1)]
# #################
# #################
# 219
# [('Clinton', 18), ('Hillary', 17), ('Trump', 13), ('MAGA', 4), ('Debate', 3)]
# #################
# #################
# 221
# [('PodestaEmails9', 10), ('wikileaks', 9), ('breaking', 7), ('MAGA', 7), ('childabuse', 6)]
# #################
# #################
# 222
# [('Trump', 4), ('SundayMorning', 1), ('TrumpWasRight', 1), ('Journalists', 1), ('RealTime', 1)]
# #################
# #################
# 223
# [('Trump', 14), ('Wikileaks', 6), ('Hillary', 5), ('MAGA', 5), ('TrumpPence16', 4)]
# #################
# #################
# 227
# [('Trump', 10), ('MAGA', 8), ('Hillary', 6), ('PodestaEmails9', 6), ('TrumpPence16', 5)]
# #################
# #################
# 229
# [('TrumpPence16', 1), ('CrookedBarack', 1), ('MAGA', 1), ('CrookedHillary', 1), ('Election2016', 1)]
# #################
# #################
# 233
# [('MAGA', 15), ('Trump', 12), ('debate', 8), ('PodestaEmails9', 8), ('BigLeagueTruth', 7)]
# #################
# #################
# 234
# [('PodestaEmails9', 15), ('HillaryGropedMe', 9), ('Trump', 3), ('DOJ', 1), ('nhdem', 1)]
# #################
# #################
# 235
# [('FBICoverUp', 4), ('ClintonCorruption', 3), ('fbicoverup', 3), ('FBICoverup', 2), ('FBI', 2)]
# #################
# #################
# 236
# [('MAGA', 23), ('Christian', 16), ('ccot', 14), ('Trump', 6), ('tcot', 4)]
# #################
# #################
# 238
# [('Trump', 11), ('Hillary', 9), ('MAGA', 6), ('SundayMorning', 4), ('PodestaEmails9', 4)]
# #################
# #################
# 239
# [('nevertrumppence', 1), ('SundayMorning', 1), ('AmericaFirst', 1), ('SheriffCoon', 1), ('1stAmendment', 1)]
# #################
# #################
# 240
# [('Corgi', 1), ('Giuliani', 1), ('election2016', 1), ('Election2016', 1), ('ImWithHer', 1)]
# #################
# #################
# 243
# [('Trump', 4), ('Trump2016', 3), ('DishonestMedia', 2), ('tcot', 2), ('HillaryGropedMe', 2)]
# #################
# #################
# 244
# [('anybodybuthillary', 1), ('HILLARYCLINTON', 1), ('Arizona', 1), ('TRUMP', 1), ('Utah', 1)]
# #################
# #################
# 245
# [('MAGA', 12), ('Trump', 9), ('Hillary', 8), ('SundayMorning', 7), ('HillaryGropedMe', 6)]
# #################
# #################
# 246
# [('Trump', 5), ('NeverTrump', 4), ('trump', 3), ('HillaryGropedMe', 3), ('neocon', 2)]
# #################
# #################
# 248
# [('DonTheCon', 1), ('iowa', 1), ('Trump', 1), ('TrumperTantrum', 1), ('McMullinFin', 1)]
# #################
# #################
# 249
# [('Trump', 2), ('ParentFail', 2), ('Election2016', 2), ('HillaryClinton', 1), ('ThirdParty', 1)]
# #################
# #################
# 250
# [('Trump', 1), ('CrookedHillary', 1), ('BringItOn', 1), ('GuidingLight', 1), ('TeaParty', 1)]
# #################
# #################
# 251
# [('Wikileaks', 2), ('SundayMorning', 1), ('CCOT', 1), ('TRUMP', 1), ('1A', 1)]
# #################
# #################
# 253
# [('Trump', 2), ('WomenWhoVoteTrump', 1), ('Hillary', 1), ('CNN', 1), ('MAGA', 1)]
# #################
# #################
# 254
# [('latinosfortrump', 2), ('maga', 2), ('TrumpPence2016', 1), ('PodestaEmails9', 1), ('Disgusting', 1)]
# #################
# #################
# 256
# [('Trump', 12), ('election', 2), ('HillaryClinton', 1), ('clinton', 1), ('trump', 1)]
# #################
# #################
# 258
# [('Trump', 15), ('MAGA', 7), ('Clinton', 7), ('Trump2016', 4), ('PodestaEmails9', 3)]
# #################
# #################
# 259
# [('Trump', 2), ('NeverTrump', 1), ('WeWontBeErased', 1), ('ReinceCowards', 1), ('YesWeKaine', 1)]
# #################
# #################
# 261
# [('Trump', 9), ('trump', 3), ('Election2016', 3), ('GOP', 3), ('Trump2016', 2)]
# #################
# #################
# 263
# [('SundayMorning', 1), ('HillaryBecasue', 1), ('PodestaEmails9', 1), ('PodestaEmails8', 1), ('PodestaEmails', 1)]
# #################
# #################
# 266
# [('StopWW3', 3), ('PodestaEmails9', 2), ('RiggingForWar', 2), ('JillOrBust', 2), ('NeverHillary', 1)]
# #################
# #################
# 267
# [('Trump', 5), ('HillaryBecause', 4), ('HillaryGropedMe', 3), ('PodestaEmails9', 3), ('MSNBC', 2)]
# #################
# #################
# 269
# [('SundayMorning', 6), ('debate', 5), ('Hillary', 4), ('Trump', 4), ('Nukes', 2)]
# #################
# #################
# 270
# [('Trump', 5), ('SheWas13', 1), ('Mediafail', 1), ('SCOTUS', 1), ('GOP', 1)]
# #################
# #################
# 273
# [('Trump', 7), ('We', 1), ('MakeHillaryClintongotoprison', 1), ('clueless', 1), ('business', 1)]
# #################
# #################
# 276
# [('hypocrite', 1), ('Grabthembythep', 1), ('Rigged2016', 1), ('coward', 1), ('unfactled', 1)]
# #################
# #################
# 278
# [('BoycottCNN', 3), ('PodestaEmails9', 1), ('RiggedSystem', 1), ('realdonaldtrump', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 279
# [('NeverTrumpOrHillary', 3), ('MAGA', 2), ('LGBTI', 2), ('wikileaks', 1), ('EndTheFed', 1)]
# #################
# #################
# 280
# [('Trump', 4), ('HillaryClinton', 1), ('ShesWithUs', 1), ('DemStorm', 1), ('johnmccain', 1)]
# #################
# #################
# 281
# [('Trump', 3), ('HRCRealityCheck', 2), ('HillaryClinton', 2), ('crooked', 2), ('ImWithHer', 2)]
# #################
# #################
# 282
# [('Trump', 8), ('MAGA', 4), ('TrumpPence16', 3), ('PodestaEmails9', 3), ('CathyObrien', 2)]
# #################
# #################
# 284
# [('Trump', 2), ('Hillary', 2), ('Clinton', 1), ('PodestaEmails9', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 285
# [('Trump', 3), ('GrabHerByThePussy', 2), ('Vote', 2), ('PodestaEmails9', 1), ('100YearsStrong', 1)]
# #################
# #################
# 286
# [('Trump', 23), ('MAGA', 6), ('CrookedHillary', 4), ('WomenWhoVoteTrump', 2), ('Hillary', 2)]
# #################
# #################
# 287
# [('Rapist', 2), ('TimKaine', 1), ('HillaryClinton', 1), ('Trump2016', 1), ('Deplorable', 1)]
# #################
# #################
# 288
# [('Trump', 19), ('MAGA', 12), ('PodestaEmails9', 8), ('Wikileaks', 7), ('TrumpPence16', 6)]
# #################
# #################
# 289
# [('Trump', 14), ('MAGA', 13), ('Wikileaks', 7), ('PodestaEmails', 6), ('Clinton', 6)]
# #################
# #################
# 290
# [('SNL', 3), ('BoycottPayPal', 2), ('Trump', 2), ('AmJoy', 2), ('PowerPost', 1)]
# #################
# #################
# 291
# [('ImWithHer', 2), ('likea5yearold', 1), ('SNL', 1), ('HintHint', 1), ('IMWithHer', 1)]
# #################
# #################
# 293
# [('Trump', 2), ('NeverTrump', 2), ('HillaryClinton', 1), ('Clinton', 1), ('pandorasbox', 1)]
# #################
# #################
# 294
# [('SundayMorning', 1), ('NeverTrump', 1), ('trump', 1), ('SNL', 1), ('foxnews', 1)]
# #################
# #################
# 296
# [('Hillary', 17), ('Debate', 16), ('Clinton', 15), ('debate', 9), ('SWVA', 2)]
# #################
# #################
# 298
# [('Trump2016', 11), ('CrookedHillary', 5), ('Faith', 3), ('tcot', 3), ('MediaBias', 2)]
# #################
# #################
# 300
# [('MAGA', 18), ('Trump', 14), ('PodestaEmails9', 9), ('HillaryClinton', 7), ('TrumpTrain', 7)]
# #################
# #################
# 301
# [('Trump', 14), ('TrumpCheck', 4), ('NeverTrump', 3), ('BoycottNordstrom', 2), ('ImWithHer', 2)]
# #################
# #################
# 302
# [('HillarysEmails', 1), ('Jews', 1), ('Chicago', 1), ('MSM', 1), ('democrats', 1)]
# #################
# #################
# 303
# [('Trump', 6), ('MTP', 5), ('debate', 3), ('MAGA', 3), ('pence', 2)]
# #################
# #################
# 304
# [('RussianConnection', 15), ('CLTV', 5), ('PuTrump', 5), ('unfit', 3), ('ImWithHer', 3)]
# #################
# #################
# 305
# [('Trump', 3), ('Jill2016', 2), ('BasketOfDeplorablesAndDespicable', 1), ('NoDAPL', 1), ('GOP', 1)]
# #################
# #################
# 310
# [('Trump', 5), ('LaCasaBianca', 4), ('Clintons', 2), ('Hillary', 2), ('Clinton', 2)]
# #################
# #################
# 311
# [('Trump', 9), ('Hillary', 7), ('Media', 6), ('ClintonKarma', 6), ('PussyGate', 5)]
# #################
# #################
# 314
# [('PodestaEmails9', 7), ('WakeUpAmerica', 3), ('Trump', 3), ('NeverHillary', 2), ('Wikileaks', 2)]
# #################
# #################
# 315
# [('CrookedDonald', 2), ('RapeyDonald', 2), ('RacistsForTrump', 1), ('TraitorTrump', 1), ('PJNET', 1)]
# #################
# #################
# 316
# [('HillaryBecasue', 1), ('TRUMP', 1), ('Crooked', 1), ('PodestaEmails9', 1), ('Clintons', 1)]
# #################
# #################
# 318
# [('Election2016', 4), ('Hillary', 4), ('MAGA', 4), ('Trump', 4), ('NeverTrump', 3)]
# #################
# #################
# 319
# [('trump', 5), ('Trump', 4), ('icanhazPulitzernow', 2), ('GOP', 2), ('IcanhazPulitzernow', 1)]
# #################
# #################
# 322
# [('PredatorDon', 16), ('debate', 12), ('Unhinged', 1), ('imwither', 1), ('SniffingDon', 1)]
# #################
# #################
# 323
# [('SundayMorning', 1), ('nevertrump', 1), ('Trump', 1), ('AgentOrange', 1), ('Winning', 1)]
# #################
# #################
# 324
# [('Hillary', 2), ('MAGA', 2), ('Clinton', 2), ('Trump', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 327
# [('bothsidery', 4), ('CorruptMedia', 2), ('JCT_Article', 2), ('MAGA', 2), ('WhereIsTheMedia', 1)]
# #################
# #################
# 328
# [('Trump', 12), ('GOP', 3), ('JohnsonWeld2016', 2), ('election', 2), ('Trump2016', 2)]
# #################
# #################
# 330
# [('MAGA', 4), ('Trump', 2), ('TrumpPence16', 2), ('BigLeagueTruth', 2), ('TRUMPKIN', 2)]
# #################
# #################
# 331
# [('NeverTrump', 5), ('ImWithHer', 3), ('DonTheCon', 3), ('DumpTrump', 3), ('UniteBlue', 2)]
# #################
# #################
# 332
# [('Hillary', 2), ('CLINTON', 1), ('Trump', 1), ('IvankaTrump', 1), ('BringBernieBack', 1)]
# #################
# #################
# 334
# [('wikileaks', 2), ('protectionRacket', 1), ('Trump', 1), ('Election2016', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 335
# [('HillaryGropedMeToo', 2), ('SundayMorning', 1), ('Trump', 1), ('PodestaEmails9', 1), ('tlot', 1)]
# #################
# #################
# 337
# [('PodestaEmails9', 2), ('PodestaEmails10', 2), ('Birther', 1), ('Trump', 1), ('TrumpRevolutionThreats', 1)]
# #################
# #################
# 339
# [('trump', 6), ('trumppence16', 6), ('trump2016', 6), ('maga', 6), ('trumptrain', 6)]
# #################
# #################
# 340
# [('MAGA', 3), ('MAGA3X', 2), ('FeelTheBern', 1), ('HillaryClinton', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 341
# [('MSNBC', 34), ('MAGA', 23), ('TrumpPence16', 23), ('Trump', 22), ('FoxNews', 17)]
# #################
# #################
# 342
# [('Trump', 12), ('PodestaEmails9', 11), ('MAGA', 9), ('Hillary', 8), ('Wikileaks', 6)]
# #################
# #################
# 343
# [('tcot', 5), ('Trump', 5), ('Hillary', 4), ('HillaryGropedMe', 3), ('NeverHillary', 2)]
# #################
# #################
# 344
# [('Trump', 3), ('HillaryClinton', 2), ('Hillary', 2), ('Wikileaks', 2), ('tcot', 2)]
# #################
# #################
# 345
# [('Trump', 4), ('WomenStopTrumpParty', 2), ('Hillary', 2), ('Canada', 1), ('HillaryClinton', 1)]
# #################
# #################
# 346
# [('Trump', 7), ('MAGA', 3), ('Hillary', 2), ('tcot', 2), ('PodestaEmails9', 2)]
# #################
# #################
# 347
# [('PodestaEmails9', 21), ('podestaemails9', 3), ('SundayMorning', 3), ('Trump', 3), ('PodestaEmails', 3)]
# #################
# #################
# 348
# [('UNFIT', 3), ('wikileaks', 2), ('TrumpPence16', 1), ('MAGA3X', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 349
# [('Trump', 4), ('Election2016', 2), ('100YearsStrong', 1), ('ageism', 1), ('MediaBias', 1)]
# #################
# #################
# 350
# [('Trump', 6), ('HillaryGropedMe', 4), ('MAGA', 3), ('wikileaks', 2), ('TrumpPence16', 2)]
# #################
# #################
# 351
# [('MAGA', 16), ('Trump', 12), ('PodestaEmails9', 9), ('Hillary', 8), ('HillaryGropedMe', 6)]
# #################
# #################
# 352
# [('PodestaEmails9', 12), ('DNC', 7), ('Clinton', 7), ('Campaign', 5), ('PodestaEmails8', 3)]
# #################
# #################
# 354
# [('MAGA', 8), ('Trump', 8), ('AmericaFirst', 3), ('TrumpPence16', 3), ('ClintonCartel', 2)]
# #################
# #################
# 355
# [('trump', 2), ('SNL', 2), ('AmericaIsWoke', 1), ('CrookedHillary', 1), ('PodestaEmails', 1)]
# #################
# #################
# 356
# [('BLM', 2), ('Trump', 2), ('me', 1), ('Clinton', 1), ('teachers', 1)]
# #################
# #################
# 358
# [('AmericaFirst', 1), ('Jobs', 1), ('PodestaEmails9', 1), ('FakeTrumpVictim', 1), ('TrumpPence16', 1)]
# #################
# #################
# 359
# [('HillaryGropedMe', 3), ('PodestaEmails9', 2), ('ImWithHer', 2), ('ClintonVictimsLivesMatter', 1), ('100YearsStrong', 1)]
# #################
# #################
# 360
# [('Trump', 3), ('debate', 3), ('DonaldTrump', 2), ('SundayMorning', 1), ('Arizona', 1)]
# #################
# #################
# 361
# [('Syria', 1), ('Clinton', 1), ('Trump', 1), ('BorisJohnson', 1), ('Aleppo', 1)]
# #################
# #################
# 363
# [('BoycottTrump', 1), ('Trump', 1), ('ImWithHer', 1), ('Hillary', 1), ('NeverTrump', 1)]
# #################
# #################
# 365
# [('MAGA', 3), ('Trump', 2), ('WikiLeaks', 1), ('luciferintheflesh', 1), ('tacky', 1)]
# #################
# #################
# 366
# [('HllaryClinton', 1), ('Trump', 1), ('SNL', 1), ('AboveTheLaw', 1), ('LockHerUp', 1)]
# #################
# #################
# 367
# [('Trump', 10), ('Hillary', 4), ('HillaryGropedMe', 4), ('ImWithHer', 3), ('PodestaEmails', 3)]
# #################
# #################
# 369
# [('Victims', 1), ('Trump', 1), ('USA', 1), ('GlobalConspiracy', 1), ('Election', 1)]
# #################
# #################
# 370
# [('p2', 1), ('Trump', 1), ('conspiracytheorists', 1), ('100YearsStrong', 1), ('DonaldTrump', 1)]
# #################
# #################
# 371
# [('PodestaEmails9', 7), ('SundayMorning', 4), ('Trump', 4), ('ImWithHer', 3), ('Clinton', 3)]
# #################
# #################
# 373
# [('PodestaEmails9', 9), ('MAGA', 7), ('HillaryGropedMe', 7), ('Hillary', 5), ('SundayMorning', 5)]
# #################
# #################
# 374
# [('SundayMorning', 3), ('PodestaEmails9', 1), ('HillaryClinton', 1), ('HillaryGropedMe', 1), ('debate', 1)]
# #################
# #################
# 375
# [('tcot', 9), ('pjnet', 7), ('gop', 6), ('Trump', 5), ('MAGA', 3)]
# #################
# #################
# 377
# [('MAGA', 7), ('Trump', 5), ('Hillary', 4), ('TrumpTrain', 3), ('MakeAmericaGreatAgain', 2)]
# #################
# #################
# 378
# [('Trump', 3), ('responsiblity', 1), ('morals', 1), ('personal', 1), ('ASHAT', 1)]
# #################
# #################
# 383
# [('PodestaEmails9', 4), ('MAGA', 3), ('Election2016', 2), ('PodestaEmails', 2), ('TrumpTrain', 2)]
# #################
# #################
# 386
# [('Trump', 3), ('Wikileaks', 2), ('projection', 1), ('ClintonCartel', 1), ('Amjoy', 1)]
# #################
# #################
# 387
# [('Trump2016', 5), ('2A', 4), ('MAGA', 3), ('politics', 2), ('tcot', 2)]
# #################
# #################
# 388
# [('CNN', 1), ('Zucker', 1), ('PodestaEmails8', 1), ('Trump', 1), ('putin', 1)]
# #################
# #################
# 389
# [('MAGA', 8), ('Hillary', 5), ('Trump', 5), ('SundayMorning', 3), ('maga', 3)]
# #################
# #################
# 390
# [('MAGA', 5), ('TCOT', 4), ('PJNET', 3), ('AmericaFirst', 2), ('TrumpPence16', 2)]
# #################
# #################
# 392
# [('SundayMorning', 1), ('RogerAiles', 1), ('SNL', 1), ('POLLS', 1), ('TRUE_THAT', 1)]
# #################
# #################
# 393
# [('Trump', 5), ('MAGA', 4), ('FL', 3), ('NH', 3), ('AMERiCAFiRST', 3)]
# #################
# #################
# 394
# [('SundayMorning', 2), ('WomenWhoVoteTrump', 1), ('Clinton', 1), ('Trump', 1), ('Bosnia', 1)]
# #################
# #################
# 395
# [('ImWithHer', 2), ('Trump', 2), ('trump', 1), ('AMJoy', 1), ('Racist', 1)]
# #################
# #################
# 396
# [('Trump', 24), ('Clinton', 5), ('GOP', 4), ('RNC', 4), ('trump', 3)]
# #################
# #################
# 397
# [('Tcot', 2), ('Mediaite', 2), ('MeetThePress', 2), ('toxicTrump', 1), ('RudyGiuiliani', 1)]
# #################
# #################
# 398
# [('Trump', 14), ('MAGA', 9), ('Clinton', 6), ('PodestaEmails9', 5), ('Hillary', 5)]
# #################
# #################
# 399
# [('TrumpPence16', 3), ('MAGA', 2), ('ClintonScandals', 1), ('Trump', 1), ('tcot', 1)]
# #################
# #################
# 400
# [('Clinton', 2), ('HillaryGropedMe', 2), ('ClintonVictimsLivesMatter', 1), ('CrookedHillaryPaidTrolls', 1), ('Maga', 1)]
# #################
# #################
# 403
# [('MAGA', 3), ('Trump', 3), ('PodestaEmails', 2), ('MakeAmericaGreatAgain', 2), ('WomenWhoVoteTrump', 1)]
# #################
# #################
# 404
# [('ohthehumanity', 1), ('Corruption', 1), ('trump', 1), ('MakeAmericaGreatAgain', 1), ('Dems4Trump', 1)]
# #################
# #################
# 405
# [('prolife', 3), ('prowoman', 2), ('NeverTrump', 2), ('Trump', 1), ('NeverHillary', 1)]
# #################
# #################
# 406
# [('clownshow', 1), ('AmericaFirst', 1), ('NeverTrump', 1), ('TrumpKnowNothingism', 1), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 407
# [('PodestaEmails9', 5), ('TrumpFatigue', 4), ('ChooChoo', 3), ('DAPL', 3), ('MAGA', 3)]
# #################
# #################
# 409
# [('TrumpPence16', 6), ('AmericaFirst', 6), ('MAGA', 6), ('Jobs', 4), ('Ohio', 2)]
# #################
# #################
# 410
# [('HillaryGropedMe', 8), ('NaziTrump', 3), ('Patriots', 3), ('crookedhillary', 1), ('Right2BHeard', 1)]
# #################
# #################
# 413
# [('MAGA', 9), ('NeverHillary', 5), ('TrumpPence16', 4), ('Trump', 4), ('MSM', 3)]
# #################
# #################
# 415
# [('SundayMorning', 3), ('PodestaEmails9', 3), ('CNNSOTU', 3), ('TrumpPence16', 2), ('MAGA', 2)]
# #################
# #################
# 418
# [('Trump', 12), ('MAGA', 11), ('TrumpPence16', 9), ('Wikileaks', 6), ('PodestaEmails', 6)]
# #################
# #################
# 419
# [('Election2016', 2), ('HillarysEmails', 1), ('c4news', 1), ('FT', 1), ('Trump', 1)]
# #################
# #################
# 422
# [('TrumpCheck', 2), ('p2', 1), ('tcot', 1), ('sexualassault', 1), ('Election2016', 1)]
# #################
# #################
# 424
# [('TRUMP', 4), ('MSNBC', 3), ('RACISM', 3), ('LIAR', 3), ('CLEVELAND', 3)]
# #################
# #################
# 428
# [('HillaryClinton', 2), ('centralparkfive', 2), ('ImWithHer', 2), ('DemStorm', 2), ('CNNSucks', 2)]
# #################
# #################
# 429
# [('PodestaEmails9', 3), ('feedly', 1), ('mustread', 1), ('Trump', 1), ('DNC', 1)]
# #################
# #################
# 430
# [('POLL', 2), ('p2', 1), ('FPU', 1), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 431
# [('Trump', 12), ('Hillary', 6), ('Wikileaks', 6), ('SundayMorning', 6), ('ImWithHer', 5)]
# #################
# #################
# 434
# [('abelincoln', 4), ('millenials', 3), ('We', 2), ('Who', 2), ('Wikileaks', 2)]
# #################
# #################
# 437
# [('Evangelical', 3), ('Christian', 3), ('maddow', 2), ('p2', 1), ('Trump', 1)]
# #################
# #################
# 438
# [('PodestaEmails', 3), ('Trump', 2), ('SteinBaraka', 1), ('wikileaks', 1), ('Fraud', 1)]
# #################
# #################
# 439
# [('Trump', 6), ('DonaldTrump', 3), ('PodestaEmails9', 2), ('LOSERTRUMP', 2), ('Hillary', 2)]
# #################
# #################
# 441
# [('HillaryGropedMe', 3), ('FakeNutritionFacts', 1), ('PodestaEmails9', 1), ('GoldmanSach', 1), ('hillarygropedmetoo', 1)]
# #################
# #################
# 442
# [('tcot', 9), ('MAGA', 9), ('Trump', 7), ('PodestaEmails', 6), ('TrumpPence16', 6)]
# #################
# #################
# 443
# [('Trump', 2), ('KansasPlot', 1), ('liar', 1), ('GoingOutOnALimb', 1), ('uniteblue', 1)]
# #################
# #################
# 444
# [('NeverTrump', 2), ('Trump', 2), ('debate', 2), ('Election2016', 2), ('DonTheCon', 1)]
# #################
# #################
# 447
# [('debates', 1), ('AMjoy', 1), ('TrumpTapes', 1), ('TrumpCheck', 1), ('Assange', 1)]
# #################
# #################
# 450
# [('Revolution', 1), ('Clinton', 1), ('SNL', 1), ('VoteTrump', 1), ('Axelrod', 1)]
# #################
# #################
# 451
# [('Trump', 16), ('MAGA', 11), ('TrumpPence16', 11), ('PodestaEmails', 6), ('AmericaFirst', 6)]
# #################
# #################
# 453
# [('Trump', 3), ('ChristianWomenPreach', 1), ('SmartNews', 1), ('SNL', 1), ('LGBTQ', 1)]
# #################
# #################
# 454
# [('p2', 2), ('nevertrump', 2), ('Trump', 2), ('dumptrump', 2), ('NeverTrump', 2)]
# #################
# #################
# 456
# [('Wikileaks', 2), ('Trump', 2), ('Hillary', 2), ('PAC', 1), ('Election2016', 1)]
# #################
# #################
# 457
# [('DumbDonald', 4), ('deleteyourself', 3), ('deleteyourcampain', 2), ('ImWithHer', 2), ('AL02', 1)]
# #################
# #################
# 459
# [('MAGA', 4), ('ccot', 3), ('tcot', 3), ('maga', 3), ('gop', 3)]
# #################
# #################
# 460
# [('Trump', 2), ('p2', 1), ('Libya', 1), ('Voters', 1), ('LawAndOrder', 1)]
# #################
# #################
# 461
# [('HillaryGropedMe', 3), ('PodestaEmails', 2), ('PodestaEmails9', 2), ('Crooked', 1), ('PayToPlay', 1)]
# #################
# #################
# 462
# [('HillaryGropedMe', 6), ('PodestaEmails9', 3), ('Wikileaks', 3), ('CrookedHillary', 2), ('MAGA3X', 1)]
# #################
# #################
# 463
# [('HillaryLiesMatter', 2), ('HILLARY', 2), ('LIAR', 1), ('Trump', 1), ('clintoncorruption', 1)]
# #################
# #################
# 465
# [('Trump', 5), ('imwithher', 2), ('Reflection', 2), ('WIBackHer', 1), ('nailedit', 1)]
# #################
# #################
# 466
# [('Trump', 2), ('Election2016', 2), ('NeverTrump', 1), ('LoveAndKindness', 1), ('TrumpTapes', 1)]
# #################
# #################
# 467
# [('PJNET', 13), ('MAGA', 8), ('DefundPP', 4), ('Benghazi', 3), ('prolife', 2)]
# #################
# #################
# 468
# [('SundayMorning', 3), ('LockHerUp', 2), ('trump', 1), ('BrockTurner', 1), ('PodestaEmail9', 1)]
# #################
# #################
# 470
# [('ImWithHer', 2), ('p2', 1), ('Trump', 1), ('AgentOrange', 1), ('TrumpTapes', 1)]
# #################
# #################
# 471
# [('PodestaEmails9', 8), ('RiggedSystem', 2), ('Trump', 2), ('TrumpTrain', 1), ('USA', 1)]
# #################
# #################
# 476
# [('Trump', 3), ('RealElectionFraud', 1), ('IDIOT', 1), ('LockerRoomTalk', 1), ('TrumpCult', 1)]
# #################
# #################
# 477
# [('Trump', 4), ('Election2016', 3), ('SundayMorning', 2), ('PodestaEmails9', 2), ('HillaryClinton', 1)]
# #################
# #################
# 481
# [('TheDebtIsTooDamnHigh', 1), ('ACA', 1), ('TrumpCon', 1), ('SNL', 1), ('TrumpsALoser', 1)]
# #################
# #################
# 482
# [('Election2016', 4), ('Trump', 3), ('wishfuldrinking', 2), ('HRC', 2), ('EvangelicalsAgainstTrump', 1)]
# #################
# #################
# 484
# [('Trump', 4), ('SundayMorning', 2), ('Trump2016', 2), ('MAGA', 2), ('HillaryClinton', 1)]
# #################
# #################
# 485
# [('FakeTrumpVictim', 2), ('Wikileaks', 2), ('FakeTrumpVictims', 1), ('TRUMP', 1), ('Reagan', 1)]
# #################
# #################
# 486
# [('MAGA', 2), ('BernieSanders', 1), ('HillaryEmails', 1), ('Clinton', 1), ('Trump', 1)]
# #################
# #################
# 487
# [('Hillary', 3), ('MAGA', 2), ('ccot', 1), ('Christian', 1), ('MAGA3X', 1)]
# #################
# #################
# 488
# [('Election2016', 4), ('Trump', 3), ('PodestaEmails9', 3), ('Deplorables', 2), ('MAGA', 2)]
# #################
# #################
# 489
# [('HillarysEmails', 1), ('HillaryClinton', 1), ('Trump', 1), ('FeelTheBern', 1), ('PodestaEmails', 1)]
# #################
# #################
# 491
# [('ImWithHer', 9), ('HillYes', 7), ('HFA', 6), ('Hillary2016', 6), ('VoteBlue', 6)]
# #################
# #################
# 492
# [('RacistHillary', 7), ('HatefulHillary', 7), ('PodestaEmails9', 5), ('RiggedSystem', 2), ('TrumpPence16', 2)]
# #################
# #################
# 493
# [('P2', 2), ('PJNET', 2), ('NoLegacy', 1), ('TCOT', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 494
# [('MAGA', 5), ('Trump', 5), ('PodestaEmails9', 5), ('wikileaks', 2), ('TrumpState', 2)]
# #################
# #################
# 495
# [('NoMoreMoldySandwiches', 2), ('election', 2), ('JohnsonWeld2016', 1), ('Trump', 1), ('HillaryBecause', 1)]
# #################
# #################
# 496
# [('TrumpPence16', 9), ('Trump', 5), ('trump', 4), ('MAGA', 4), ('SundayMorning', 2)]
# #################
# #################
# 498
# [('ThinkAmerica', 59), ('MAGA', 4), ('Trump', 4), ('PodestaEmails7', 3), ('TrumpTrain', 3)]
# #################
# #################
# 499
# [('Trump', 5), ('trump', 3), ('ImWithHer', 3), ('WhinyLittleBitch', 2), ('billmaher', 2)]
# #################
# #################
# 500
# [('Trump', 3), ('CACD49', 2), ('p2', 1), ('India', 1), ('GOPfail', 1)]
# #################
# #################
# 501
# [('clinton', 3), ('PodestaEmails9', 3), ('podestaemails', 2), ('TRUMP', 2), ('sanders', 1)]
# #################
# #################
# 503
# [('ImWithHer', 3), ('Trump', 2), ('p2', 1), ('SundayMorning', 1), ('copolitics', 1)]
# #################
# #################
# 506
# [('t4a', 3), ('TrutherbotArmy', 3), ('STOPIT', 1), ('RIGHTWINGMEDIA', 1), ('IhJ5', 1)]
# #################
# #################
# 510
# [('MAGA', 6), ('Trump', 2), ('SundayMorning', 1), ('ClintonCollapse', 1), ('Cuck', 1)]
# #################
# #################
# 511
# [('Papal', 8), ('Pope', 8), ('Trump', 5), ('s', 2), ('2A', 2)]
# #################
# #################
# 512
# [('tcot', 7), ('Trump', 7), ('Hope', 2), ('DNCHack', 1), ('wikileaks', 1)]
# #################
# #################
# 513
# [('Trump', 1), ('Birther', 1), ('GOPhypocrite', 1), ('TrumpRevolutionThreats', 1), ('CNNSOTU', 1)]
# #################
# #################
# 514
# [('Trump', 2), ('DropOutHillary', 1), ('SundayMorning', 1), ('Putin', 1), ('nevertrump', 1)]
# #################
# #################
# 515
# [('Trump', 7), ('PodestaEmails9', 6), ('Wikileaks', 5), ('MAGA', 5), ('RiggedSystem', 2)]
# #################
# #################
# 516
# [('HelpWikileaks', 1), ('MAGA', 1), ('ISIS', 1), ('HillaryClinton', 1), ('fightfor15bc', 1)]
# #################
# #################
# 517
# ...
# #################
# #################
# 1212
# [('SundayMorning', 1), ('trump', 1), ('TrumpTapes', 1), ('PodestaEmails9', 1), ('GOPRapeCulture', 1)]
# #################
# #################
# 1218
# [('JohnsonWeld2016', 1), ('VoteYourFuture', 1), ('NoQuarter', 1), ('hope', 1), ('Libertarian', 1)]
# #################
# #################
# 1220
# [('UniteBlue', 2), ('sanders', 1), ('podestaemails', 1), ('HFA', 1), ('RT', 1)]
# #################
# #################
# 1222
# [('PodestaEmails9', 6), ('MAGA', 4), ('Trump', 3), ('GOPBombing', 3), ('HillaryClinton', 2)]
# #################
# #################
# 1224
# [('Trump', 2), ('MAGA', 2), ('WikiLeak', 1), ('millennials', 1), ('student', 1)]
# #################
# #################
# 1226
# [('ReligiousFreedom', 1), ('CCOT', 1), ('Trump', 1), ('HillaryGropedMeToo', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 1227
# [('Trump', 4), ('MAGA', 2), ('HillaryGropedMe', 2), ('TrumpLandslide', 1), ('croockedhillary', 1)]
# #################
# #################
# 1228
# [('Trump', 1), ('TrumpCheck', 1), ('TerrifyingTrump', 1), ('100YearsStrong', 1), ('TrumpsterFire', 1)]
# #################
# #################
# 1229
# [('Trump', 3), ('MAGA', 2), ('TrumpPence2016', 1), ('imwithher', 1), ('tonight', 1)]
# #################
# #################
# 1233
# [('p2', 2), ('topprog', 2), ('Trump', 2), ('BoycottNordstrom', 2), ('NCPol', 1)]
# #################
# #################
# 1234
# [('TogetherWeWin', 3), ('MAGA', 3), ('TrumpPence2016', 2), ('Trump', 2), ('LationsWithTrump', 2)]
# #################
# #################
# 1235
# [('PodestaEmails9', 19), ('Trump', 4), ('Wikileaks', 3), ('MAGA', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 1236
# [('Trump', 3), ('maga3x', 2), ('FixedElection', 1), ('art', 1), ('CrookedFBI', 1)]
# #################
# #################
# 1240
# [('Trump', 2), ('Pennsylvania', 1), ('Ohio', 1), ('hillarybecause', 1), ('HillYes', 1)]
# #################
# #################
# 1243
# [('NeverTrump', 1), ('Trump', 1), ('SNL', 1), ('NeverTrumpOrHillary', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 1247
# [('Trump', 5), ('2A', 3), ('AltRight', 3), ('Bible', 1), ('CrookedHillary', 1)]
# #################
# #################
# 1249
# [('Trump', 20), ('PodestaEmails9', 16), ('MAGA', 12), ('Hillary', 8), ('HillaryGropedMe', 7)]
# #################
# #################
# 1254
# [('Trump', 8), ('PodestaEmails9', 3), ('poll', 2), ('Election2016', 2), ('TRUMP', 2)]
# #################
# #################
# 1257
# [('INDEPENDENTS', 2), ('MILLENIALS', 2), ('LIBERTARIANS', 2), ('ALVEDAKING', 1), ('FeelTheBern', 1)]
# #################
# #################
# 1258
# [('Trump', 5), ('SNL', 2), ('scary', 1), ('TranslatingTrumpy', 1), ('NEVERTRUMP', 1)]
# #################
# #################
# 1261
# [('MAGA', 4), ('MakeAmericaGreatAgain', 2), ('trump', 1), ('voters', 1), ('Trump', 1)]
# #################
# #################
# 1263
# [('Trump', 2), ('Benghazi', 1), ('Rapist', 1), ('DNC', 1), ('Hillary', 1)]
# #################
# #################
# 1264
# [('NuclearNightmare', 2), ('NorthKoreanKOOK', 2), ('DonTheThinSkinnedCON', 2), ('StarWars', 1), ('ohwait', 1)]
# #################
# #################
# 1266
# [('TRUMP', 6), ('JFK', 2), ('TRICKYdick', 2), ('MLK', 2), ('REAGAN', 2)]
# #################
# #################
# 1268
# [('PodestaEmails', 5), ('MAGA', 5), ('Clinton', 5), ('ImWithHer', 3), ('SundayMorning', 3)]
# #################
# #################
# 1270
# [('MAGA', 3), ('Trump', 3), ('AmericaFirst', 2), ('TrumpPence16', 2), ('Hillary', 2)]
# #################
# #################
# 1272
# [('AmericaFirst', 2), ('Jobs', 2), ('TrumpPence16', 2), ('Ohio', 2), ('MAGA', 2)]
# #################
# #################
# 1276
# [('PodestaEmails9', 2), ('VoteTrumpPence16', 1), ('REAL', 1), ('tcot', 1), ('PowerToThePeople', 1)]
# #################
# #################
# 1281
# [('tcot', 3), ('Catholic', 2), ('ncpol', 2), ('co', 2), ('oh', 2)]
# #################
# #################
# 1284
# [('Trump', 10), ('NeverHillary', 4), ('Hillary', 3), ('MAGA', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 1287
# [('trump', 2), ('dates', 1), ('WomenWhoVoteTrump', 1), ('Imwithher', 1), ('voteblue', 1)]
# #################
# #################
# 1288
# [('trumpismplusinmypants', 1), ('Trump', 1), ('imwithher', 1), ('Hillary', 1), ('USElection', 1)]
# #################
# #################
# 1289
# [('PodestaEmails9', 2), ('HillaryGropedMe', 2), ('SundayMorning', 1), ('HillaryClinton', 1), ('Clinton', 1)]
# #################
# #################
# 1290
# [('Clinton', 1), ('Trump', 1), ('Jacinallhonesty', 1), ('InvestYourVote', 1), ('PodestaEmails', 1)]
# #################
# #################
# 1295
# [('EXCLUSIVE', 4), ('Clinton', 4), ('Trump', 4), ('BillClinton', 2), ('biased', 1)]
# #################
# #################
# 1297
# [('tcot', 18), ('p2', 17), ('pjnet', 13), ('SundayMorning', 1), ('Trump', 1)]
# #################
# #################
# 1298
# [('TeamTrump', 1), ('HillaryClinton', 1), ('debates', 1), ('PodestaEmails9', 1), ('debate', 1)]
# #################
# #################
# 1300
# [('PodestaEmails9', 14), ('HillaryGropedMe', 7), ('SundayMorning', 3), ('TrumpPence2016', 1), ('trump', 1)]
# #################
# #################
# 1304
# [('HillaryClinton', 11), ('ImWithHer', 11), ('Strongertogether', 11), ('WakeUpAmerica', 9), ('millennials', 8)]
# #################
# #################
# 1305
# [('debate', 2), ('Trump', 1), ('PodestaEmails9', 1), ('MikePence', 1), ('Debate', 1)]
# #################
# #################
# 1306
# [('Trump', 6), ('PodestaEmails9', 2), ('MAGA', 2), ('HillaryClinton', 1), ('NOW', 1)]
# #################
# #################
# 1309
# [('TrumpSupporters', 1), ('Trump', 1), ('SNL', 1), ('NeverHas', 1), ('sad', 1)]
# #################
# #################
# 1311
# [('Romney', 2), ('FireChuckTodd', 2), ('p2', 1), ('TrumpTapes', 1), ('FireMatLauer', 1)]
# #################
# #################
# 1317
# [('Hillary', 1), ('ClimateFarce', 1), ('GUNVOTE', 1), ('pathetic', 1), ('Trump', 1)]
# #################
# #################
# 1318
# [('Welfarefortherich', 1), ('MSM', 1), ('Systemriggedfortherich', 1), ('debate', 1), ('Trump', 1)]
# #################
# #################
# 1320
# [('PodestaEmails9', 3), ('HillaryGropedMeToo', 2), ('Trump2016', 2), ('HillaryGropedMe', 2), ('VoteTrumpPence16', 1)]
# #################
# #################
# 1324
# [('Trump', 2), ('ragereport', 2), ('PodestaEmails', 2), ('SundayMorning', 1), ('NeverTrump', 1)]
# #################
# #################
# 1329
# [('Trump', 3), ('Hillary2016', 1), ('Putin', 1), ('Clinton', 1), ('SNL', 1)]
# #################
# #################
# 1330
# [('RethinkNotRestart', 1), ('mustread', 1), ('nuclear', 1), ('WillSmith', 1), ('NoNukes', 1)]
# #################
# #################
# 1333
# [('Georgia', 1), ('Hypocrisy', 1), ('NeedyLatinos', 1), ('ImWithHer', 1), ('TruePundit', 1)]
# #################
# #################
# 1334
# [('Trump', 3), ('CrookedHillary', 3), ('Trump2016', 2), ('debate', 2), ('HillaryClinton', 1)]
# #################
# #################
# 1337
# [('Trump2016', 4), ('MakeAmericaGreatAgain', 3), ('TrumpTrain', 3), ('Wikileaks', 2), ('Time', 2)]
# #################
# #################
# 1340
# [('AmericaKnows', 1), ('DNCleak', 1), ('Clinton', 1), ('Trump', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 1341
# [('PodestaEmails9', 2), ('sundaymorning', 1), ('PodestaEmails', 1), ('ClintonEmails', 1), ('Wikileaks', 1)]
# #################
# #################
# 1344
# [('HillaryBecause', 4), ('TrumpPence16', 2), ('MAGA', 2), ('TrumpTrain', 2), ('Benghazi', 1)]
# #################
# #################
# 1345
# [('TeamTrump', 1), ('GrossMedia', 1), ('Trump2016', 1), ('NastyBillAndHill', 1), ('NeverHillary', 1)]
# #################
# #################
# 1346
# [('MAGA', 5), ('LatinosForTrump', 2), ('Wikileaks', 2), ('DeplorablesUnite', 2), ('Trump', 2)]
# #################
# #################
# 1349
# [('MAGA', 4), ('NeverHillary', 3), ('Trump', 3), ('USA', 2), ('Hillary', 2)]
# #################
# #################
# 1352
# [('cdnpoli', 3), ('PodestaEmails9', 2), ('CTVpp', 2), ('uspoli', 2), ('UKpolitics', 2)]
# #################
# #################
# 1353
# [('trump', 4), ('msm', 4), ('SmartNews', 2), ('chicago', 1), ('TrumpTrain', 1)]
# #################
# #################
# 1355
# [('maga', 3), ('HillaryGropedMe', 2), ('p2', 1), ('trump', 1), ('altright', 1)]
# #################
# #################
# 1360
# [('Trump', 4), ('MAGA', 1), ('Hillary', 1), ('MAGA3X', 1), ('TRUMP', 1)]
# #################
# #################
# 1363
# [('Trump', 4), ('TrumpPence16', 2), ('MAGA', 2), ('SundayMorning', 1), ('AmericaFirst', 1)]
# #################
# #################
# 1364
# [('SundayMorning', 2), ('Trump', 2), ('Clinton', 1), ('RobertDeNiro', 1), ('PodestaEmails9', 1)]
# #################
# #################
# 1369
# [('p2', 1), ('snl', 1), ('BuckeyeState', 1), ('BringItOn', 1), ('LoveTrumpsHate', 1)]
# #################
# #################
# 1372
# [('MAGA3X', 1), ('dumpsterfire', 1), ('ImWithHer', 1), ('TrumpPence16', 1), ('ElectoralCollege', 1)]
# #################
# #################
# 1375
# [('SNL', 2), ('icanhazPulitzernow', 1), ('TrumpFatigue', 1), ('loser', 1), ('whiner', 1)]
# #################
# #################
# 1377
# [('Clinton', 1), ('Trump', 1), ('PodestaEmails9', 1), ('wikileakemails', 1), ('Debate', 1)]
# #################
# #################
# 1378
# [('TrumpTapes', 1), ('100YearsStrong', 1), ('TrumpPence16', 1), ('TrumpCheck', 1), ('rigged', 1)]
# #################
# #################
# 1380
# [('Hillary2016', 3), ('HillYes', 3), ('VoteBlue', 3), ('ImWithHer', 2), ('HFA', 2)]
# #################
# #################
# 1383
# [('Trump', 4), ('WA', 1), ('ak', 1), ('WI', 1), ('WV', 1)]
# #################
# #################
# 1386
# [('trump', 2), ('MAGA', 2), ('georgia', 1), ('iowa', 1), ('usa', 1)]
# #################
# #################
# 1389
# [('Obama', 2), ('Soros', 1), ('1A', 1), ('HillaryBecause', 1), ('2A', 1)]
# #################
# #################
# 1390
# [('Trump', 4), ('TrumpPence16', 3), ('debate', 2), ('Hillary', 2), ('Obama', 2)]
# #################
# #################
# 1391
# [('Undecidedvoter', 1), ('CCOT', 1), ('Trump', 1), ('realtalk', 1), ('stupidDOPE', 1)]
# #################
# #################
# 1392
# [('Trump', 5), ('FlipItALLBlue', 2), ('HillaryGropedMe', 2), ('SchizophonicSocioplathicNarcissistic', 1), ('AmenstyDon', 1)]
# #################
# #################
# 1395
# [('NeverTrump', 1), ('Trump', 1), ('freedom', 1), ('bigly', 1), ('abortion', 1)]
# #################
# #################
# 1396
# [('tcot', 4), ('NeverHillary', 3), ('WakeUpAmerica', 3), ('MAGA', 3), ('PodestaEmails9', 3)]
# #################
# #################
# 1402
# [('Florida', 2), ('CNN', 2), ('NBCNews', 1), ('WI', 1), ('IA', 1)]
# #################
# #################
# 1403
# [('PodestaEmails9', 3), ('trump', 2), ('RiggedSystem', 2), ('MAGA3X', 2), ('ClintonNewsNetwork', 1)]
# #################
# #################
# 1404
# [('TrumpPence16', 2), ('MAGA', 1), ('HillaryForPrison2016', 1), ('MEDIA', 1), ('DumpRyan', 1)]
# #################
# #################
# 1406
# [('Trump', 2), ('MAGA', 2), ('biased', 1), ('CLINTON', 1), ('PartyWithDobbs', 1)]
# #################
# #################
# 1407
# [('MAGA', 8), ('TeamTrump', 7), ('Trump', 7), ('TrumpPence16', 7), ('TrumpTrain', 7)]
# #################
# #################
# 1409
# [('PodestaEmails9', 3), ('AmericaFirst', 2), ('MAGA', 2), ('girlpower', 1), ('podestaemails', 1)]
# #################
# #################
# 1413
# [('SundayMorning', 2), ('Trump', 1), ('tcot', 1), ('PodestaEmails9', 1), ('JudgeJeanine', 1)]
# #################
# #################
# 1414
# [('PodestaEmails9', 5), ('Trump', 3), ('HillaryClinton', 2), ('100YearsStrong', 1), ('HillaryBecause', 1)]
# #################
# #################
# 1419
# [('13TH', 1), ('TrumpSNL', 1), ('americandictator', 1), ('never', 1), ('BLACKLIVESMATTER', 1)]
# #################
# #################
# 1420
# [('PodestaEmails9', 2), ('Reflection', 1), ('ImWithHer', 1), ('VoteBlue', 1), ('HillaryBecause', 1)]
# #################
# #################
# 1429
# [('MAGA', 5), ('Trump', 4), ('TrumpTrain', 3), ('NCGOPHeadquarters', 3), ('MakeAmericaGreatAgain', 1)]
# #################
# #################
# 1434
# [('Trump', 8), ('MAGA', 6), ('TrumpTrain', 6), ('Hillary', 2), ('NeverHillary', 2)]
# #################
# #################
# 1437
# [('SHOWUSYOURTRUMP', 2), ('Trump', 2), ('HillaryBecause', 2), ('PodestaEmails', 2), ('MAGA', 2)]
# #################
# #################
# 1443
# [('PodestaEmails9', 7), ('HillaryGropedMe', 4), ('Periscope', 2), ('MAGA', 2), ('podestaemails9', 1)]
# #################
# #################
# 1444
# [('Trump', 2), ('CLINTON', 1), ('DefeatHillary', 1), ('PodestaEmails9', 1), ('LibCorruption', 1)]
# #################
# #################
# 1445
# [('DumpTrump', 3), ('dumptrump', 1), ('trump', 1), ('OrangeLoser', 1), ('TrumpCheck', 1)]
# #################
# #################
# 1446
# [('Trump', 1), ('BONESMEN4TRUMP', 1), ('podestaemails', 1), ('GoldmanSach', 1), ('memebusters', 1)]
# #################
# #################
# 1449
# [('trump', 10), ('podestaemails', 8), ('trumptrain', 6), ('cnn', 6), ('maga3x', 5)]
# #################
# #################
# 1451
# [('Trump', 2), ('HillaryClinton', 1), ('Sisi', 1), ('RealityisSurreal', 1), ('justice', 1)]
# #################
# #################
# 1453
# [('comtntests', 1), ('dementia', 1), ('media', 1), ('winner', 1), ('loser', 1)]
# #################
# #################
# 1455
# [('PodestaEmails', 2), ('SundayMorning', 1), ('Tatiana', 1), ('Trump', 1), ('TCOT', 1)]
# #################
# #################
# 1458
# [('Trump2016', 3), ('Trump', 3), ('MAGA', 3), ('PodestaEmails9', 2), ('Debate', 1)]
# #################
# #################
# 1459
# [('PodestaEmails9', 11), ('BoycottCNN', 5), ('BoycottCNNSponsors', 3), ('PodestaEmails', 3), ('HillaryGropedMe', 3)]
# #################
# #################
# 1461
# [('TrumpEffect', 1), ('p2', 1), ('SNL', 1), ('VotingRights', 1), ('GOP', 1)]
# #################
# #################
# 1463
# [('wikileaks', 2), ('scandalous', 1), ('DumpTrump', 1), ('TrumpCheck', 1), ('FoxNews', 1)]
# #################
# #################
# 1464
# [('MAGA', 5), ('Trump', 5), ('AmericaFirst', 2), ('HillaryBecause', 2), ('trump', 1)]
# #################
# #################
# 1467
# [('Trump', 3), ('icanhazPulitzernow', 1), ('NEVERTRUMP', 1), ('Romney', 1), ('NYT', 1)]
# #################
# #################
# 1472
# [('VoteTrumpPence16', 1), ('Arizona', 1), ('Clinton', 1), ('TRUMP', 1), ('nohyphenatedAmericans', 1)]
# #################
# #################
# 1478
# [('TRUMP', 2), ('PodestaEmails9', 2), ('tcot', 2), ('Hillary', 2), ('p2', 1)]
# #################
# #################
# 1479
# [('NeverTrump', 1), ('HillYes', 1), ('VoteYourFuture', 1), ('FlipItDem', 1), ('ImWithHer', 1)]
# #################
# #################
# 1481
# [('TrumpPence16', 3), ('Trump', 2), ('AmericaFirst', 1), ('USA', 1), ('WeThePeople', 1)]
# #################
# #################
# 1483
# [('vtpoli', 2), ('dumptrump', 1), ('vtdems', 1), ('VT', 1), ('vtgop', 1)]
# #################
# #################
# 1484
# [('Wikileaks', 1), ('HillaryClinton', 1), ('StopGlobalization', 1), ('MSMsucks', 1), ('NoMoreWAR', 1)]
# #################
# #################
# 1485
# [('trump', 3), ('SandyHook', 2), ('Election2016', 2), ('anybluewontdo', 1), ('uniteblue', 1)]
# #################
# #################
# 1487
# [('TrumpPence16', 2), ('TrumpTrain', 2), ('MAGA', 2), ('PaulRyan', 1), ('DALvsGB', 1)]
# #################
# #################
# 1493
# [('MAGA', 3), ('Trump', 2), ('Wikileaks', 2), ('TrumpTrain', 2), ('FeelTheBern', 1)]
# #################
# #################
# 1499
# [('PodestaEmails', 1), ('bernieorbust', 1), ('demexit', 1), ('0Sale', 1), ('HillaryGropedMe', 1)]
# #################
# #################
# 1503
# [('fascist', 2), ('Trump', 2), ('sniff', 1), ('TrumpTapes', 1), ('AMJoy', 1)]
# #################
# #################
# 1510
# [('politics', 10), ('news', 3), ('NBC', 2), ('Politics', 1), ('Philly', 1)]
# #################
# #################
# 1513
# [('clinton', 1), ('Trump', 1), ('2016election', 1), ('Utah', 1), ('TrumpCheck', 1)]
# #################
# #################
# 1517
# [('SundayMorning', 3), ('Election2016', 3), ('SNL', 2), ('AmericaFirst', 1), ('Corruption', 1)]
# #################
# #################
# 1521
# [('Trump', 3), ('TrumpPence16', 3), ('PodestaEmails9', 2), ('neverhillary', 2), ('maga3x', 1)]
# #################
# #################
# 1522
# [('OrangeBuffoon', 1), ('Republicans', 1), ('Black', 1), ('usa', 1), ('Election2016', 1)]
# #################
